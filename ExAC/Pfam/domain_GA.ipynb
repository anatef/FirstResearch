# %%
import pandas as pd
import numpy as np
import gzip
from collections import defaultdict
import matplotlib.pyplot as plt
import pickle
import sys
from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; }</style>")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
curr_dir = !pwd
filename = "Pfam-A.hmm.gz"

# %%
pfam_file = gzip.open(curr_dir[0]+"/"+filename,'r')

# %%
#Extract domain names and gathering threshold
domain_names = []
domain_GA = []
for line in pfam_file:
    if (line[0:4] == "NAME"):
        domain_names.append(line[6:-1])
    if (line[0:2] == "GA"):
        domain_GA.append(float(line[6:].split(" ")[0]))

# %%
#Create a table of names and GA
domain_GA_table = pd.DataFrame()
domain_GA_table["name"] = domain_names
domain_GA_table["GA"] = domain_GA

# %%
#Save the table to file
domain_GA_table.to_csv(curr_dir[0]+"/domains_GA.csv", sep='\t')
# Out:
#                   name    GA
# 0           1-cysPrx_C  20.4
# 1         120_Rick_ant  21.0
# 2               12TM_1  33.0
# 3               14-3-3  24.6
# 4         17kDa_Anti_2  26.6
# 5           2-Hacid_dh  24.6
# 6         2-Hacid_dh_C  25.1
# 7         2-oxoacid_dh  23.0
# 8      2-oxogl_dehyd_N  27.0
# 9           2-ph_phosp  26.4
# 10               23ISL  25.0
# 11        23S_rRNA_IVP  23.4
# 12              2CSK_N  21.0
# 13            2C_adapt  20.1
# 14     2Fe-2S_Ferredox  25.0
# 15     2Fe-2S_thioredx  24.8
# 16     2H-phosphodiest  21.0
# 17                2HCT  26.2
# 18        2OG-FeII_Oxy  21.3
# 19      2OG-FeII_Oxy_2  27.0
# 20      2OG-FeII_Oxy_3  27.0
# 21      2OG-FeII_Oxy_4  21.4
# 22      2OG-FeII_Oxy_5  27.0
# 23        2OG-Fe_Oxy_2  23.1
# 24                 2TM  24.8
# 25     2_5_RNA_ligase2  27.0
# 26             3-alpha  22.7
# 27        3-dmu-9_3-mt  21.1
# 28               3-HAO  20.4
# 29               3-PAP  23.2
# ...                ...   ...
# 16265    zinc_ribbon_6  27.0
# 16266    zinc_ribbon_9  30.0
# 16267        Zinicin_2  25.0
# 16268             ZinT  20.5
# 16269              Zip  29.0
# 16270           ZipA_C  20.6
# 16271           ZirS_C  27.0
# 16272     zn-ribbon_14  26.0
# 16273      Zn-ribbon_8  32.3
# 16274             ZnuA  23.7
# 16275          Zn_clus  20.8
# 16276      Zn_dep_PLPC  26.8
# 16277     Zn_peptidase  23.2
# 16278   Zn_peptidase_2  20.2
# 16279      Zn_protease  21.8
# 16280     Zn_ribbon_17  27.0
# 16281      Zn_ribbon_2  22.5
# 16282  Zn_ribbon_recom  25.3
# 16283       Zn_Tnp_IS1  26.1
# 16284    Zn_Tnp_IS1595  25.0
# 16285      Zn_Tnp_IS91  26.3
# 16286   Zona_pellucida  21.0
# 16287      ZoocinA_TRD  27.4
# 16288              Zot  20.3
# 16289         ZT_dimer  26.7
# 16290              ZU5  20.7
# 16291             Zw10  27.1
# 16292            Zwint  27.0
# 16293  ZYG-11_interact  25.0
# 16294               ZZ  21.4
#
# [16295 rows x 2 columns]
