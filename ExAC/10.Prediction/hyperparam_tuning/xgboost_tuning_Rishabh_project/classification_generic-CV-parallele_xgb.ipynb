# %%
#Basic imports
import pandas as pd
import numpy as np
import pickle
from collections import defaultdict
from os import environ

#Classifier imports
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost.sklearn import XGBClassifier

#ML framework imports
from sklearn.metrics import auc, roc_auc_score, precision_recall_curve
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import scale
import xgboost as xgb

#Downsamplers imports - prototype generation
from imblearn.under_sampling import ClusterCentroids

#Downsamplers imports - prototype selection - controlled
from imblearn.under_sampling import RandomUnderSampler, NearMiss

#Downsamplers imports - prototype selection - Cleaning techniques
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours, RepeatedEditedNearestNeighbours

#Downsamplers imports - prototype selection - Cleaning techniques - Condensed nearest neighbors and derived algorithms
from imblearn.under_sampling import CondensedNearestNeighbour, OneSidedSelection, NeighbourhoodCleaningRule

#Downsamplers imports - prototype selection - Cleaning techniques
from imblearn.under_sampling import InstanceHardnessThreshold

from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; }</style>")

ABSOLUTE_NEGATIVES = False
FILTER_DOMAIN = False

# %% [markdown]
# ### Reading the input dataset

# %%
curr_dir = !pwd
curr_dir[0] = curr_dir[0] + "/.."
input_path = curr_dir[0]+"/domains_similarity/filtered_features_table/"
filename = "positions_features_mediode_filter_01.25.18.csv"

#input_path = curr_dir[0]+"/../9.Features_exploration/binding_df/10/"
#filename = "positions_features_01.25.18.csv"

bind_scores_num = 10

#Features table
features_all = pd.read_csv(input_path+filename, sep='\t', index_col=0)
features_cols = features_all.columns[1:-bind_scores_num] #removing binding scores and domain name
ligands = ["dna", "dnabase", "dnabackbone", "rna", "rnabase", "rnabackbone", "peptide", "ion", "metabolite"]
print "all samples positions #: "+str(features_all.shape[0])

#lignd binding domains dictionary
with open(curr_dir[0]+"/ligands_negatives_domains_dict.pik", 'rb') as handle:
        negatives_dict = pickle.load(handle)
# Out:
# all samples positions #: 38944

# %% [markdown]
# #### Dataset of negative examples

# %%
def filter_to_ligand_binding_domains(use_max_binding_score):
    
    ligands_negatives_df = {}
    for ligand in ligands:
        
        ligands_negatives_df[ligand] = pd.DataFrame()
        for domain in negatives_dict[ligand].keys():
            if domain == 'negatives' or domain == 'domains':
                continue
            domain_all = features_all.loc[features_all.loc[:,"domain_name"] == domain,:]
            
            #In case this domain was previously filtered
            if len(domain_all) == 0:
                continue
            
            if (use_max_binding_score):
                ligands_negatives_df[ligand] = pd.concat([ligands_negatives_df[ligand],domain_all.loc[domain_all.loc[:,"max_binding_score"] == 0,:]])
            else:
                ligand_bind_str = ligand+"_binding_score"
                ligands_negatives_df[ligand] = pd.concat([ligands_negatives_df[ligand],domain_all.loc[domain_all.loc[:,ligand_bind_str] == 0,:]])
        
    #Handeling the ligand "all_ligands"
    all_ligands_negatives_df = pd.concat([ligands_negatives_df["dna"], ligands_negatives_df["dnabase"], ligands_negatives_df["dnabackbone"], ligands_negatives_df["rna"], ligands_negatives_df["rnabase"], 
                                 ligands_negatives_df["rnabackbone"], ligands_negatives_df["ion"], ligands_negatives_df["peptide"], ligands_negatives_df["metabolite"]])
    all_ligands_negatives_df = all_ligands_negatives_df.drop_duplicates()
    #Filter to just positions with max. binding score = 0
    all_ligands_negatives_df = all_ligands_negatives_df[all_ligands_negatives_df["max_binding_score"] == 0]
    ligands_negatives_df["all_ligands"] = all_ligands_negatives_df
    
    #Leaving just the features columns
    for ligand in ligands_negatives_df.keys():   
        ligands_negatives_df[ligand] = ligands_negatives_df[ligand][features_cols]
        print(ligand+" non-binding #:"+str(len(ligands_negatives_df[ligand])))
    
    return ligands_negatives_df

# %%
def negatives_by_binding_score(use_max_binding_score):
    
    ligands_negatives_df = {}
    for ligand in ligands:
        
        if use_max_binding_score:
            ligand_bind_str = "max_binding_score"
        else:
            ligand_bind_str = ligand+"_binding_score"
        
        ligands_negatives_df[ligand] = features_all[features_all[ligand_bind_str] == 0]
        ligands_negatives_df[ligand] = ligands_negatives_df[ligand].loc[:,features_cols]
        print(ligand+" non-binding #:"+str(len(ligands_negatives_df[ligand])))
        
    #Handeling the ligand "all_ligands"
    ligands_negatives_df["all_ligands"] = features_all[features_all["max_binding_score"] == 0]
    ligands_negatives_df["all_ligands"] = ligands_negatives_df["all_ligands"].loc[:,features_cols]
    print("all_ligands non-binding #:"+str(len(ligands_negatives_df["all_ligands"])))
    
    return ligands_negatives_df

# %%
#Create negatives datasets
if FILTER_DOMAIN:
    if ABSOLUTE_NEGATIVES:
        ligands_negatives_df = filter_to_ligand_binding_domains(True)
    else:
        ligands_negatives_df = filter_to_ligand_binding_domains(False)
else:
    if ABSOLUTE_NEGATIVES:
        ligands_negatives_df = negatives_by_binding_score(True)
    else:
        ligands_negatives_df = negatives_by_binding_score(False)
# Out:
# dna non-binding #:38095
# dnabase non-binding #:38577
# dnabackbone non-binding #:38203
# rna non-binding #:38047
# rnabase non-binding #:38407
# rnabackbone non-binding #:38223
# peptide non-binding #:35437
# ion non-binding #:34488
# metabolite non-binding #:33971
# all_ligands non-binding #:27191

# %% [markdown]
# #### Datasets of positive examples by ligand

# %%
bind_th = 0.1
ligands_features_df = {}

for ligand in ligands:
    score_col_str = ligand+"_binding_score"
    ligand_binding_df = features_all[features_all[score_col_str] >= bind_th]
    print ligand+" #: "+str(ligand_binding_df.shape[0])
    ligands_features_df[ligand] = ligand_binding_df.loc[:,features_cols]
# Out:
# dna #: 501
# dnabase #: 193
# dnabackbone #: 408
# rna #: 433
# rnabase #: 224
# rnabackbone #: 308
# peptide #: 1496
# ion #: 1093
# metabolite #: 1525

# %% [markdown]
# #### Dataset of positive examples - all ligands combined

# %%
all_ligands_features_df = pd.concat([ligands_features_df["dna"], ligands_features_df["dnabase"], ligands_features_df["dnabackbone"], ligands_features_df["rna"], ligands_features_df["rnabase"], 
                                     ligands_features_df["rnabackbone"], ligands_features_df["ion"], ligands_features_df["peptide"], ligands_features_df["metabolite"]])
all_ligands_features_df = all_ligands_features_df.drop_duplicates()
print "all_ligands #: "+str(all_ligands_features_df.shape[0])
ligands_features_df["all_ligands"] = all_ligands_features_df
# Out:
# all_ligands #: 4518

# %% [markdown]
# ### Models tested (and their hyper-parameters)

# %%
classifiers = {}
classifiers["Logistic"] = LogisticRegression(C=0.001, random_state=0)
classifiers["RF"] = RandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=0)  
#classifiers["RF"] = RandomForestRegressor(n_estimators=1000)  
classifiers["KNN"] = KNeighborsClassifier(n_neighbors=100, n_jobs=-1)
#classifiers["KNN"] = KNeighborsRegressor(n_neighbors=100)
classifiers["SVM"] = SVC(kernel='rbf', probability=True, random_state=0)
classifiers["ADA-RF"] = AdaBoostClassifier(n_estimators=1000, random_state=0)
classifiers["ADA-Log"] = AdaBoostClassifier(base_estimator=classifiers["Logistic"], n_estimators=1000, random_state=0)
#classifiers["Bag-Log"] = BaggingClassifier(base_estimator=classifiers["Logistic"], n_estimators=1000, n_jobs=-1, random_state=0)
classifiers["XGB"] = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=0, max_depth=6, min_child_weight=0.05, colsample_bytree=0.5)
classifiers["XGB0"] = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=0, max_depth=6, min_child_weight=0, colsample_bytree=0.5)
classifiers["XGB1"] = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=0, max_depth=6, min_child_weight=1, colsample_bytree=0.5)
classifiers["XGBTuned1"] = XGBClassifier(n_estimators=108, learning_rate = 0.1, n_jobs=-1, random_state=0, max_depth=3, min_child_weight=16, colsample_bytree=0.7, subsample=0.7, gamma = 0, reg_alpha = .5, scale_pos_weight = 1)
classifiers["XGBTuned2"] = XGBClassifier(n_estimators=268, learning_rate = 0.1, n_jobs=-1, random_state=0, max_depth=3, min_child_weight=16, colsample_bytree=0.7, subsample=0.7, gamma = 0, reg_alpha = .5, scale_pos_weight = 1)
classifiers["XGBTuned3"] = XGBClassifier(n_estimators=86, learning_rate = .01, n_jobs=-1, random_state=0, max_depth=3, min_child_weight=16, colsample_bytree=0.7, subsample=0.7, gamma = 0, reg_alpha = .5, scale_pos_weight = 1)

classifiers["XGBUntuned4Dna"] = XGBClassifier( learning_rate =0.1, n_estimators=190, max_depth=5, min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic', nthread=5, scale_pos_weight=1, random_state=0)
classifiers["XGBTuned4Dna"] = XGBClassifier( learning_rate =0.1, n_estimators=190, max_depth=7, min_child_weight=4, gamma=.6, subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic', nthread=5, scale_pos_weight=1, random_state=0)

classifiers["XGBSPW=76"] = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=0, max_depth=6, min_child_weight=0.05, colsample_bytree=0.5, scale_pos_weight = 76)

classifiers["XGBSPW=76Tuned"] = XGBClassifier(n_estimators=190, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=0.5, scale_pos_weight = 76,gamma = .2,)
classifiers["XGBSPW=76Tuned2"] = XGBClassifier(n_estimators=190, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=0.5, scale_pos_weight = 76,gamma = .1,)
classifiers["XGBSPWSampling1"] = XGBClassifier(n_estimators=190, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=1.0, subsample=.1, scale_pos_weight = 76,gamma = .1,)
classifiers["XGBSPWSampling2"] = XGBClassifier(n_estimators=190, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=.5, subsample=.8, scale_pos_weight = 76,gamma = .1,)
classifiers["XGBSPWSampling3"] = XGBClassifier(n_estimators=190, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=.2, subsample=1.0, scale_pos_weight = 76,gamma = .1,)
classifiers["XGBSPWSampling3Slow"] = XGBClassifier(n_estimators=215, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=.2, subsample=1.0, scale_pos_weight = 76,gamma = .1,learning_rate=0.1)
classifiers["XGBSPWSampling3EarlyStoppingTest"] = XGBClassifier(n_estimators=215, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=.2, subsample=1.0, scale_pos_weight = 76,gamma = .1,learning_rate=0.1)
classifiers["XGBBestDNA_from_cluster"] = XGBClassifier(n_estimators=42, n_jobs = -1, random_state=0, max_depth=5, min_child_weight=2,
    colsample_bytree=.8, subsample=.9, scale_pos_weight = 76,gamma = .6,learning_rate=0.1)

# %% [markdown]
# ### Downsamplers tested

# %%
#documentation on techniques: http://contrib.scikit-learn.org/imbalanced-learn/stable/under_sampling.html#cleaning-under-sampling-techniques
downsamplers = defaultdict(dict)

##Prototype generation##
downsamplers["ClusterCentroids"] = ClusterCentroids(random_state=0)

##Prototype selection##
#Contolled#
downsamplers["RandomUnderSampler"] = RandomUnderSampler(random_state=0)
downsamplers["NearMiss3"] = NearMiss(random_state=0, version=3)
downsamplers["NearMiss2"] = NearMiss(random_state=0, version=2)
downsamplers["NearMiss1"] = NearMiss(random_state=0, version=1)

#Cleaning#
downsamplers["TomekLinks"] = TomekLinks(random_state=0)
downsamplers["EditedNearestNeighbours"] = EditedNearestNeighbours(random_state=0)
downsamplers["RepeatedEditedNearestNeighbours"] = RepeatedEditedNearestNeighbours(random_state=0)
downsamplers["NeighbourhoodCleaningRule"] = NeighbourhoodCleaningRule(random_state=0)

# Instance hardness threshold#
downsamplers["InstanceHardnessThreshold"]["KNN"] = InstanceHardnessThreshold(random_state=0, estimator=classifiers["KNN"])
#downsamplers["InstanceHardnessThreshold"]["KNN"] = InstanceHardnessThreshold(random_state=0, estimator= KNeighborsClassifier(n_neighbors=100))
downsamplers["InstanceHardnessThreshold"]["SVM"] = InstanceHardnessThreshold(random_state=0, estimator=classifiers["SVM"])
downsamplers["InstanceHardnessThreshold"]["RF"] = InstanceHardnessThreshold(random_state=0, estimator=classifiers["RF"])
#downsamplers["InstanceHardnessThreshold"]["RF"] = InstanceHardnessThreshold(random_state=0, estimator=RandomForestClassifier(n_estimators=1000))
downsamplers["InstanceHardnessThreshold"]["Logistic"] = InstanceHardnessThreshold(random_state=0, estimator=classifiers["Logistic"])
#downsamplers["InstanceHardnessThreshold"]["ADA"] = InstanceHardnessThreshold(random_state=0, estimator=classifiers["ADA"])

# %% [markdown]
# ### Reading env input for downsampler technique, ligand and classifier

# %%
#Reading the ligand input
try:
    ligand = environ['ligand']
except:
    ligand = "dnabase"
print "ligand = "+ligand
    
#Reading the downsampler input
try: 
    downsample_method = environ['down']
except:
    downsample_method = "NoDown"
print "downsample_method = "+downsample_method

#Reading the classifier input
try: 
    classifier_method = environ['classifier']
except:
    classifier_method = "XGB"
print "classifier_method = "+classifier_method
# Out:
# ligand = dnabase
# downsample_method = NoDown
# classifier_method = XGB

# %% [markdown]
# ### Test model functions

# %%
def test_model(pred_dict, auc_dict, auprc_dict, ligand_bind_features, ligand_negatives_features, ligand_name, downsample_method, features=[]):
    """
    Test different models in 10-folds cross-validation.
    """
    
    #Default: Exclude no features
    if len(features) == 0:
        features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
        
    #Arranging the features table by the CV order, for each model
    features_pred_dfs = dict.fromkeys(classifiers.keys())
    
    models_req_scaling = ["SVM", "KNN"]
    
    for classifier in classifiers.keys():
        classifier = classifier_method
        model = classifiers[classifier]
        print "classifier_method = " + classifier_method
        print "ligand = " + ligand
        #early_stop = 200
        #print "early stopping: " + str(early_stop)
        print model.get_xgb_params()
        features_pred_dfs[classifier] = pd.DataFrame()
        
        #Create X and y with included features
        X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
        
        if (classifier in models_req_scaling):
            idx = X.index
            cols = X.columns
            X = pd.DataFrame(scale(X)) #Is z-scoring the data needed?
            X.index = idx #Restoring indices after scaling
            X.columns = cols

        y = [1] * ligand_bind_features.shape[0]
        y.extend([0] * ligand_negatives_features.shape[0])
        y = np.array(y)

        binding_skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
        pred_idx = 1

        for train_index, test_index in binding_skf.split(X, y):
            print "fold #: "+str(pred_idx)
            X_train, X_test = X.iloc[train_index,:], X.iloc[test_index,:]
            y_train, y_test = y[train_index], y[test_index]

            #Down-sample negative examples to have balanced classes
            if (downsample_method == "NoDown"):
                X_train_sampled = X_train
                y_train_sampled = y_train
            else:
                if (downsample_method == "InstanceHardnessThreshold"):
                    downsampler = downsamplers[downsample_method][classifier]
                else:
                    downsampler = downsamplers[downsample_method]

                X_train_sampled, y_train_sampled = downsampler.fit_sample(X_train, y_train)
            
            #early_stopping validation set 
            #7.8 Early stopping and Algorithm 7.2
            #http://egrcc.github.io/docs/dl/deeplearningbook-regularization.pdf
            
            #X_subtrain, X_valid, y_subtrain, y_valid = train_test_split(X_train_sampled, 
            #                                y_train_sampled, stratify=y_train_sampled, test_size = .5)
            
            #fit to training data
            model = classifiers[classifier]
            #model.fit(X_subtrain, y_subtrain, eval_set = [(X_valid,y_valid)],eval_metric = "map", early_stopping_rounds = early_stop,verbose = False)
            
            model.fit(X_train_sampled, y_train_sampled)
            
            #print model.best_ntree_limit
            probs_list = []

            #probs = model.predict(X_test)
            #probs_list = probs
            
            probs = model.predict_proba(X_test)#, ntree_limit=model.best_ntree_limit)
            for l in probs:
                probs_list.append(l[1])
                
            pred_dict["obs"].extend(y_test)
            pred_dict["prob"].extend(probs_list)
            fold_list = [pred_idx] * len(probs_list)
            pred_dict["fold"].extend(fold_list)

            model_list = [classifier] * len(probs_list)
            pred_dict["model"].extend(model_list)

            #Update auc auprc dictionaries
            auc_dict[classifier].append(roc_auc_score(y_test, probs[:, 1]))
            precision, recall, _ = precision_recall_curve(y_test, probs[:, 1])
            
            #auc_dict[classifier].append(roc_auc_score(y_test, probs))
            #precision, recall, _ = precision_recall_curve(y_test, probs)
            
            auprc_dict[classifier].append(auc(recall, precision))
            
            #Update features table
            features_pred_dfs[classifier] = features_pred_dfs[classifier].append(X_test)
            pred_idx += 1
            
            print "AUC = "+str(auc_dict[classifier][-1])
            print "AUPRC = "+str(auprc_dict[classifier][-1])

        avg_auc = np.sum(auc_dict[classifier])/10.0
        print "avg auc = "+str(avg_auc) 
        
        avg_auprc = np.sum(auprc_dict[classifier])/10.0
        print "avg auprc = "+str(avg_auprc)
            
        print "Finished "+ligand+" "+classifier
        break
    
    return features_pred_dfs

# %%
def combine_features_predictions(ligand, ordered_features, pred_df):
    
    pred_res = pred_df.copy(deep=True)
    for classifier in classifiers.keys():
        classifier = classifier_method
        model_pred = pred_res[pred_res["model"] == classifier]
        model_pred.index = ordered_features[classifier].index
        
        #Creating the combined table
        features_pred = pd.concat([ordered_features[classifier], model_pred], axis=1)
        
        #Saving
        #features_pred.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/features_pred_tables/"+ligand+"_"+classifier+"_features_pred.csv", sep='\t')
        break

# %% [markdown]
# #### Predict for each ligand seperatelly

# %%
ligands
# Out:
# ['dna',
#  'dnabase',
#  'dnabackbone',
#  'rna',
#  'rnabase',
#  'rnabackbone',
#  'peptide',
#  'ion',
#  'metabolite']

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGB"
ligand = "dna"
print "classifier_method = "+classifier_method
ret_val = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)
print ret_val

#pred_df = pd.DataFrame.from_dict(pred_dict)
#auc_df = pd.DataFrame.from_dict(auc_dict)
#auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
#combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGB
# classifier_method = XGB
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 1000, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 0.05, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 6, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# fold #: 2
# fold #: 3
# fold #: 4
# fold #: 5
# fold #: 6
# fold #: 7
# fold #: 8
# fold #: 9
# fold #: 10
# avg auc = 0.9688455763937419
# avg auprc = 0.5728799955409182
# Finished dna XGB
# (0.9688455763937419, 0.5728799955409182)
# Finished ligand dna
# CPU times: user 3h 34min 41s, sys: 1min 5s, total: 3h 35min 46s
# Wall time: 6min 15s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGB0"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGB0
# XGB0
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 1000, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 6, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9283307413167443
# AUPRC = 0.20598023081482716
# fold #: 2
# AUC = 0.9261664074650078
# AUPRC = 0.3347628515265228
# fold #: 3
# AUC = 0.9717340590979783
# AUPRC = 0.34607683761326613
# fold #: 4
# AUC = 0.9706692859676407
# AUPRC = 0.2893260762256532
# fold #: 5
# AUC = 0.9336853019017217
# AUPRC = 0.15494171444777186
# fold #: 6
# AUC = 0.9876538157212628
# AUPRC = 0.33022125279318804
# fold #: 7
# AUC = 0.9682955444599055
# AUPRC = 0.23838729908026665
# fold #: 8
# AUC = 0.9406274306455795
# AUPRC = 0.13281975767740178
# fold #: 9
# AUC = 0.9778666266391933
# AUPRC = 0.2318335902319532
# fold #: 10
# AUC = 0.9808550414147893
# AUPRC = 0.20323760510817854
# avg auc = 0.9585884254629823
# avg auprc = 0.24675872155190293
# Finished dnabase XGB0
# Finished ligand dnabase
# CPU times: user 14h 20min 6s, sys: 3min 34s, total: 14h 23min 41s
# Wall time: 25min 38s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGB1"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGB1
# XGB1
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 1000, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 1, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 6, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9459823742871954
# AUPRC = 0.18759793948050751
# fold #: 2
# AUC = 0.9256220839813375
# AUPRC = 0.3134783583479348
# fold #: 3
# AUC = 0.9661093831000518
# AUPRC = 0.2545237423287126
# fold #: 4
# AUC = 0.9755259065236964
# AUPRC = 0.2908478006779861
# fold #: 5
# AUC = 0.926332160104772
# AUPRC = 0.15980258304066633
# fold #: 6
# AUC = 0.9837385064527571
# AUPRC = 0.2973899886274574
# fold #: 7
# AUC = 0.9737933480669013
# AUPRC = 0.24637447311508268
# fold #: 8
# AUC = 0.9481735190971985
# AUPRC = 0.13682648794125002
# fold #: 9
# AUC = 0.9696518974386966
# AUPRC = 0.2197572267935536
# fold #: 10
# AUC = 0.9812098303835814
# AUPRC = 0.20868797612266715
# avg auc = 0.959613900943619
# avg auprc = 0.23152865764758182
# Finished dnabase XGB1
# Finished ligand dnabase
# CPU times: user 7h 37min 2s, sys: 2min 15s, total: 7h 39min 18s
# Wall time: 14min 1s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBTuned1"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBTuned1
# XGBTuned1
# {'reg_alpha': 0.5, 'colsample_bytree': 0.7, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 108, 'subsample': 0.7, 'reg_lambda': 1, 'min_child_weight': 16, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 1, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.807030844997408
# AUPRC = 0.14713145744324044
# fold #: 2
# AUC = 0.8922174701918093
# AUPRC = 0.2456178570800179
# fold #: 3
# AUC = 0.9034862623120788
# AUPRC = 0.26463888531935736
# fold #: 4
# AUC = 0.8979495784562495
# AUPRC = 0.13171896467807515
# fold #: 5
# AUC = 0.8494925104362773
# AUPRC = 0.14732196704699865
# fold #: 6
# AUC = 0.9173760606804725
# AUPRC = 0.3133979962441291
# fold #: 7
# AUC = 0.8274671905268615
# AUPRC = 0.10221648986231564
# fold #: 8
# AUC = 0.8706521294160992
# AUPRC = 0.10743259909223946
# fold #: 9
# AUC = 0.8335630364477437
# AUPRC = 0.08929582855078706
# fold #: 10
# AUC = 0.9402317044880805
# AUPRC = 0.1590159420926052
# avg auc = 0.8739466787953079
# avg auprc = 0.1707787987409766
# Finished dnabase XGBTuned1
# Finished ligand dnabase
# CPU times: user 17min 49s, sys: 14.8 s, total: 18min 4s
# Wall time: 50.5 s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBTuned2"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBTuned2
# XGBTuned2
# {'reg_alpha': 0.5, 'colsample_bytree': 0.7, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 268, 'subsample': 0.7, 'reg_lambda': 1, 'min_child_weight': 16, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 1, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.8260627268014515
# AUPRC = 0.11302788408812203
# fold #: 2
# AUC = 0.9217988595127009
# AUPRC = 0.25699153321887486
# fold #: 3
# AUC = 0.9217340590979782
# AUPRC = 0.21325011468921576
# fold #: 4
# AUC = 0.9212026956972523
# AUPRC = 0.25630803736264407
# fold #: 5
# AUC = 0.8588442334451993
# AUPRC = 0.13308505025211484
# fold #: 6
# AUC = 0.9434121852064064
# AUPRC = 0.3721012794570318
# fold #: 7
# AUC = 0.8568933999072331
# AUPRC = 0.09290295799242532
# fold #: 8
# AUC = 0.8893058417368285
# AUPRC = 0.1362742417427251
# fold #: 9
# AUC = 0.8805589290831435
# AUPRC = 0.11963527918550573
# fold #: 10
# AUC = 0.9449667726484997
# AUPRC = 0.1986312299293705
# avg auc = 0.8964779703136692
# avg auprc = 0.189220760791803
# Finished dnabase XGBTuned2
# Finished ligand dnabase
# CPU times: user 39min 11s, sys: 26.6 s, total: 39min 37s
# Wall time: 1min 33s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBTuned3"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBTuned3
# XGBTuned3
# {'reg_alpha': 0.5, 'colsample_bytree': 0.7, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.01, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 86, 'subsample': 0.7, 'reg_lambda': 1, 'min_child_weight': 16, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 1, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.7570697252462416
# AUPRC = 0.05553485190377219
# fold #: 2
# AUC = 0.853538102643857
# AUPRC = 0.07532002163355103
# fold #: 3
# AUC = 0.8338711767755314
# AUPRC = 0.11065110247574282
# fold #: 4
# AUC = 0.8272625576382636
# AUPRC = 0.08251685637131378
# fold #: 5
# AUC = 0.8352705246787264
# AUPRC = 0.09161760242813605
# fold #: 6
# AUC = 0.8501814411612234
# AUPRC = 0.15406479264345818
# fold #: 7
# AUC = 0.7363441652342365
# AUPRC = 0.09690432634167996
# fold #: 8
# AUC = 0.7693939931498437
# AUPRC = 0.0621913231656854
# fold #: 9
# AUC = 0.6681222111540194
# AUPRC = 0.02431524051758961
# fold #: 10
# AUC = 0.8541066823137698
# AUPRC = 0.1320084230573519
# avg auc = 0.7985160579995713
# avg auprc = 0.08851245405382809
# Finished dnabase XGBTuned3
# Finished ligand dnabase
# CPU times: user 14min 37s, sys: 13.3 s, total: 14min 50s
# Wall time: 43.7 s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBUntuned4Dna"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBUntuned4Dna
# classifier_method = XGBUntuned4Dna
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.8, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'nthread': 5, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 0.8, 'reg_lambda': 1, 'min_child_weight': 1, 'objective': 'binary:logistic', 'seed': 27, 'max_depth': 5, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9595749060779167
# AUPRC = 0.5411362662126133
# fold #: 2
# AUC = 0.9730236220472441
# AUPRC = 0.568356016856487
# fold #: 3
# AUC = 0.940503937007874
# AUPRC = 0.570108574610205
# fold #: 4
# AUC = 0.9656797900262467
# AUPRC = 0.6134804384575574
# fold #: 5
# AUC = 0.9658005249343832
# AUPRC = 0.5371323639161083
# fold #: 6
# AUC = 0.9845628773956419
# AUPRC = 0.518449800821479
# fold #: 7
# AUC = 0.9602362824888422
# AUPRC = 0.5314029051981678
# fold #: 8
# AUC = 0.9885481753741139
# AUPRC = 0.6704159617094891
# fold #: 9
# AUC = 0.9838697820950381
# AUPRC = 0.5278406734887721
# fold #: 10
# AUC = 0.9484064058808086
# AUPRC = 0.5371575103248813
# avg auc = 0.9670206303328109
# avg auprc = 0.5615480511595761
# Finished dna XGBUntuned4Dna
# Finished ligand dna
# CPU times: user 25min 21s, sys: 3.15 s, total: 25min 24s
# Wall time: 5min 19s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBTuned4Dna"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBTuned4Dna
# classifier_method = XGBTuned4Dna
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.8, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'nthread': 5, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 0.8, 'reg_lambda': 1, 'min_child_weight': 4, 'objective': 'binary:logistic', 'seed': 27, 'max_depth': 7, 'gamma': 0.6, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9623436776285317
# AUPRC = 0.5126136645073994
# fold #: 2
# AUC = 0.9641049868766405
# AUPRC = 0.5320622749349843
# fold #: 3
# AUC = 0.9473490813648295
# AUPRC = 0.5641662809068302
# fold #: 4
# AUC = 0.9700892388451443
# AUPRC = 0.6111808578460529
# fold #: 5
# AUC = 0.9708188976377953
# AUPRC = 0.5459117239500124
# fold #: 6
# AUC = 0.98367550538199
# AUPRC = 0.5178210309843262
# fold #: 7
# AUC = 0.9613179312155422
# AUPRC = 0.5570482001065977
# fold #: 8
# AUC = 0.9876503019165135
# AUPRC = 0.6658482408190497
# fold #: 9
# AUC = 0.9851614597007089
# AUPRC = 0.5209172610698962
# fold #: 10
# AUC = 0.9491730112890523
# AUPRC = 0.5001420134993805
# avg auc = 0.9681684091856747
# avg auprc = 0.5527711548624529
# Finished dna XGBTuned4Dna
# Finished ligand dna
# CPU times: user 33min 22s, sys: 3.19 s, total: 33min 25s
# Wall time: 6min 55s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPW=76"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPW=76
# classifier_method = XGBSPW=76
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 1000, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 0.05, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 6, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9681231022592764
# AUPRC = 0.5314034298120206
# fold #: 2
# AUC = 0.9625511811023623
# AUPRC = 0.5532429779991392
# fold #: 3
# AUC = 0.9589238845144357
# AUPRC = 0.5587261390338145
# fold #: 4
# AUC = 0.9768713910761154
# AUPRC = 0.6504401216125754
# fold #: 5
# AUC = 0.9740419947506562
# AUPRC = 0.5433794925930066
# fold #: 6
# AUC = 0.9820005250721974
# AUPRC = 0.5436923714958115
# fold #: 7
# AUC = 0.9619952743502231
# AUPRC = 0.5422731828918693
# fold #: 8
# AUC = 0.9803622998162248
# AUPRC = 0.6599993114435061
# fold #: 9
# AUC = 0.9859280651089525
# AUPRC = 0.6135566355842432
# fold #: 10
# AUC = 0.9407823575741665
# AUPRC = 0.5411106311590795
# avg auc = 0.9691580075624611
# avg auprc = 0.5737824293625066
# Finished dna XGBSPW=76
# Finished ligand dna
# CPU times: user 7h 16min 33s, sys: 2min 5s, total: 7h 18min 39s
# Wall time: 12min 47s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPW=76Tuned"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPW=76Tuned
# classifier_method = XGBSPW=76Tuned
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'nthread': 1, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.2, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9725696052699295
# AUPRC = 0.5496023107391048
# fold #: 2
# AUC = 0.9729238845144357
# AUPRC = 0.5945276617158096
# fold #: 3
# AUC = 0.9619737532808399
# AUPRC = 0.5465831329057493
# fold #: 4
# AUC = 0.9754803149606299
# AUPRC = 0.648100795656263
# fold #: 5
# AUC = 0.9752755905511812
# AUPRC = 0.6081963950632989
# fold #: 6
# AUC = 0.9857915463376214
# AUPRC = 0.5413520126426142
# fold #: 7
# AUC = 0.9728905224468365
# AUPRC = 0.528470428500273
# fold #: 8
# AUC = 0.985607771068522
# AUPRC = 0.706295508052633
# fold #: 9
# AUC = 0.9846101338934103
# AUPRC = 0.6164476999403622
# fold #: 10
# AUC = 0.9434759779469677
# AUPRC = 0.5457911052586532
# avg auc = 0.9730599100270373
# avg auprc = 0.5885367050474761
# Finished dna XGBSPW=76Tuned
# Finished ligand dna
# CPU times: user 27min 16s, sys: 2.89 s, total: 27min 19s
# Wall time: 27min 19s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPW=76Tuned2"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPW=76Tuned2
# classifier_method = XGBSPW=76Tuned2
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9654315269414853
# AUPRC = 0.5395793256024765
# fold #: 2
# AUC = 0.9682992125984251
# AUPRC = 0.5437820066712443
# fold #: 3
# AUC = 0.9600000000000001
# AUPRC = 0.5765961423656617
# fold #: 4
# AUC = 0.9676482939632546
# AUPRC = 0.680253390857843
# fold #: 5
# AUC = 0.9786141732283465
# AUPRC = 0.5984576348544359
# fold #: 6
# AUC = 0.9876765555263849
# AUPRC = 0.5662582795430952
# fold #: 7
# AUC = 0.9741454449986873
# AUPRC = 0.5129763847646818
# fold #: 8
# AUC = 0.9811551588343397
# AUPRC = 0.7159968783103337
# fold #: 9
# AUC = 0.9825623523234445
# AUPRC = 0.6043627410301569
# fold #: 10
# AUC = 0.9402362824888422
# AUPRC = 0.5485362281894248
# avg auc = 0.970576900090321
# avg auprc = 0.5886799012189353
# Finished dna XGBSPW=76Tuned2
# Finished ligand dna
# CPU times: user 59min 20s, sys: 18.6 s, total: 59min 39s
# Wall time: 1min 51s

# %%
# %%time
    
#Trying early stopping
#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGB"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGB
# classifier_method = XGB
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 1000, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 0.05, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 6, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# 91
# AUC = 0.9752148628480264
# AUPRC = 0.5490236817104815
# fold #: 2
# 116
# AUC = 0.972482939632546
# AUPRC = 0.5373684053454282
# fold #: 3
# 90
# AUC = 0.9669238845144357
# AUPRC = 0.5781991142319687
# fold #: 4
# 111
# AUC = 0.9765984251968505
# AUPRC = 0.6244182297791343
# fold #: 5
# 61
# AUC = 0.9680209973753281
# AUPRC = 0.46974786568908633
# fold #: 6
# 97
# AUC = 0.9891572591231294
# AUPRC = 0.5418884275389815
# fold #: 7
# 96
# AUC = 0.9791493830401681
# AUPRC = 0.5526473263389557
# fold #: 8
# 73
# AUC = 0.98947755316356
# AUPRC = 0.6891099855823766
# fold #: 9
# 75
# AUC = 0.9856130217904961
# AUPRC = 0.5666105174181898
# fold #: 10
# 116
# AUC = 0.9478288264636386
# AUPRC = 0.5294528214131621
# avg auc = 0.9750467153148177
# avg auprc = 0.5638466375047765
# Finished dna XGB
# Finished ligand dna
# CPU times: user 3h 25min 47s, sys: 1min 18s, total: 3h 27min 5s
# Wall time: 9min 34s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling1"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling1
# classifier_method = XGBSPWSampling1
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 1.0, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 0.1, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.8565282280891359
# AUPRC = 0.32559855589513725
# fold #: 2
# AUC = 0.8405564304461942
# AUPRC = 0.26856106300066923
# fold #: 3
# AUC = 0.8577007874015748
# AUPRC = 0.23620270996713247
# fold #: 4
# AUC = 0.873280839895013
# AUPRC = 0.29236407474185094
# fold #: 5
# AUC = 0.9135958005249344
# AUPRC = 0.3972530010633824
# fold #: 6
# AUC = 0.8635179837227619
# AUPRC = 0.20232838483122798
# fold #: 7
# AUC = 0.8674402730375427
# AUPRC = 0.3155712603654748
# fold #: 8
# AUC = 0.9153583617747441
# AUPRC = 0.4242542800587117
# fold #: 9
# AUC = 0.8841165660278288
# AUPRC = 0.31437689411523023
# fold #: 10
# AUC = 0.8456182725124706
# AUPRC = 0.3247828242541989
# avg auc = 0.8717713543432201
# avg auprc = 0.31012930482930157
# Finished dna XGBSPWSampling1
# Finished ligand dna
# CPU times: user 57min 25s, sys: 18.7 s, total: 57min 44s
# Wall time: 1min 48s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling2"
ligand = "dna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling2
# classifier_method = XGBSPWSampling2
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 0.8, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.954021923730122
# AUPRC = 0.506743739131805
# fold #: 2
# AUC = 0.9665354330708662
# AUPRC = 0.5473325610819234
# fold #: 3
# AUC = 0.9541574803149606
# AUPRC = 0.5318716129328095
# fold #: 4
# AUC = 0.9716482939632546
# AUPRC = 0.6440484977607943
# fold #: 5
# AUC = 0.9663097112860893
# AUPRC = 0.5624779016017152
# fold #: 6
# AUC = 0.9817694933053295
# AUPRC = 0.4958970285553826
# fold #: 7
# AUC = 0.9715778419532686
# AUPRC = 0.5598216789592925
# fold #: 8
# AUC = 0.9840010501443948
# AUPRC = 0.6715948118940062
# fold #: 9
# AUC = 0.977967970595957
# AUPRC = 0.5373063790296229
# fold #: 10
# AUC = 0.9484431609346284
# AUPRC = 0.5142504823616928
# avg auc = 0.9676432359298872
# avg auprc = 0.5571344693309044
# Finished dna XGBSPWSampling2
# Finished ligand dna
# CPU times: user 58min 5s, sys: 18.7 s, total: 58min 23s
# Wall time: 1min 49s

# %%
print "test"
# Out:
# test

# %%
# %%time

classifiers["XGB_GS"] = XGBClassifier(n_estimators=190, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
    colsample_bytree=.5, subsample=.8, scale_pos_weight = 76,gamma = .1,)    
score_dict = defaultdict(list)
classifier_method = "XGB_GS"
ligand = "dna"
curr_best_score = 0
print "classifier_method = "+classifier_method
for colsamp in range(1,11,1):
    for subsamp in range(1,11,1):
        pred_dict = defaultdict(list)
        auc_dict = defaultdict(list)
        auprc_dict = defaultdict(list)
        classifiers["XGB_GS"] = XGBClassifier(n_estimators=190, n_jobs = -1, random_state=0, max_depth=9, min_child_weight=0,
            colsample_bytree=colsamp/10.0, subsample=subsamp/10.0, scale_pos_weight = 76,gamma = .1,nthreads=-1) 
        
        test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)
        score_dict[(colsamp,subsamp)] = np.sum(aucprc_dict[classifier_method])/10.0
        print "score for params: {colsample_bytree: " + str(colsamp/10.0) + ", subsample:" + str(subsamp/10.0) + "}: " +  str(score_dict[(colsamp,subsamp)])
        #vals = score_dict[(colsamp,subsamp)]
        if(vals >  curr_best_score):
            curr_best_score = vals
            curr_best_colsamp = colsamp
            curr_best_subsamp = subsamp
            
print "Best AUPRC for params: {colsample_bytree: " + str(curr_best_colsamp/10.0) + ", subsample:" + str(curr_best_subsamp/10.0) + "}: " +  str(curr_best_score)
print "Finished ligand "+ligand
# Out:
# classifier_method = XGB_GS
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.1, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.8541557305336833
# AUPRC = 0.22813914440083952
# fold #: 2
# AUC = 0.8589133858267716
# AUPRC = 0.3101038882429761
# fold #: 3
# AUC = 0.8613648293963253
# AUPRC = 0.2799784848928295
# fold #: 4
# AUC = 0.8915538057742782
# AUPRC = 0.243618512709997
# fold #: 5
# AUC = 0.8582992125984251
# AUPRC = 0.27730883529421535
# fold #: 6
# AUC = 0.904368600682594
# AUPRC = 0.2588292602982561
# fold #: 7
# AUC = 0.8941296928327644
# AUPRC = 0.3212466031507529
# fold #: 8
# AUC = 0.9009766342872145
# AUPRC = 0.37253432788577856
# fold #: 9
# AUC = 0.880871619847729
# AUPRC = 0.3206164270415442
# fold #: 10
# AUC = 0.8495825676030454
# AUPRC = 0.27899736929213903
# avg auc = 0.875421607938283
# avg auprc = 0.28913728532093286
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.1}: 0.28913728532093286
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.2, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.918403581905203
# AUPRC = 0.379455525048215
# fold #: 2
# AUC = 0.9228293963254592
# AUPRC = 0.3829944125492098
# fold #: 3
# AUC = 0.8976377952755906
# AUPRC = 0.3332876278419229
# fold #: 4
# AUC = 0.9083674540682415
# AUPRC = 0.35051951024644246
# fold #: 5
# AUC = 0.9028451443569553
# AUPRC = 0.389618467049421
# fold #: 6
# AUC = 0.9304541874507745
# AUPRC = 0.3318409208976941
# fold #: 7
# AUC = 0.919438172748753
# AUPRC = 0.42760463183204156
# fold #: 8
# AUC = 0.9303386715673405
# AUPRC = 0.4851394410900262
# fold #: 9
# AUC = 0.9211131530585456
# AUPRC = 0.43173416515631247
# fold #: 10
# AUC = 0.873210816487267
# AUPRC = 0.3589210687580775
# avg auc = 0.9124638373244129
# avg auprc = 0.38711157704693633
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.2}: 0.38711157704693633
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.3, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9067057794246307
# AUPRC = 0.37527734909686744
# fold #: 2
# AUC = 0.933763779527559
# AUPRC = 0.42588689868577956
# fold #: 3
# AUC = 0.9253385826771654
# AUPRC = 0.42865677094011434
# fold #: 4
# AUC = 0.9216850393700788
# AUPRC = 0.3150634029404765
# fold #: 5
# AUC = 0.9099737532808398
# AUPRC = 0.3657930722594179
# fold #: 6
# AUC = 0.9361459700708847
# AUPRC = 0.37108405262166233
# fold #: 7
# AUC = 0.9503754266211604
# AUPRC = 0.4822434485022134
# fold #: 8
# AUC = 0.9674192701496457
# AUPRC = 0.5643221998066769
# fold #: 9
# AUC = 0.9213599369913363
# AUPRC = 0.37587625461488805
# fold #: 10
# AUC = 0.8838697820950381
# AUPRC = 0.4227097314193805
# avg auc = 0.925663732020834
# avg auprc = 0.41269131808874765
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.3}: 0.41269131808874765
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.4, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9196335752148627
# AUPRC = 0.3943951446894161
# fold #: 2
# AUC = 0.9516325459317585
# AUPRC = 0.45570112687930214
# fold #: 3
# AUC = 0.9268713910761156
# AUPRC = 0.410397647745732
# fold #: 4
# AUC = 0.9415853018372704
# AUPRC = 0.4649153231940098
# fold #: 5
# AUC = 0.9396272965879264
# AUPRC = 0.4601035525655419
# fold #: 6
# AUC = 0.9485271724862168
# AUPRC = 0.4072028448311382
# fold #: 7
# AUC = 0.958104489367288
# AUPRC = 0.5080674051010371
# fold #: 8
# AUC = 0.9690995011814124
# AUPRC = 0.5442422606596116
# fold #: 9
# AUC = 0.9610133893410344
# AUPRC = 0.45697817862321954
# fold #: 10
# AUC = 0.9070149645576266
# AUPRC = 0.4107509588498604
# avg auc = 0.9423109627581512
# avg auprc = 0.4512754443138868
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.4}: 0.4512754443138868
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.5, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9490401935052236
# AUPRC = 0.43082008102396424
# fold #: 2
# AUC = 0.9480997375328084
# AUPRC = 0.4847125748003835
# fold #: 3
# AUC = 0.9488293963254593
# AUPRC = 0.4734431058953126
# fold #: 4
# AUC = 0.9660314960629921
# AUPRC = 0.5092392679716111
# fold #: 5
# AUC = 0.9600472440944882
# AUPRC = 0.5122727142975595
# fold #: 6
# AUC = 0.9799107377264374
# AUPRC = 0.46925830524252315
# fold #: 7
# AUC = 0.9639747965345234
# AUPRC = 0.4870700131768645
# fold #: 8
# AUC = 0.9724442110790233
# AUPRC = 0.6296865012022378
# fold #: 9
# AUC = 0.960735101076398
# AUPRC = 0.5072203960063169
# fold #: 10
# AUC = 0.933289577316881
# AUPRC = 0.5036433177981275
# avg auc = 0.9582402491254236
# avg auprc = 0.5007366277414901
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.5}: 0.5007366277414901
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.6, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9475322937573979
# AUPRC = 0.45550218237263257
# fold #: 2
# AUC = 0.9510446194225721
# AUPRC = 0.4765567441345405
# fold #: 3
# AUC = 0.9634698162729658
# AUPRC = 0.4903429635523126
# fold #: 4
# AUC = 0.9720524934383201
# AUPRC = 0.5596457301235922
# fold #: 5
# AUC = 0.9583937007874015
# AUPRC = 0.5056276976554811
# fold #: 6
# AUC = 0.9750380677343135
# AUPRC = 0.47884518348866295
# fold #: 7
# AUC = 0.9631714360724599
# AUPRC = 0.4885283995931662
# fold #: 8
# AUC = 0.9788133368338147
# AUPRC = 0.613856513476708
# fold #: 9
# AUC = 0.9719243896035705
# AUPRC = 0.4731370254999444
# fold #: 10
# AUC = 0.9242425833552113
# AUPRC = 0.4965381384211759
# avg auc = 0.9605682737278027
# avg auprc = 0.5038580578318217
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.6}: 0.5038580578318217
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.7, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9594668313519633
# AUPRC = 0.47710887436189436
# fold #: 2
# AUC = 0.9652913385826771
# AUPRC = 0.5448100336895886
# fold #: 3
# AUC = 0.9540734908136483
# AUPRC = 0.5288339339365603
# fold #: 4
# AUC = 0.965758530183727
# AUPRC = 0.5335631242763351
# fold #: 5
# AUC = 0.9620839895013122
# AUPRC = 0.5428947776818083
# fold #: 6
# AUC = 0.9834077185613022
# AUPRC = 0.5216074100577164
# fold #: 7
# AUC = 0.9645156208978735
# AUPRC = 0.5338049186810955
# fold #: 8
# AUC = 0.9826148595431872
# AUPRC = 0.6599827012354672
# fold #: 9
# AUC = 0.9724074560252034
# AUPRC = 0.5114802333252921
# fold #: 10
# AUC = 0.9324389603570491
# AUPRC = 0.5614996685725898
# avg auc = 0.9642058795817944
# avg auprc = 0.5415585675818348
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.7}: 0.5415585675818348
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.8, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9620400391127579
# AUPRC = 0.5392840916291185
# fold #: 2
# AUC = 0.9709238845144357
# AUPRC = 0.5811927349254912
# fold #: 3
# AUC = 0.9699475065616798
# AUPRC = 0.5510875599972991
# fold #: 4
# AUC = 0.9711916010498687
# AUPRC = 0.5666706153395198
# fold #: 5
# AUC = 0.9705721784776903
# AUPRC = 0.5508114241397187
# fold #: 6
# AUC = 0.9825360987135732
# AUPRC = 0.5320061948363024
# fold #: 7
# AUC = 0.9697453399842478
# AUPRC = 0.5458704133564952
# fold #: 8
# AUC = 0.9821107902336571
# AUPRC = 0.6730348213257243
# fold #: 9
# AUC = 0.9836492517721187
# AUPRC = 0.5745883285277215
# fold #: 10
# AUC = 0.9316986085586767
# AUPRC = 0.5682675447191088
# avg auc = 0.9694415298978706
# avg auprc = 0.56828137287965
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.8}: 0.56828137287965
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.9, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.95437187998559
# AUPRC = 0.5313402756756468
# fold #: 2
# AUC = 0.9731496062992125
# AUPRC = 0.5680814954926541
# fold #: 3
# AUC = 0.9626561679790027
# AUPRC = 0.5590210488130892
# fold #: 4
# AUC = 0.977023622047244
# AUPRC = 0.586319756643531
# fold #: 5
# AUC = 0.9643569553805774
# AUPRC = 0.5571663452476436
# fold #: 6
# AUC = 0.984872669992124
# AUPRC = 0.5350886153930325
# fold #: 7
# AUC = 0.9751483328957731
# AUPRC = 0.5362741155564104
# fold #: 8
# AUC = 0.9823260698346022
# AUPRC = 0.6927974010179136
# fold #: 9
# AUC = 0.9759044368600682
# AUPRC = 0.5644789972630875
# fold #: 10
# AUC = 0.9492202677868207
# AUPRC = 0.5563842005797834
# avg auc = 0.9699030009061016
# avg auprc = 0.5686952251682792
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:0.9}: 0.5686952251682792
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.1, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 1.0, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9708455560701971
# AUPRC = 0.5301122234700726
# fold #: 2
# AUC = 0.9796640419947507
# AUPRC = 0.5966242169910763
# fold #: 3
# AUC = 0.967522309711286
# AUPRC = 0.5781556558774489
# fold #: 4
# AUC = 0.9751023622047245
# AUPRC = 0.6081550601053534
# fold #: 5
# AUC = 0.9750236220472441
# AUPRC = 0.5288574055707157
# fold #: 6
# AUC = 0.9867366762929903
# AUPRC = 0.558322057501224
# fold #: 7
# AUC = 0.9765397742189552
# AUPRC = 0.5450462772038578
# fold #: 8
# AUC = 0.9835494880546075
# AUPRC = 0.6620409627209816
# fold #: 9
# AUC = 0.9819217642425834
# AUPRC = 0.5965237825871749
# fold #: 10
# AUC = 0.94212654239958
# AUPRC = 0.5318035085047125
# avg auc = 0.9739032137236918
# avg auprc = 0.5735641150532618
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.1, subsample:1.0}: 0.5735641150532618
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.1, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.8509855385723843
# AUPRC = 0.2803844714121005
# fold #: 2
# AUC = 0.8574855643044619
# AUPRC = 0.26851766060115123
# fold #: 3
# AUC = 0.8485091863517061
# AUPRC = 0.27477259397706816
# fold #: 4
# AUC = 0.849763779527559
# AUPRC = 0.2406458671764864
# fold #: 5
# AUC = 0.857989501312336
# AUPRC = 0.25844383398110315
# fold #: 6
# AUC = 0.8664951430821738
# AUPRC = 0.22610000674137484
# fold #: 7
# AUC = 0.8790601207666053
# AUPRC = 0.3507099118072111
# fold #: 8
# AUC = 0.8903439222893148
# AUPRC = 0.339960320717165
# fold #: 9
# AUC = 0.8902441585718036
# AUPRC = 0.2772238376454584
# fold #: 10
# AUC = 0.8448884221580467
# AUPRC = 0.2715462037951228
# avg auc = 0.8635765336936393
# avg auprc = 0.27883047078542417
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.1}: 0.27883047078542417
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.2, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9072564458854407
# AUPRC = 0.32091295045458246
# fold #: 2
# AUC = 0.901002624671916
# AUPRC = 0.35248800517306184
# fold #: 3
# AUC = 0.8855853018372704
# AUPRC = 0.34383665176474904
# fold #: 4
# AUC = 0.8986246719160105
# AUPRC = 0.3604816112071941
# fold #: 5
# AUC = 0.8881627296587926
# AUPRC = 0.31169138921449535
# fold #: 6
# AUC = 0.9117563665003938
# AUPRC = 0.3444332355871834
# fold #: 7
# AUC = 0.922803885534261
# AUPRC = 0.4272315736256821
# fold #: 8
# AUC = 0.9408243633499606
# AUPRC = 0.5164160269747207
# fold #: 9
# AUC = 0.9080546075085325
# AUPRC = 0.34112031733259496
# fold #: 10
# AUC = 0.8944499868731951
# AUPRC = 0.4166425656524676
# avg auc = 0.9058520983735774
# avg auprc = 0.3735254326986731
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.2}: 0.3735254326986731
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.3, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9013586536976995
# AUPRC = 0.36818884584435563
# fold #: 2
# AUC = 0.9188451443569554
# AUPRC = 0.3739832965735134
# fold #: 3
# AUC = 0.9279317585301837
# AUPRC = 0.3998477348874868
# fold #: 4
# AUC = 0.9540367454068241
# AUPRC = 0.47691064323428306
# fold #: 5
# AUC = 0.9201154855643043
# AUPRC = 0.47875660052647834
# fold #: 6
# AUC = 0.9467156734050932
# AUPRC = 0.4075893148415992
# fold #: 7
# AUC = 0.9220530322919402
# AUPRC = 0.463156223026759
# fold #: 8
# AUC = 0.9471619847729064
# AUPRC = 0.5190049244792888
# fold #: 9
# AUC = 0.924662641113153
# AUPRC = 0.3799660381301314
# fold #: 10
# AUC = 0.8643580992386454
# AUPRC = 0.3780656063634387
# avg auc = 0.9227239218377704
# avg auprc = 0.42454692279073347
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.3}: 0.42454692279073347
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.4, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9331429159590345
# AUPRC = 0.4358518958764172
# fold #: 2
# AUC = 0.9461522309711285
# AUPRC = 0.44846448483148565
# fold #: 3
# AUC = 0.9290498687664042
# AUPRC = 0.4566337090703017
# fold #: 4
# AUC = 0.9396482939632544
# AUPRC = 0.4636754672255442
# fold #: 5
# AUC = 0.933727034120735
# AUPRC = 0.43931621098128915
# fold #: 6
# AUC = 0.9523444473615121
# AUPRC = 0.4740746844316953
# fold #: 7
# AUC = 0.9596744552375952
# AUPRC = 0.43531303872412047
# fold #: 8
# AUC = 0.9721921764242584
# AUPRC = 0.5704936491321135
# fold #: 9
# AUC = 0.9535258598057234
# AUPRC = 0.46630129495549816
# fold #: 10
# AUC = 0.9080808611184038
# AUPRC = 0.4824641048504419
# avg auc = 0.9427538143728048
# avg auprc = 0.4672588540078907
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.4}: 0.4672588540078907
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.5, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9424888065462406
# AUPRC = 0.4578892617035675
# fold #: 2
# AUC = 0.9422362204724409
# AUPRC = 0.47893732709339676
# fold #: 3
# AUC = 0.9338110236220473
# AUPRC = 0.47821375177002645
# fold #: 4
# AUC = 0.9757742782152232
# AUPRC = 0.5550335722227567
# fold #: 5
# AUC = 0.9460944881889765
# AUPRC = 0.4844223589966558
# fold #: 6
# AUC = 0.9647676555526384
# AUPRC = 0.4974415631809842
# fold #: 7
# AUC = 0.9645103701758991
# AUPRC = 0.5186858872175434
# fold #: 8
# AUC = 0.9778734576004201
# AUPRC = 0.6300938809579073
# fold #: 9
# AUC = 0.9570280913625623
# AUPRC = 0.4750821055305202
# fold #: 10
# AUC = 0.923344709897611
# AUPRC = 0.4924347863647087
# avg auc = 0.952792910163406
# avg auprc = 0.5068234495038066
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.5}: 0.5068234495038066
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.6, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9359785909114302
# AUPRC = 0.49471808365321457
# fold #: 2
# AUC = 0.9593385826771653
# AUPRC = 0.537292057136558
# fold #: 3
# AUC = 0.9518267716535433
# AUPRC = 0.4808491089997334
# fold #: 4
# AUC = 0.9711128608923885
# AUPRC = 0.5536733662083143
# fold #: 5
# AUC = 0.9624041994750656
# AUPRC = 0.4907840007144724
# fold #: 6
# AUC = 0.9774533998424784
# AUPRC = 0.4537511797259262
# fold #: 7
# AUC = 0.9512312943029666
# AUPRC = 0.4917443212859883
# fold #: 8
# AUC = 0.9851404568128118
# AUPRC = 0.6404570343529201
# fold #: 9
# AUC = 0.9683066421632973
# AUPRC = 0.5023349793726757
# fold #: 10
# AUC = 0.9160199527435021
# AUPRC = 0.4864873241213522
# avg auc = 0.9578812751474649
# avg auprc = 0.5132091455571156
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.6}: 0.5132091455571156
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.7, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9541866090268128
# AUPRC = 0.525937469594394
# fold #: 2
# AUC = 0.96101312335958
# AUPRC = 0.5427102903987869
# fold #: 3
# AUC = 0.949244094488189
# AUPRC = 0.531594359523079
# fold #: 4
# AUC = 0.9691181102362204
# AUPRC = 0.58447663987295
# fold #: 5
# AUC = 0.9692020997375328
# AUPRC = 0.525636986147473
# fold #: 6
# AUC = 0.9750118141244422
# AUPRC = 0.4644504769546102
# fold #: 7
# AUC = 0.9672932528222631
# AUPRC = 0.5547548953226735
# fold #: 8
# AUC = 0.9753636124967183
# AUPRC = 0.6398285653910242
# fold #: 9
# AUC = 0.9733840903124179
# AUPRC = 0.5260320529694849
# fold #: 10
# AUC = 0.9325754791283802
# AUPRC = 0.5054756547398338
# avg auc = 0.9626392285732557
# avg auprc = 0.540089739091431
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.7}: 0.540089739091431
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.8, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.963656013586537
# AUPRC = 0.5117192988345233
# fold #: 2
# AUC = 0.9676325459317585
# AUPRC = 0.5846019867801262
# fold #: 3
# AUC = 0.9606561679790027
# AUPRC = 0.5503425847157524
# fold #: 4
# AUC = 0.9749658792650919
# AUPRC = 0.600104786286324
# fold #: 5
# AUC = 0.9724199475065617
# AUPRC = 0.5497849546043252
# fold #: 6
# AUC = 0.985145707534786
# AUPRC = 0.5286894716702606
# fold #: 7
# AUC = 0.9679758466789185
# AUPRC = 0.5367633468821771
# fold #: 8
# AUC = 0.9814176949330533
# AUPRC = 0.690439594725593
# fold #: 9
# AUC = 0.9767760567077973
# AUPRC = 0.552451363001107
# fold #: 10
# AUC = 0.9467891835127329
# AUPRC = 0.5553793473499022
# avg auc = 0.969743504363624
# avg auprc = 0.566027673485009
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.8}: 0.566027673485009
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.9, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9567443775410427
# AUPRC = 0.5626140454301598
# fold #: 2
# AUC = 0.9665669291338582
# AUPRC = 0.5937517959265634
# fold #: 3
# AUC = 0.9621574803149607
# AUPRC = 0.5437905951956595
# fold #: 4
# AUC = 0.9729133858267717
# AUPRC = 0.6400879593416198
# fold #: 5
# AUC = 0.9763254593175854
# AUPRC = 0.5653174204302216
# fold #: 6
# AUC = 0.9861433447098976
# AUPRC = 0.5087535068230409
# fold #: 7
# AUC = 0.9799684956681544
# AUPRC = 0.5701964848132816
# fold #: 8
# AUC = 0.9835704909425046
# AUPRC = 0.7048430027046161
# fold #: 9
# AUC = 0.9878288264636387
# AUPRC = 0.5751063741572272
# fold #: 10
# AUC = 0.9426516145970071
# AUPRC = 0.5400702186185213
# avg auc = 0.9714870404515421
# avg auprc = 0.5804531403440911
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:0.9}: 0.5804531403440911
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.2, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 1.0, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9641912408007823
# AUPRC = 0.5495056486917419
# fold #: 2
# AUC = 0.9735380577427821
# AUPRC = 0.5802052831959399
# fold #: 3
# AUC = 0.976997375328084
# AUPRC = 0.5976381757372138
# fold #: 4
# AUC = 0.9772020997375328
# AUPRC = 0.64595313810209
# fold #: 5
# AUC = 0.976530183727034
# AUPRC = 0.5976224074109922
# fold #: 6
# AUC = 0.9858493042793385
# AUPRC = 0.5552070189936047
# fold #: 7
# AUC = 0.9743397217117353
# AUPRC = 0.5773654342507899
# fold #: 8
# AUC = 0.9835442373326332
# AUPRC = 0.7098603835831692
# fold #: 9
# AUC = 0.9823470727224994
# AUPRC = 0.5709165512150546
# fold #: 10
# AUC = 0.9525702284064059
# AUPRC = 0.5797139229653665
# avg auc = 0.9747109521788827
# avg auprc = 0.5963987964145963
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.2, subsample:1.0}: 0.5963987964145963
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.1, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.8516031084349751
# AUPRC = 0.2446363216330162
# fold #: 2
# AUC = 0.8816797900262467
# AUPRC = 0.2708495824239754
# fold #: 3
# AUC = 0.8718057742782152
# AUPRC = 0.31856712706499063
# fold #: 4
# AUC = 0.8713648293963255
# AUPRC = 0.3113447862336247
# fold #: 5
# AUC = 0.8857060367454068
# AUPRC = 0.3387736686537394
# fold #: 6
# AUC = 0.8694512995536887
# AUPRC = 0.26074956217097167
# fold #: 7
# AUC = 0.8897925964820163
# AUPRC = 0.3847493077658183
# fold #: 8
# AUC = 0.9163822525597269
# AUPRC = 0.40797305613940876
# fold #: 9
# AUC = 0.8805355736413757
# AUPRC = 0.3802830417021479
# fold #: 10
# AUC = 0.8544342347072723
# AUPRC = 0.3232060083713484
# avg auc = 0.877275549582525
# avg auprc = 0.3241132462159041
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.1}: 0.3241132462159041
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.2, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9116206062477484
# AUPRC = 0.32871782080939854
# fold #: 2
# AUC = 0.9153753280839896
# AUPRC = 0.39680248702325116
# fold #: 3
# AUC = 0.8918897637795276
# AUPRC = 0.3844919209770068
# fold #: 4
# AUC = 0.9256640419947506
# AUPRC = 0.3267265610418613
# fold #: 5
# AUC = 0.8946614173228347
# AUPRC = 0.3713938857930264
# fold #: 6
# AUC = 0.9248621685481753
# AUPRC = 0.31234555967852123
# fold #: 7
# AUC = 0.9363612496718299
# AUPRC = 0.5038237315281651
# fold #: 8
# AUC = 0.8946495143082174
# AUPRC = 0.45906890161438024
# fold #: 9
# AUC = 0.8872459963244946
# AUPRC = 0.3681962661952505
# fold #: 10
# AUC = 0.8751483328957732
# AUPRC = 0.31609309163786764
# avg auc = 0.9057478419177339
# avg auprc = 0.3767660226298729
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.2}: 0.3767660226298729
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.3, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9048942411610312
# AUPRC = 0.37710177023316904
# fold #: 2
# AUC = 0.9280997375328084
# AUPRC = 0.39981586184902157
# fold #: 3
# AUC = 0.9373280839895013
# AUPRC = 0.37511378910181714
# fold #: 4
# AUC = 0.9438188976377953
# AUPRC = 0.41667195659642126
# fold #: 5
# AUC = 0.9176535433070866
# AUPRC = 0.403401492581731
# fold #: 6
# AUC = 0.9225781044893673
# AUPRC = 0.3727941888804506
# fold #: 7
# AUC = 0.9248306642163298
# AUPRC = 0.46798943672770904
# fold #: 8
# AUC = 0.9598687319506432
# AUPRC = 0.5223082852768114
# fold #: 9
# AUC = 0.9219900236282489
# AUPRC = 0.33749091228513073
# fold #: 10
# AUC = 0.8933683381464952
# AUPRC = 0.4232237772335176
# avg auc = 0.9254430366059306
# avg auprc = 0.40959114707657795
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.3}: 0.40959114707657795
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.4, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9428953733724461
# AUPRC = 0.46221917544656754
# fold #: 2
# AUC = 0.9527769028871391
# AUPRC = 0.44437036342798003
# fold #: 3
# AUC = 0.9328398950131234
# AUPRC = 0.4707318166879604
# fold #: 4
# AUC = 0.945790026246719
# AUPRC = 0.4896136200110736
# fold #: 5
# AUC = 0.947753280839895
# AUPRC = 0.5017604520759014
# fold #: 6
# AUC = 0.9597007088474666
# AUPRC = 0.5015469134765147
# fold #: 7
# AUC = 0.9538251509582569
# AUPRC = 0.47948854147134395
# fold #: 8
# AUC = 0.9639432922026779
# AUPRC = 0.5746613087548538
# fold #: 9
# AUC = 0.9483854029929115
# AUPRC = 0.43798963034830557
# fold #: 10
# AUC = 0.8950905749540561
# AUPRC = 0.4237530143892797
# avg auc = 0.9443000608314691
# avg auprc = 0.4786134836089781
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.4}: 0.4786134836089781
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.5, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9364520611394164
# AUPRC = 0.45210228200067987
# fold #: 2
# AUC = 0.957265091863517
# AUPRC = 0.4787750441473513
# fold #: 3
# AUC = 0.9408451443569553
# AUPRC = 0.42220794448000587
# fold #: 4
# AUC = 0.964503937007874
# AUPRC = 0.508859173347956
# fold #: 5
# AUC = 0.9373858267716536
# AUPRC = 0.4994480179642813
# fold #: 6
# AUC = 0.9726437385140457
# AUPRC = 0.4934512190641045
# fold #: 7
# AUC = 0.9597899711210292
# AUPRC = 0.5260737956847568
# fold #: 8
# AUC = 0.9784352848516671
# AUPRC = 0.6325842661599252
# fold #: 9
# AUC = 0.961354686269362
# AUPRC = 0.45957619992925375
# fold #: 10
# AUC = 0.9173641375689157
# AUPRC = 0.48076635720268607
# avg auc = 0.9526039879464434
# avg auprc = 0.4953844299981001
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.5}: 0.4953844299981001
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.6, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.941305130976275
# AUPRC = 0.476193113285531
# fold #: 2
# AUC = 0.9622204724409449
# AUPRC = 0.4970906026527516
# fold #: 3
# AUC = 0.9480577427821523
# AUPRC = 0.5001960951449315
# fold #: 4
# AUC = 0.9736640419947507
# AUPRC = 0.5696933853957231
# fold #: 5
# AUC = 0.9525039370078741
# AUPRC = 0.5027528248007725
# fold #: 6
# AUC = 0.9725964820162771
# AUPRC = 0.4732987032725501
# fold #: 7
# AUC = 0.9535101076398004
# AUPRC = 0.4758173969949285
# fold #: 8
# AUC = 0.975258598057233
# AUPRC = 0.615022122499272
# fold #: 9
# AUC = 0.9541296928327645
# AUPRC = 0.44239980854738103
# fold #: 10
# AUC = 0.941023890784983
# AUPRC = 0.4904766260362894
# avg auc = 0.9574270096533055
# avg auprc = 0.5042940678630131
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.6}: 0.5042940678630131
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.7, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9631979826051155
# AUPRC = 0.5040434092221509
# fold #: 2
# AUC = 0.9702152230971129
# AUPRC = 0.5146228247367421
# fold #: 3
# AUC = 0.9657007874015748
# AUPRC = 0.5322213701584807
# fold #: 4
# AUC = 0.9755643044619423
# AUPRC = 0.5913768913278706
# fold #: 5
# AUC = 0.959501312335958
# AUPRC = 0.5681701919349933
# fold #: 6
# AUC = 0.9750328170123392
# AUPRC = 0.48056842962965557
# fold #: 7
# AUC = 0.9663848779207141
# AUPRC = 0.525121889560857
# fold #: 8
# AUC = 0.9847939091625098
# AUPRC = 0.6709743532192823
# fold #: 9
# AUC = 0.9697453399842478
# AUPRC = 0.5544434938398988
# fold #: 10
# AUC = 0.9351745865056444
# AUPRC = 0.5260509536708317
# avg auc = 0.9665311140487158
# avg auprc = 0.5467593807300763
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.7}: 0.5467593807300763
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.8, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9624671916010499
# AUPRC = 0.521930320812228
# fold #: 2
# AUC = 0.967784776902887
# AUPRC = 0.5365312667725864
# fold #: 3
# AUC = 0.9569291338582677
# AUPRC = 0.5364017138579583
# fold #: 4
# AUC = 0.9771391076115485
# AUPRC = 0.5997211003050439
# fold #: 5
# AUC = 0.9771128608923885
# AUPRC = 0.5895263291191297
# fold #: 6
# AUC = 0.9815909687582043
# AUPRC = 0.4902251419386235
# fold #: 7
# AUC = 0.9679023365712786
# AUPRC = 0.5402199064189418
# fold #: 8
# AUC = 0.9803255447624049
# AUPRC = 0.6446908506878607
# fold #: 9
# AUC = 0.9703544237332634
# AUPRC = 0.5511079541678289
# fold #: 10
# AUC = 0.9361039642950905
# AUPRC = 0.5105534899441962
# avg auc = 0.9677710308986385
# avg auprc = 0.5520908074024398
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.8}: 0.5520908074024398
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.9, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9603571612371984
# AUPRC = 0.5388256497546577
# fold #: 2
# AUC = 0.968278215223097
# AUPRC = 0.581388092159322
# fold #: 3
# AUC = 0.9627191601049868
# AUPRC = 0.556615976596784
# fold #: 4
# AUC = 0.9745931758530183
# AUPRC = 0.6541835446152995
# fold #: 5
# AUC = 0.9724409448818897
# AUPRC = 0.5667448599873522
# fold #: 6
# AUC = 0.9856917826201103
# AUPRC = 0.5155520165837372
# fold #: 7
# AUC = 0.9751378314518245
# AUPRC = 0.569423646617238
# fold #: 8
# AUC = 0.9870569703334209
# AUPRC = 0.6681849410536047
# fold #: 9
# AUC = 0.9807403517983723
# AUPRC = 0.5575364289992097
# fold #: 10
# AUC = 0.9533578367025466
# AUPRC = 0.5370530859934574
# avg auc = 0.9720373430206465
# avg auprc = 0.5745508242360663
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:0.9}: 0.5745508242360663
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.3, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 1.0, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9661674643610725
# AUPRC = 0.5624999827506652
# fold #: 2
# AUC = 0.9789396325459317
# AUPRC = 0.6064964623761374
# fold #: 3
# AUC = 0.9654383202099738
# AUPRC = 0.5683909347119706
# fold #: 4
# AUC = 0.9718740157480315
# AUPRC = 0.6668705404610736
# fold #: 5
# AUC = 0.969238845144357
# AUPRC = 0.5670947832179871
# fold #: 6
# AUC = 0.9833342084536625
# AUPRC = 0.5123337994941245
# fold #: 7
# AUC = 0.9743817274875295
# AUPRC = 0.5725450148470218
# fold #: 8
# AUC = 0.9846836440010502
# AUPRC = 0.6713350091673368
# fold #: 9
# AUC = 0.9880913625623524
# AUPRC = 0.6214250910053744
# fold #: 10
# AUC = 0.9528957731688108
# AUPRC = 0.5272158976943593
# avg auc = 0.9735044993682772
# avg auprc = 0.587620751572605
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.3, subsample:1.0}: 0.587620751572605
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.1, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.8759868251762647
# AUPRC = 0.28159240725261153
# fold #: 2
# AUC = 0.8639527559055118
# AUPRC = 0.24914001750984263
# fold #: 3
# AUC = 0.8410341207349082
# AUPRC = 0.26011500217776684
# fold #: 4
# AUC = 0.8361364829396325
# AUPRC = 0.27184633788607077
# fold #: 5
# AUC = 0.8558162729658793
# AUPRC = 0.2567805335284534
# fold #: 6
# AUC = 0.8697138356524022
# AUPRC = 0.3008790821837584
# fold #: 7
# AUC = 0.8796377001837753
# AUPRC = 0.3578934413458821
# fold #: 8
# AUC = 0.919805723286952
# AUPRC = 0.421018493289129
# fold #: 9
# AUC = 0.898220005250722
# AUPRC = 0.25704496088052853
# fold #: 10
# AUC = 0.8420582830139144
# AUPRC = 0.24041509664999633
# avg auc = 0.8682362005109964
# avg auprc = 0.289672537270404
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.1}: 0.289672537270404
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.2, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9090371056559107
# AUPRC = 0.3673300513298635
# fold #: 2
# AUC = 0.9096272965879264
# AUPRC = 0.33713150981213463
# fold #: 3
# AUC = 0.8871863517060368
# AUPRC = 0.32992544459705464
# fold #: 4
# AUC = 0.9052860892388452
# AUPRC = 0.29954004183681093
# fold #: 5
# AUC = 0.8919002624671916
# AUPRC = 0.2937392840561161
# fold #: 6
# AUC = 0.9251089524809661
# AUPRC = 0.34138039766863904
# fold #: 7
# AUC = 0.8971961144657391
# AUPRC = 0.4264288814818273
# fold #: 8
# AUC = 0.9411079023365713
# AUPRC = 0.45562262788798163
# fold #: 9
# AUC = 0.8932895773168811
# AUPRC = 0.35666343397812833
# fold #: 10
# AUC = 0.8796009451299553
# AUPRC = 0.33831060952526626
# avg auc = 0.9039340597386023
# avg auprc = 0.3546072282173822
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.2}: 0.3546072282173822
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.3, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9177088158097885
# AUPRC = 0.36453129445735644
# fold #: 2
# AUC = 0.9198477690288714
# AUPRC = 0.39644357343174963
# fold #: 3
# AUC = 0.9232020997375328
# AUPRC = 0.4376689951332359
# fold #: 4
# AUC = 0.9228766404199474
# AUPRC = 0.40926009567900024
# fold #: 5
# AUC = 0.8990498687664041
# AUPRC = 0.43147619076567023
# fold #: 6
# AUC = 0.9235809923864531
# AUPRC = 0.37585929021922765
# fold #: 7
# AUC = 0.939747965345235
# AUPRC = 0.48988353673042134
# fold #: 8
# AUC = 0.9574323969545813
# AUPRC = 0.539157414941357
# fold #: 9
# AUC = 0.9168810711472827
# AUPRC = 0.364834174578384
# fold #: 10
# AUC = 0.9040063008663691
# AUPRC = 0.41554766524620673
# avg auc = 0.9224333920462465
# avg auprc = 0.42246622311826093
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.3}: 0.42246622311826093
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.4, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.913643147547733
# AUPRC = 0.37650644199665756
# fold #: 2
# AUC = 0.9445721784776904
# AUPRC = 0.4463419085274286
# fold #: 3
# AUC = 0.9333753280839894
# AUPRC = 0.47778878091178834
# fold #: 4
# AUC = 0.9543359580052493
# AUPRC = 0.4564904195124292
# fold #: 5
# AUC = 0.9391811023622048
# AUPRC = 0.4708596212356165
# fold #: 6
# AUC = 0.9456445261223418
# AUPRC = 0.4376785354290652
# fold #: 7
# AUC = 0.9472775006563403
# AUPRC = 0.46580855081587724
# fold #: 8
# AUC = 0.9653347335258597
# AUPRC = 0.5727993523446215
# fold #: 9
# AUC = 0.9287529535311105
# AUPRC = 0.4599596092227981
# fold #: 10
# AUC = 0.9098503544237332
# AUPRC = 0.425703791113432
# avg auc = 0.9381967782736252
# avg auprc = 0.4589937011109714
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.4}: 0.4589937011109714
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.5, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9488909474550975
# AUPRC = 0.46933259914403064
# fold #: 2
# AUC = 0.9738687664041994
# AUPRC = 0.5137065644424788
# fold #: 3
# AUC = 0.9336640419947507
# AUPRC = 0.4689915009733943
# fold #: 4
# AUC = 0.9635328083989502
# AUPRC = 0.5508373474297558
# fold #: 5
# AUC = 0.9578372703412072
# AUPRC = 0.5458363556025163
# fold #: 6
# AUC = 0.9680178524547126
# AUPRC = 0.4874053972671052
# fold #: 7
# AUC = 0.9565397742189551
# AUPRC = 0.5079850699786739
# fold #: 8
# AUC = 0.9746967708059858
# AUPRC = 0.6177490697490476
# fold #: 9
# AUC = 0.9578682068784458
# AUPRC = 0.44805957646622346
# fold #: 10
# AUC = 0.9118666316618534
# AUPRC = 0.4577980610142945
# avg auc = 0.9546783070614158
# avg auprc = 0.506770154206752
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.5}: 0.506770154206752
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.6, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9435335288971232
# AUPRC = 0.474043044700624
# fold #: 2
# AUC = 0.9528556430446194
# AUPRC = 0.4642773695835527
# fold #: 3
# AUC = 0.9515433070866142
# AUPRC = 0.4923073082488544
# fold #: 4
# AUC = 0.9658897637795275
# AUPRC = 0.5810564761132199
# fold #: 5
# AUC = 0.9585564304461942
# AUPRC = 0.5306085004284433
# fold #: 6
# AUC = 0.9706169598319769
# AUPRC = 0.45935431593682985
# fold #: 7
# AUC = 0.9513625623523234
# AUPRC = 0.4959951841496134
# fold #: 8
# AUC = 0.979033867156734
# AUPRC = 0.6589598532640882
# fold #: 9
# AUC = 0.9637437647676557
# AUPRC = 0.5179901677764847
# fold #: 10
# AUC = 0.9284694145444999
# AUPRC = 0.4534048237003421
# avg auc = 0.9565605241907269
# avg auprc = 0.5127997043902053
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.6}: 0.5127997043902053
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.7, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9489629972723999
# AUPRC = 0.503929532350536
# fold #: 2
# AUC = 0.9615905511811024
# AUPRC = 0.5424338104227355
# fold #: 3
# AUC = 0.9498005249343832
# AUPRC = 0.5311170063096285
# fold #: 4
# AUC = 0.9754540682414699
# AUPRC = 0.6276463806726329
# fold #: 5
# AUC = 0.9589763779527559
# AUPRC = 0.5320123787268983
# fold #: 6
# AUC = 0.9793121554213704
# AUPRC = 0.4582503513943097
# fold #: 7
# AUC = 0.9630454187450774
# AUPRC = 0.5550787103945344
# fold #: 8
# AUC = 0.9823050669467053
# AUPRC = 0.6814245452291927
# fold #: 9
# AUC = 0.9695668154371226
# AUPRC = 0.5245991114925126
# fold #: 10
# AUC = 0.9437595169335784
# AUPRC = 0.5460060171267201
# avg auc = 0.9632773493065965
# avg auprc = 0.5502497844119699
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.7}: 0.5502497844119699
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.8, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9615305439761206
# AUPRC = 0.488999412114795
# fold #: 2
# AUC = 0.9676115485564304
# AUPRC = 0.5743853208694971
# fold #: 3
# AUC = 0.956010498687664
# AUPRC = 0.5477925576929485
# fold #: 4
# AUC = 0.9729448818897637
# AUPRC = 0.6109395061373748
# fold #: 5
# AUC = 0.9680892388451443
# AUPRC = 0.5748887775838221
# fold #: 6
# AUC = 0.9795221843003413
# AUPRC = 0.5013336424447505
# fold #: 7
# AUC = 0.9693252822263061
# AUPRC = 0.5383377601729932
# fold #: 8
# AUC = 0.9885744289839853
# AUPRC = 0.6872534534028943
# fold #: 9
# AUC = 0.9810343922289315
# AUPRC = 0.5372403617717902
# fold #: 10
# AUC = 0.9358414281963771
# AUPRC = 0.5173182517297173
# avg auc = 0.9680484427891065
# avg auprc = 0.5578489043920583
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.8}: 0.5578489043920583
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.9, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9670989655704801
# AUPRC = 0.5537296379777533
# fold #: 2
# AUC = 0.9745669291338582
# AUPRC = 0.5657989024329304
# fold #: 3
# AUC = 0.9676010498687664
# AUPRC = 0.556874750105905
# fold #: 4
# AUC = 0.9778792650918635
# AUPRC = 0.6646283647506944
# fold #: 5
# AUC = 0.978734908136483
# AUPRC = 0.5867117949474602
# fold #: 6
# AUC = 0.9835337358886846
# AUPRC = 0.5145095098435698
# fold #: 7
# AUC = 0.9751798372276188
# AUPRC = 0.553998781287712
# fold #: 8
# AUC = 0.9871094775531636
# AUPRC = 0.690641015683218
# fold #: 9
# AUC = 0.9800157521659227
# AUPRC = 0.5814684789281325
# fold #: 10
# AUC = 0.9430821737988972
# AUPRC = 0.5438270183757626
# avg auc = 0.9734802094435739
# avg auprc = 0.5812188254333138
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:0.9}: 0.5812188254333138
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.4, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 1.0, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# AUC = 0.9709381915495857
# AUPRC = 0.5402868757096878
# fold #: 2
# AUC = 0.9640000000000001
# AUPRC = 0.5727920807596808
# fold #: 3
# AUC = 0.9578162729658792
# AUPRC = 0.5555555487401557
# fold #: 4
# AUC = 0.9698950131233596
# AUPRC = 0.6383046128209016
# fold #: 5
# AUC = 0.9731811023622047
# AUPRC = 0.55215246279001
# fold #: 6
# AUC = 0.9832396954581255
# AUPRC = 0.5400087079107014
# fold #: 7
# AUC = 0.9765292727750066
# AUPRC = 0.5807069056274977
# fold #: 8
# AUC = 0.9806720924127067
# AUPRC = 0.702899937596084
# fold #: 9
# AUC = 0.9844893672880022
# AUPRC = 0.5854355636689881
# fold #: 10
# AUC = 0.9471042268311893
# AUPRC = 0.5636367641682325
# avg auc = 0.9707865234766061
# avg auprc = 0.583177945979194
# Finished dna XGB_GS
# score for params: {colsample_bytree: 0.4, subsample:1.0}: 0.583177945979194
# classifier_method = XGB_GS
# ligand = dna
# {'reg_alpha': 0, 'nthreads': -1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'seed': 0, 'booster': 'gbtree', 'colsample_bytree': 0.5, 'silent': 1, 'missing': None, 'min_child_weight': 0, 'subsample': 0.1, 'reg_lambda': 1, 'objective': 'binary:logistic', 'max_depth': 9, 'gamma': 0.1}
# fold #: 1
# ...
# GATA_26                          5.504415                 3.634243
# GTP_EFTU_D2_62                   4.925844                 3.634751
# HLH_14                           4.520608                 3.423765
# HMG_box_5                        4.827124                 3.476630
# HMG_box_51                       4.827124                 3.476630
# HMG_box_69                       4.827124                 3.476630
# HSF_DNA-bind_57                  2.482234                 3.207164
# Histone_117                      4.341777                 3.652280
# Histone_57                       4.341777                 3.652280
# Histone_66                       4.341777                 3.652280
# Histone_86                       4.341777                 3.652280
# Homeobox_47                      4.561819                 3.710223
# Homeobox_52                      4.561819                 3.710223
# Homeobox_54                      4.561819                 3.710223
# Homeobox_56                      4.561819                 3.710223
# KH_1_26                          5.070466                 3.619836
# KH_1_43                          5.070466                 3.619836
# MH1_72                           5.561837                 3.553087
# Metallophos_132                  4.563237                 3.621348
# Metallophos_78                   4.563237                 3.621348
# ...                                   ...                      ...
# zf-AN1_5                         4.338725                 3.249095
# zf-B_box_10                      2.435417                 3.290288
# zf-B_box_15                      2.435417                 3.290288
# zf-B_box_19                      2.435417                 3.290288
# zf-B_box_20                      2.435417                 3.290288
# zf-B_box_21                      2.435417                 3.290288
# zf-B_box_23                      2.435417                 3.290288
# zf-B_box_26                      2.435417                 3.290288
# zf-B_box_35                      2.435417                 3.290288
# zf-B_box_4                       2.435417                 3.290288
# zf-B_box_6                       2.435417                 3.290288
# zf-C4_30                         5.521789                 3.587656
# zf-C4_43                         5.521789                 3.587656
# zf-C4_44                         5.521789                 3.587656
# zf-C4_45                         5.521789                 3.587656
# zf-C4_46                         5.521789                 3.587656
# zf-C4_5                          5.521789                 3.587656
# zf-C4_63                         5.521789                 3.587656
# zf-C4_66                         5.521789                 3.587656
# zf-CCCH_2                        4.655067                 3.326979
# zf-CCCH_23                       4.655067                 3.326979
# zf-CCHC_10                       4.849147                 3.184487
# zf-CCHC_7                        4.849147                 3.184487
# zf-CCHC_9                        4.849147                 3.184487
# zf-CXXC_11                       4.555677                 3.390207
# zf-CXXC_31                       4.555677                 3.390207
# zf-CXXC_43                       4.555677                 3.390207
# zf-RING_2_20                     4.098144                 3.530717
# zf-RING_2_27                     4.098144                 3.530717
# zf-RING_2_7                      4.098144                 3.530717
#
#                   GO:NO_TERM  GO:NUCLEIC_ACID_BINDING  GO:PROTEIN_BINDING  \
# Ank_2_57                   0                        0                   1
# BEN_30                     1                        0                   0
# BEN_74                     1                        0                   0
# CSD_7                      0                        1                   0
# Ets_49                     0                        1                   0
# Ets_50                     0                        1                   0
# Exo_endo_phos_66           1                        0                   0
# Forkhead_51                0                        1                   0
# Forkhead_70                0                        1                   0
# GATA_14                    0                        1                   0
# GATA_26                    0                        1                   0
# GTP_EFTU_D2_62             0                        1                   0
# HLH_14                     0                        0                   1
# HMG_box_5                  1                        0                   0
# HMG_box_51                 1                        0                   0
# HMG_box_69                 1                        0                   0
# HSF_DNA-bind_57            0                        1                   0
# Histone_117                0                        1                   0
# Histone_57                 0                        1                   0
# Histone_66                 0                        1                   0
# Histone_86                 0                        1                   0
# Homeobox_47                0                        1                   0
# Homeobox_52                0                        1                   0
# Homeobox_54                0                        1                   0
# Homeobox_56                0                        1                   0
# KH_1_26                    0                        1                   0
# KH_1_43                    0                        1                   0
# MH1_72                     0                        0                   0
# Metallophos_132            1                        0                   0
# Metallophos_78             1                        0                   0
# ...                      ...                      ...                 ...
# zf-AN1_5                   0                        0                   0
# zf-B_box_10                0                        0                   0
# zf-B_box_15                0                        0                   0
# zf-B_box_19                0                        0                   0
# zf-B_box_20                0                        0                   0
# zf-B_box_21                0                        0                   0
# zf-B_box_23                0                        0                   0
# zf-B_box_26                0                        0                   0
# zf-B_box_35                0                        0                   0
# zf-B_box_4                 0                        0                   0
# zf-B_box_6                 0                        0                   0
# zf-C4_30                   0                        1                   0
# zf-C4_43                   0                        1                   0
# zf-C4_44                   0                        1                   0
# zf-C4_45                   0                        1                   0
# zf-C4_46                   0                        1                   0
# zf-C4_5                    0                        1                   0
# zf-C4_63                   0                        1                   0
# zf-C4_66                   0                        1                   0
# zf-CCCH_2                  0                        0                   0
# zf-CCCH_23                 0                        0                   0
# zf-CCHC_10                 0                        1                   0
# zf-CCHC_7                  0                        1                   0
# zf-CCHC_9                  0                        1                   0
# zf-CXXC_11                 0                        1                   0
# zf-CXXC_31                 0                        1                   0
# zf-CXXC_43                 0                        1                   0
# zf-RING_2_20               0                        0                   1
# zf-RING_2_27               0                        0                   1
# zf-RING_2_7                0                        0                   1
#
#                   GO:METAL_ION_BINDING  GO:MEMBRANE  GO:INTRACELLULAR  \
# Ank_2_57                             0            0                 0
# BEN_30                               0            0                 0
# BEN_74                               0            0                 0
# CSD_7                                0            0                 0
# Ets_49                               0            0                 0
# Ets_50                               0            0                 0
# Exo_endo_phos_66                     0            0                 0
# Forkhead_51                          0            0                 0
# Forkhead_70                          0            0                 0
# GATA_14                              1            0                 0
# GATA_26                              1            0                 0
# GTP_EFTU_D2_62                       0            0                 0
# HLH_14                               0            0                 0
# HMG_box_5                            0            0                 0
# HMG_box_51                           0            0                 0
# HMG_box_69                           0            0                 0
# HSF_DNA-bind_57                      0            0                 1
# Histone_117                          0            0                 0
# Histone_57                           0            0                 0
# Histone_66                           0            0                 0
# Histone_86                           0            0                 0
# Homeobox_47                          0            0                 0
# Homeobox_52                          0            0                 0
# Homeobox_54                          0            0                 0
# Homeobox_56                          0            0                 0
# KH_1_26                              0            0                 0
# KH_1_43                              0            0                 0
# MH1_72                               0            0                 1
# Metallophos_132                      0            0                 0
# Metallophos_78                       0            0                 0
# ...                                ...          ...               ...
# zf-AN1_5                             1            0                 0
# zf-B_box_10                          1            0                 1
# zf-B_box_15                          1            0                 1
# zf-B_box_19                          1            0                 1
# zf-B_box_20                          1            0                 1
# zf-B_box_21                          1            0                 1
# zf-B_box_23                          1            0                 1
# zf-B_box_26                          1            0                 1
# zf-B_box_35                          1            0                 1
# zf-B_box_4                           1            0                 1
# zf-B_box_6                           1            0                 1
# zf-C4_30                             1            0                 1
# zf-C4_43                             1            0                 1
# zf-C4_44                             1            0                 1
# zf-C4_45                             1            0                 1
# zf-C4_46                             1            0                 1
# zf-C4_5                              1            0                 1
# zf-C4_63                             1            0                 1
# zf-C4_66                             1            0                 1
# zf-CCCH_2                            1            0                 0
# zf-CCCH_23                           1            0                 0
# zf-CCHC_10                           1            0                 0
# zf-CCHC_7                            1            0                 0
# zf-CCHC_9                            1            0                 0
# zf-CXXC_11                           1            0                 0
# zf-CXXC_31                           1            0                 0
# zf-CXXC_43                           1            0                 0
# zf-RING_2_20                         1            0                 0
# zf-RING_2_27                         1            0                 0
# zf-RING_2_7                          1            0                 0
#
#                   GO:SIGNAL_TRANSDUCTION
# Ank_2_57                               0
# BEN_30                                 0
# BEN_74                                 0
# CSD_7                                  0
# Ets_49                                 0
# Ets_50                                 0
# Exo_endo_phos_66                       0
# Forkhead_51                            0
# Forkhead_70                            0
# GATA_14                                0
# GATA_26                                0
# GTP_EFTU_D2_62                         0
# HLH_14                                 0
# HMG_box_5                              0
# HMG_box_51                             0
# HMG_box_69                             0
# HSF_DNA-bind_57                        0
# Histone_117                            0
# Histone_57                             0
# Histone_66                             0
# Histone_86                             0
# Homeobox_47                            0
# Homeobox_52                            0
# Homeobox_54                            0
# Homeobox_56                            0
# KH_1_26                                0
# KH_1_43                                0
# MH1_72                                 0
# Metallophos_132                        0
# Metallophos_78                         0
# ...                                  ...
# zf-AN1_5                               0
# zf-B_box_10                            0
# zf-B_box_15                            0
# zf-B_box_19                            0
# zf-B_box_20                            0
# zf-B_box_21                            0
# zf-B_box_23                            0
# zf-B_box_26                            0
# zf-B_box_35                            0
# zf-B_box_4                             0
# zf-B_box_6                             0
# zf-C4_30                               0
# zf-C4_43                               0
# zf-C4_44                               0
# zf-C4_45                               0
# zf-C4_46                               0
# zf-C4_5                                0
# zf-C4_63                               0
# zf-C4_66                               0
# zf-CCCH_2                              0
# zf-CCCH_23                             0
# zf-CCHC_10                             0
# zf-CCHC_7                              0
# zf-CCHC_9                              0
# zf-CXXC_11                             0
# zf-CXXC_31                             0
# zf-CXXC_43                             0
# zf-RING_2_20                           0
# zf-RING_2_27                           0
# zf-RING_2_7                            0
#
# [38596 rows x 397 columns], 'XGB': None, 'XGBUntuned4Dna': None, 'XGBSPWSampling1': None, 'XGBSPW=76Tuned2': None, 'XGBSPWSampling2': None, 'XGBSPW=76': None, 'RF': None, 'ADA-RF': None, 'XGBTuned1': None, 'Logistic': None, 'XGBTuned3': None, 'XGB1': None, 'XGB0': None, 'XGBTuned2': None, 'XGBSPW=76Tuned': None}
# Finished ligand dna
# CPU times: user 4d 7h 36min 16s, sys: 37min 33s, total: 4d 8h 13min 50s
# Wall time: 3h 17min 36s

# %%
print "score for params: {colsample_bytree: " + str(colsamp/1.0) + ", subsample:" + str(subsamp/1.0) + "}: " +  str(score_dict[(colsamp,subsamp)])
# Out:
# score for params: {colsample_bytree: 1.0, subsample:1.0}: (0.9710241305303919, 0.5675739900382796)

# %%
score_dict
# Out:
# defaultdict(list,
#             {(1, 1): 0.28913728532093286,
#              (1, 2): 0.38711157704693633,
#              (1, 3): 0.41269131808874765,
#              (1, 4): 0.4512754443138868,
#              (1, 5): 0.5007366277414901,
#              (1, 6): 0.5038580578318217,
#              (1, 7): 0.5415585675818348,
#              (1, 8): 0.56828137287965,
#              (1, 9): 0.5686952251682792,
#              (1, 10): 0.5735641150532618,
#              (2, 1): 0.27883047078542417,
#              (2, 2): 0.3735254326986731,
#              (2, 3): 0.42454692279073347,
#              (2, 4): 0.4672588540078907,
#              (2, 5): 0.5068234495038066,
#              (2, 6): 0.5132091455571156,
#              (2, 7): 0.540089739091431,
#              (2, 8): 0.566027673485009,
#              (2, 9): 0.5804531403440911,
#              (2, 10): 0.5963987964145963,
#              (3, 1): 0.3241132462159041,
#              (3, 2): 0.3767660226298729,
#              (3, 3): 0.40959114707657795,
#              (3, 4): 0.4786134836089781,
#              (3, 5): 0.4953844299981001,
#              (3, 6): 0.5042940678630131,
#              (3, 7): 0.5467593807300763,
#              (3, 8): 0.5520908074024398,
#              (3, 9): 0.5745508242360663,
#              (3, 10): 0.587620751572605,
#              (4, 1): 0.289672537270404,
#              (4, 2): 0.3546072282173822,
#              (4, 3): 0.42246622311826093,
#              (4, 4): 0.4589937011109714,
#              (4, 5): 0.506770154206752,
#              (4, 6): 0.5127997043902053,
#              (4, 7): 0.5502497844119699,
#              (4, 8): 0.5578489043920583,
#              (4, 9): 0.5812188254333138,
#              (4, 10): 0.583177945979194,
#              (5, 1): 0.31555711928569313,
#              (5, 2): 0.37569083911864665,
#              (5, 3): 0.4133929983203487,
#              (5, 4): 0.470031702014288,
#              (5, 5): 0.5064560312457802,
#              (5, 6): 0.5245791813475195,
#              (5, 7): 0.5511686569508827,
#              (5, 8): 0.5571344693309044,
#              (5, 9): 0.5729518247625115,
#              (5, 10): 0.5886799012189353,
#              (6, 1): 0.31073106568606434,
#              (6, 2): 0.3531074782174064,
#              (6, 3): 0.41204844208196434,
#              (6, 4): 0.46826380780816174,
#              (6, 5): 0.5036271201124908,
#              (6, 6): 0.5227902134885428,
#              (6, 7): 0.5538594446621584,
#              (6, 8): 0.5647452542882165,
#              (6, 9): 0.5770113234209517,
#              (6, 10): 0.5822010249935055,
#              (7, 1): 0.2924029396182,
#              (7, 2): 0.3551629121521002,
#              (7, 3): 0.4111227964436798,
#              (7, 4): 0.45755564578801955,
#              (7, 5): 0.5096363892250403,
#              (7, 6): 0.5336874657278036,
#              (7, 7): 0.535951891116689,
#              (7, 8): 0.5776976780594161,
#              (7, 9): 0.578947684213296,
#              (7, 10): 0.5818719721335033,
#              (8, 1): 0.3112291893977749,
#              (8, 2): 0.3575164282455618,
#              (8, 3): 0.42465339148436865,
#              (8, 4): 0.4595639394566941,
#              (8, 5): 0.5037145296347162,
#              (8, 6): 0.5361728137967308,
#              (8, 7): 0.5493880277925693,
#              (8, 8): 0.5682021397861681,
#              (8, 9): 0.5668388643767661,
#              (8, 10): 0.5805223412595818,
#              (9, 1): 0.3194603988217898,
#              (9, 2): 0.35050310498364723,
#              (9, 3): 0.4094362719978095,
#              (9, 4): 0.4850432649532941,
#              (9, 5): 0.5027382446295936,
#              (9, 6): 0.5368765094549431,
#              (9, 7): 0.5543517779391081,
#              (9, 8): 0.574729738696283,
#              (9, 9): 0.5688085120967805,
#              (9, 10): 0.5715458408359779,
#              (10, 1): 0.31012930482930157,
#              (10, 2): 0.3571796666718112,
#              (10, 3): 0.41645146886465667,
#              (10, 4): 0.4537863562820307,
#              (10, 5): 0.5023153555514808,
#              (10, 6): 0.5325246681326966,
#              (10, 7): 0.5383154220015225,
#              (10, 8): 0.5544986754351483,
#              (10, 9): 0.5782038590153881,
#              (10, 10): 0.5675739900382796})

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3"
ligand = "dna"

print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3
# classifier_method = XGBSPWSampling3
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9641912408007823
# AUPRC = 0.5495056486917419
# fold #: 2
# AUC = 0.9735380577427821
# AUPRC = 0.5802052831959399
# fold #: 3
# AUC = 0.976997375328084
# AUPRC = 0.5976381757372138
# fold #: 4
# AUC = 0.9772020997375328
# AUPRC = 0.64595313810209
# fold #: 5
# AUC = 0.976530183727034
# AUPRC = 0.5976224074109922
# fold #: 6
# AUC = 0.9858493042793385
# AUPRC = 0.5552070189936047
# fold #: 7
# AUC = 0.9743397217117353
# AUPRC = 0.5773654342507899
# fold #: 8
# AUC = 0.9835442373326332
# AUPRC = 0.7098603835831692
# fold #: 9
# AUC = 0.9823470727224994
# AUPRC = 0.5709165512150546
# fold #: 10
# AUC = 0.9525702284064059
# AUPRC = 0.5797139229653665
# avg auc = 0.9747109521788827
# avg auprc = 0.5963987964145963
# Finished dna XGBSPWSampling3
# Finished ligand dna
# CPU times: user 38min 39s, sys: 18.2 s, total: 38min 57s
# Wall time: 1min 19s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGB"
ligand = "rna"
print "classifier_method = "+classifier_method
ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGB
# classifier_method = XGB
# ligand = rna
# {'reg_alpha': 0, 'colsample_bytree': 0.5, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 1, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 1000, 'subsample': 1, 'reg_lambda': 1, 'min_child_weight': 0.05, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 6, 'gamma': 0, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9674710309401505
# AUPRC = 0.37065195495809733
# fold #: 2
# AUC = 0.9884004300561463
# AUPRC = 0.5270838474011739
# fold #: 3
# AUC = 0.9764723450005973
# AUPRC = 0.3704730456450048
# fold #: 4
# AUC = 0.9871038718943862
# AUPRC = 0.5243851273258894
# fold #: 5
# AUC = 0.985838706720044
# AUPRC = 0.576322521721664
# fold #: 6
# AUC = 0.9876906151636464
# AUPRC = 0.4554248661110003
# fold #: 7
# AUC = 0.9820370992879626
# AUPRC = 0.5007883753699155
# fold #: 8
# AUC = 0.9766952779204264
# AUPRC = 0.5279426825365796
# fold #: 9
# AUC = 0.9752524882009146
# AUPRC = 0.3973184840738373
# fold #: 10
# AUC = 0.9806874037121268
# AUPRC = 0.5131144185044093
# avg auc = 0.98076492688964
# avg auprc = 0.4763505323647572
# Finished rna XGB
# Finished ligand rna
# CPU times: user 3h 32min 21s, sys: 1min 5s, total: 3h 33min 27s
# Wall time: 6min 12s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3"
ligand = "rna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3
# 87
# classifier_method = XGBSPWSampling3
# ligand = rna
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 87, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 190, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9777445944331622
# AUPRC = 0.39465288835868295
# fold #: 2
# AUC = 0.9870206665870266
# AUPRC = 0.5569483817001637
# fold #: 3
# AUC = 0.9742742802532552
# AUPRC = 0.41762431912174747
# fold #: 4
# AUC = 0.9873605720746875
# AUPRC = 0.5126390199135636
# fold #: 5
# AUC = 0.9904287504201937
# AUPRC = 0.635105143310217
# fold #: 6
# AUC = 0.9878617486171806
# AUPRC = 0.4767376760565716
# fold #: 7
# AUC = 0.9839623506402225
# AUPRC = 0.5053377593631626
# fold #: 8
# AUC = 0.9780891595138532
# AUPRC = 0.4328572122046081
# fold #: 9
# AUC = 0.9796114249382535
# AUPRC = 0.3927251066744631
# fold #: 10
# AUC = 0.9852725405326095
# AUPRC = 0.5309610904595625
# avg auc = 0.9831626088010446
# avg auprc = 0.4855588597162743
# Finished rna XGBSPWSampling3
# Finished ligand rna
# CPU times: user 36min 22s, sys: 17.1 s, total: 36min 39s
# Wall time: 1min 16s

# %%
print "hello"
# Out:
# hello

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3Slow"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3Slow
# 76
# classifier_method = XGBSPWSampling3Slow
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9648191034944161
# AUPRC = 0.5430409037548003
# fold #: 2
# AUC = 0.9745144356955381
# AUPRC = 0.5811160705648373
# fold #: 3
# AUC = 0.9770971128608924
# AUPRC = 0.5993087923337878
# fold #: 4
# AUC = 0.9757217847769029
# AUPRC = 0.6442016610954655
# fold #: 5
# AUC = 0.9763464566929134
# AUPRC = 0.6075330543043458
# fold #: 6
# AUC = 0.9855605145707536
# AUPRC = 0.5548762068469886
# fold #: 7
# AUC = 0.9716933578367025
# AUPRC = 0.5732954436782262
# fold #: 8
# AUC = 0.9839380414807037
# AUPRC = 0.71140851158771
# fold #: 9
# AUC = 0.9840063008663691
# AUPRC = 0.5766811452188603
# fold #: 10
# AUC = 0.9526857442898399
# AUPRC = 0.5776045567411082
# avg auc = 0.9746382852565031
# avg auprc = 0.596906634612613
# Finished dna XGBSPWSampling3Slow
# Finished ligand dna
# CPU times: user 45min 32s, sys: 21.6 s, total: 45min 53s
# Wall time: 1min 32s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3EarlyStoppingTest"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3EarlyStopping50
# 76
# classifier_method = XGBSPWSampling3EarlyStopping50
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# early stopping: 50
# 45
# AUC = 0.962755390870259
# AUPRC = 0.48891433922885175
# fold #: 2
# early stopping: 50
# 22
# AUC = 0.9588398950131234
# AUPRC = 0.45201346897229894
# fold #: 3
# early stopping: 50
# 39
# AUC = 0.9768766404199475
# AUPRC = 0.5447950482861221
# fold #: 4
# early stopping: 50
# 41
# AUC = 0.9712755905511811
# AUPRC = 0.52539109554099
# fold #: 5
# early stopping: 50
# 63
# AUC = 0.9749501312335958
# AUPRC = 0.564253959181467
# fold #: 6
# early stopping: 50
# 30
# AUC = 0.9733210816487268
# AUPRC = 0.4579439700663
# fold #: 7
# early stopping: 50
# 47
# AUC = 0.9812496718298765
# AUPRC = 0.5221045095347033
# fold #: 8
# early stopping: 50
# 42
# AUC = 0.9801995274350224
# AUPRC = 0.7004881530503824
# fold #: 9
# early stopping: 50
# 41
# AUC = 0.9748595431871881
# AUPRC = 0.49473089959022487
# fold #: 10
# early stopping: 50
# 33
# AUC = 0.9522341822000524
# AUPRC = 0.5071801210222838
# avg auc = 0.9706561654388974
# avg auprc = 0.5257815564473625
# Finished dna XGBSPWSampling3EarlyStopping50
# Finished ligand dna
# CPU times: user 57min 53s, sys: 25.5 s, total: 58min 19s
# Wall time: 1min 59s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3EarlyStoppingTest"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# 76
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# early stopping: 75
# 57
# AUC = 0.9635788173537132
# AUPRC = 0.5022308253112271
# fold #: 2
# early stopping: 75
# 46
# AUC = 0.9708556430446194
# AUPRC = 0.5242439766193314
# fold #: 3
# early stopping: 75
# 26
# AUC = 0.9548818897637795
# AUPRC = 0.4888105737643177
# fold #: 4
# early stopping: 75
# 36
# AUC = 0.968262467191601
# AUPRC = 0.49046744363371003
# fold #: 5
# early stopping: 75
# 45
# AUC = 0.9675748031496064
# AUPRC = 0.5672222358603679
# fold #: 6
# early stopping: 75
# 33
# AUC = 0.9747702809136256
# AUPRC = 0.447981780971057
# fold #: 7
# early stopping: 75
# 36
# AUC = 0.9783250196902075
# AUPRC = 0.4896659946828288
# fold #: 8
# early stopping: 75
# 55
# AUC = 0.9830296665791547
# AUPRC = 0.7170443408518745
# fold #: 9
# early stopping: 75
# 61
# AUC = 0.9786033079548437
# AUPRC = 0.5290655353336373
# fold #: 10
# early stopping: 75
# 68
# AUC = 0.956072459963245
# AUPRC = 0.5736003086921002
# avg auc = 0.9695954355604396
# avg auprc = 0.5330333015720452
# Finished dna XGBSPWSampling3EarlyStoppingTest
# Finished ligand dna
# CPU times: user 1h 4min 34s, sys: 27.7 s, total: 1h 5min 1s
# Wall time: 2min 11s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3EarlyStoppingTest"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# 76
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# ligand = dna
# early stopping: 100
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# 36
# AUC = 0.9621429674231897
# AUPRC = 0.46702143089068676
# fold #: 2
# 38
# AUC = 0.9699107611548556
# AUPRC = 0.5150855892606926
# fold #: 3
# 50
# AUC = 0.9777900262467192
# AUPRC = 0.5692666430111766
# fold #: 4
# 49
# AUC = 0.9749606299212599
# AUPRC = 0.5536494321129208
# fold #: 5
# 27
# AUC = 0.9620367454068242
# AUPRC = 0.5137297679015996
# fold #: 6
# 51
# AUC = 0.979070622210554
# AUPRC = 0.47125265831575286
# fold #: 7
# 60
# AUC = 0.982803885534261
# AUPRC = 0.560836141484673
# fold #: 8
# 41
# AUC = 0.9796114465739039
# AUPRC = 0.6951925726873712
# fold #: 9
# 33
# AUC = 0.9712470464688895
# AUPRC = 0.47361787121200793
# fold #: 10
# 54
# AUC = 0.9506379627198741
# AUPRC = 0.5503528426073413
# avg auc = 0.9710212093660331
# avg auprc = 0.5370004949484224
# Finished dna XGBSPWSampling3EarlyStoppingTest
# Finished ligand dna
# CPU times: user 3h 32min 40s, sys: 1min 11s, total: 3h 33min 52s
# Wall time: 14min 43s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3EarlyStoppingTest"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# 76
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# ligand = dna
# early stopping: 10
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# 43
# AUC = 0.9638721630384437
# AUPRC = 0.480577774543267
# fold #: 2
# 24
# AUC = 0.9630341207349081
# AUPRC = 0.466263271760524
# fold #: 3
# 43
# AUC = 0.9771548556430446
# AUPRC = 0.5618093410764109
# fold #: 4
# 35
# AUC = 0.9694540682414698
# AUPRC = 0.49522248484045206
# fold #: 5
# 33
# AUC = 0.9633490813648293
# AUPRC = 0.5524133175027547
# fold #: 6
# 62
# AUC = 0.9822893147807823
# AUPRC = 0.4827980302128536
# fold #: 7
# 24
# AUC = 0.9717301128905225
# AUPRC = 0.45470745095755194
# fold #: 8
# 30
# AUC = 0.9804200577579416
# AUPRC = 0.6730276220448067
# fold #: 9
# 33
# AUC = 0.9712470464688895
# AUPRC = 0.47361787121200793
# fold #: 10
# 38
# AUC = 0.9453452349698084
# AUPRC = 0.5051587628901789
# avg auc = 0.968789605589064
# avg auprc = 0.5145595927040809
# Finished dna XGBSPWSampling3EarlyStoppingTest
# Finished ligand dna
# CPU times: user 2h 24min 45s, sys: 45.5 s, total: 2h 25min 31s
# Wall time: 14min 51s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3EarlyStoppingTest"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# 76
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# ligand = dna
# early stopping: 10
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# 43
# AUC = 0.9638721630384437
# AUPRC = 0.480577774543267
# fold #: 2
# 36
# AUC = 0.9684409448818898
# AUPRC = 0.5068797908737674
# fold #: 3
# 38
# AUC = 0.9754593175853019
# AUPRC = 0.5451419865104782
# fold #: 4
# 48
# AUC = 0.9753123359580053
# AUPRC = 0.5513945998908375
# fold #: 5
# 38
# AUC = 0.9646351706036745
# AUPRC = 0.55505442852954
# fold #: 6
# 13
# AUC = 0.9489419795221844
# AUPRC = 0.38175703468209526
# fold #: 7
# 46
# AUC = 0.9802625360987136
# AUPRC = 0.5151048233028346
# fold #: 8
# 35
# AUC = 0.979553688632187
# AUPRC = 0.6732394127536506
# fold #: 9
# 35
# AUC = 0.9719506432134419
# AUPRC = 0.48310297558306786
# fold #: 10
# 49
# AUC = 0.9534155946442636
# AUPRC = 0.5428958673314959
# avg auc = 0.9681844374178106
# avg auprc = 0.5235148694001035
# Finished dna XGBSPWSampling3EarlyStoppingTest
# Finished ligand dna
# CPU times: user 1h 33min 21s, sys: 30.3 s, total: 1h 33min 51s
# Wall time: 5min 42s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3EarlyStoppingTest"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# 76
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# ligand = dna
# early stopping: 100
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# 36
# AUC = 0.9621429674231897
# AUPRC = 0.46702143089068676
# fold #: 2
# 37
# AUC = 0.9689081364829396
# AUPRC = 0.5148045220025064
# fold #: 3
# 32
# AUC = 0.9709238845144357
# AUPRC = 0.5245232109625534
# fold #: 4
# 40
# AUC = 0.9714330708661418
# AUPRC = 0.5164483156474048
# fold #: 5
# 47
# AUC = 0.9674540682414697
# AUPRC = 0.5750965334207851
# fold #: 6
# 29
# AUC = 0.9714885796797059
# AUPRC = 0.45285932676110663
# fold #: 7
# 34
# AUC = 0.979474927802573
# AUPRC = 0.5030399395802992
# fold #: 8
# 27
# AUC = 0.9785140456812812
# AUPRC = 0.6364810145941375
# fold #: 9
# 45
# AUC = 0.9752323444473615
# AUPRC = 0.5082413118519316
# fold #: 10
# 49
# AUC = 0.9534155946442636
# AUPRC = 0.5428958673314959
# avg auc = 0.9698987619783364
# avg auprc = 0.5241411473042908
# Finished dna XGBSPWSampling3EarlyStoppingTest
# Finished ligand dna
# CPU times: user 3h 39min 52s, sys: 1min 8s, total: 3h 41min 1s
# Wall time: 7min 15s

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBSPWSampling3EarlyStoppingTest"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# 76
# classifier_method = XGBSPWSampling3EarlyStoppingTest
# ligand = dna
# early stopping: 200
# {'reg_alpha': 0, 'colsample_bytree': 0.2, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 215, 'subsample': 1.0, 'reg_lambda': 1, 'min_child_weight': 0, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 9, 'gamma': 0.1, 'booster': 'gbtree'}
# fold #: 1
# 53
# AUC = 0.964469147238948
# AUPRC = 0.4982082574430017
# fold #: 2
# 59
# AUC = 0.9737952755905511
# AUPRC = 0.5379075029288289
# fold #: 3
# 60
# AUC = 0.979249343832021
# AUPRC = 0.570168208215304
# fold #: 4
# 56
# AUC = 0.9715643044619422
# AUPRC = 0.5649434457616964
# fold #: 5
# 53
# AUC = 0.9729081364829397
# AUPRC = 0.5760471635171187
# fold #: 6
# 55
# AUC = 0.9804883171436072
# AUPRC = 0.46992336772222837
# fold #: 7
# 59
# AUC = 0.9828091362562353
# AUPRC = 0.5566049128343686
# fold #: 8
# 56
# AUC = 0.9837070097138356
# AUPRC = 0.7225482642103784
# fold #: 9
# 45
# AUC = 0.9752323444473615
# AUPRC = 0.5082413118519316
# fold #: 10
# 68
# AUC = 0.956072459963245
# AUPRC = 0.5736003086921002
# avg auc = 0.9740295475130687
# avg auprc = 0.5578192743176957
# Finished dna XGBSPWSampling3EarlyStoppingTest
# Finished ligand dna
# CPU times: user 5h 42min 6s, sys: 1min 45s, total: 5h 43min 51s
# Wall time: 11min

# %%
# %%time
    

#Initialize dictionary
pred_dict = defaultdict(list)
auc_dict = defaultdict(list)
auprc_dict = defaultdict(list)
classifier_method = "XGBBestDNA"
ligand = "dna"
print "classifier_method = "+classifier_method

ligand_bind_features = ligands_features_df[ligand]
ligand_negatives_features = ligands_negatives_df[ligand]
features = features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negatives_features.iloc[:,features]])
y = [1] * ligand_bind_features.shape[0]
y.extend([0] * ligand_negatives_features.shape[0])
y = np.array(y)
val_scale_pos_weight = len([y[i] for i in range(len(y)) if y[i]==0])/len([y[i] for i in range(len(y)) if y[i]==1])
print val_scale_pos_weight
classifiers[classifier_method].set_params(scale_pos_weight=val_scale_pos_weight)

ordered_features = test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], ligands_negatives_df[ligand], ligand, downsample_method)

pred_df = pd.DataFrame.from_dict(pred_dict)
auc_df = pd.DataFrame.from_dict(auc_dict)
auprc_df = pd.DataFrame.from_dict(auprc_dict)

#Save to file
#pred_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1.csv", sep='\t')
#auc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auc.csv", sep='\t')
#auprc_df.to_csv(curr_dir[0]+"/pred_AUC_AUPRC/mediode_NegLigand_NoFilter/"+downsample_method+"/01.25.2018/"+ligand+"_"+classifier_method+"_0.1_auprc.csv", sep='\t')

#Combine features and pred results to a unified table
combine_features_predictions(ligand, ordered_features, pred_df)

print "Finished ligand "+ligand
# Out:
# classifier_method = XGBBestDNA
# 76
# classifier_method = XGBBestDNA
# ligand = dna
# {'reg_alpha': 0, 'colsample_bytree': 0.8, 'silent': 1, 'colsample_bylevel': 1, 'scale_pos_weight': 76, 'learning_rate': 0.1, 'missing': None, 'max_delta_step': 0, 'base_score': 0.5, 'n_estimators': 42, 'subsample': 0.9, 'reg_lambda': 1, 'min_child_weight': 2, 'objective': 'binary:logistic', 'seed': 0, 'max_depth': 5, 'gamma': 0.6, 'booster': 'gbtree'}
# fold #: 1
# AUC = 0.9709793628737584
# AUPRC = 0.4588001759302606
# fold #: 2
# AUC = 0.9634435695538058
# AUPRC = 0.4568549294981013
# fold #: 3
# AUC = 0.9766666666666668
# AUPRC = 0.4871797406379282
# fold #: 4
# AUC = 0.9664304461942257
# AUPRC = 0.4606976584499785
# fold #: 5
# AUC = 0.9557322834645668
# AUPRC = 0.5172748123492589
# fold #: 6
# AUC = 0.9814491992648989
# AUPRC = 0.41720173547434264
# fold #: 7
# AUC = 0.9729010238907849
# AUPRC = 0.47372218211813494
# fold #: 8
# AUC = 0.9879023365712787
# AUPRC = 0.5704541624848185
# fold #: 9
# AUC = 0.9768810711472827
# AUPRC = 0.505699979995254
# fold #: 10
# AUC = 0.9469992123917038
# AUPRC = 0.46310207687142313
# avg auc = 0.9699385172018973
# avg auprc = 0.48109874538095
# Finished dna XGBBestDNA
# Finished ligand dna
# CPU times: user 25min 47s, sys: 12.5 s, total: 26min
# Wall time: 58.2 s
