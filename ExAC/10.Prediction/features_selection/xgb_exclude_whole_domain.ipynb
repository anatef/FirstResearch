# %% [markdown]
# ## Feature Selection
#
# Uses a variety of methods to test the importance of each feature in classification.
#
# ### Files Needed:
# 1. Positions features as a csv
#
# ### Instructions:
# Run cells in order

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import pickle
from collections import defaultdict

# Models
from xgboost.sklearn import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# CV Splitting
import random as random
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.cross_validation import KFold
from sklearn.preprocessing import scale

# Evaluation
from sklearn.metrics import auc, roc_auc_score, precision_recall_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import scale

# Plotting
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

# Downsamplers imports - prototype selection - controlled
from imblearn.under_sampling import RandomUnderSampler

from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; }</style>")
# Out:
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Reading the input dataset

# %%
curr_dir = !pwd
input_path = curr_dir[0]+"/../../10.Prediction/domains_similarity/filtered_features_table/"
filename = "positions_features_mediode_filter_01.25.18.csv"
bind_scores_num = 10

features_all = pd.read_csv(input_path+filename, sep='\t', index_col=0)
features_cols = features_all.columns[1:-bind_scores_num] #removing binding scores and domain name
ligands = ["dna", "dnabase", "dnabackbone", "rna", "rnabase", "rnabackbone", "peptide", "ion", "metabolite"]

classifiers = {}
classifiers["Logistic"] = LogisticRegression(C=0.001, random_state=0)
classifiers["RF"] = RandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=0)
#classifiers["KNN"] = KNeighborsClassifier(n_neighbors=100, n_jobs=-1)
#classifiers["SVM"] = SVC(kernel='rbf', probability=True, random_state=0)
classifiers["ADA"] = AdaBoostClassifier(n_estimators=1000, random_state=0)
classifiers["XGB"] = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=0, max_depth=6, min_child_weight=0.05, colsample_bytree=0.5)

# %%
classifiers["XGB"].set_params(scale_pos_weight = 0)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=6, min_child_weight=0.05, missing=None, n_estimators=1000,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=0,
#        seed=None, silent=True, subsample=1)

# %% [markdown]
# ### Checking input features doesn't have NaNs

# %%
for col in features_cols:
    nan_idx = np.where( np.isnan(features_all[col].tolist()) == True)[0]
    if (len(nan_idx) > 0):
        print col+" has NaNs"

# %% [markdown]
# ### Checking input features doesn't have Infs

# %%
for col in features_cols:
    inf_idx = np.where(np.isinf(features_all[col].tolist()) == True)[0]
    if (len(inf_idx) > 0):
        print col+" has Inf"

# %% [markdown]
# ### Datasets of negative examples

# %%
non_binding_positions = features_all[features_all["max_binding_score"] == 0]
non_binding_positions = non_binding_positions.loc[:,features_cols]
print "non_binding #: "+str(non_binding_positions.shape[0])
# Out:
# non_binding #: 27191

# %%
with open(curr_dir[0]+"/../ligands_negatives_domains_dict.pik", 'rb') as handle:
    negatives_dict = pickle.load(handle)

ligands_negatives_df = {}
for ligand in ligands:
    ligands_negatives_df[ligand] = pd.DataFrame()
    for domain in negatives_dict[ligand]:
        if domain == 'negatives' or domain == 'domains':
            continue
        domain_all = features_all.loc[features_all.loc[:,"domain_name"] == domain,:]
        if len(domain_all) == 0:
            continue
        ligands_negatives_df[ligand] = pd.concat([ligands_negatives_df[ligand],domain_all.loc[domain_all.loc[:,"max_binding_score"] == 0,:]])
    
    ligands_negatives_df[ligand] = ligands_negatives_df[ligand][features_cols]
    print(ligand+" non-binding #: "+str(len(ligands_negatives_df[ligand])))
# Out:
# dna non-binding #: 1531
# dnabase non-binding #: 1219
# dnabackbone non-binding #: 1515
# rna non-binding #: 1343
# rnabase non-binding #: 1309
# rnabackbone non-binding #: 1331
# peptide non-binding #: 8142
# ion non-binding #: 20351
# metabolite non-binding #: 16143

# %% [markdown]
# ### Datasets of positive examples by ligand

# %%
bind_th = 0.1
ligands_features_df = {}

for ligand in ligands:
    score_col_str = ligand+"_binding_score"
    ligand_binding_df = features_all[features_all[score_col_str] >= bind_th]
    ligands_features_df[ligand] = ligand_binding_df.loc[:,features_cols]

# %% [markdown]
# ### Downsamplers

# %%
# Down-sample a balanced set with largest possible number of positives
downsamplers = defaultdict(dict)

downsamplers["RandomUnderSampler"] = RandomUnderSampler(random_state=0)

# %% [markdown]
# ### Classifier for a particular ligand-binding
# #### Test different algorithms with features removed

# %%
def test_model(pred_dict, auc_dict, auprc_dict, ligand_bind_features, ligand_negative_features, ligand_name, downsample_method, features=[]):
    """
    Test different models in 10-folds cross-validation.
    """
    
    #Default: Exclude no features
    if len(features) == 0:
        features = np.ones([ligand_bind_features.shape[1],]).astype(bool)
        
    #Arranging the features table by the CV order, for each model
    features_pred_dfs = dict.fromkeys(classifiers.keys())
    
    models_req_scaling = ["SVM", "KNN"]
    
    for classifier in classifiers.keys():
        classifier = classifier_method
        model = classifiers[classifier]
        features_pred_dfs[classifier] = pd.DataFrame()
        
        #Create X and y with included features
        X = pd.concat([ligand_bind_features.iloc[:,features], ligand_negative_features.iloc[:,features]])
        
        if (classifier in models_req_scaling):
            idx = X.index
            cols = X.columns
            X = pd.DataFrame(scale(X)) #Is z-scoring the data needed?
            X.index = idx #Restoring indices after scaling
            X.columns = cols

        y = [1] * ligand_bind_features.shape[0]
        y.extend([0] * ligand_negative_features.shape[0])
        y = np.array(y)

        binding_skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
        pred_idx = 1

        for train_index, test_index in binding_skf.split(X, y):
            print "fold #: "+str(pred_idx)
            X_train, X_test = X.iloc[train_index,:], X.iloc[test_index,:]
            y_train, y_test = y[train_index], y[test_index]

            #Down-sample negative examples to have balanced classes
            if (downsample_method == "NoDown"):
                X_train_sampled = X_train
                y_train_sampled = y_train
            else:
                if (downsample_method == "InstanceHardnessThreshold"):
                    downsampler = downsamplers[downsample_method][classifier]
                else:
                    downsampler = downsamplers[downsample_method]

                print(X_train.shape)
                print(y_train.shape)
                X_train_sampled, y_train_sampled = downsampler.fit_sample(X_train, y_train)
            
            #fit to training data
            model = classifiers[classifier]
            model.fit(X_train_sampled, y_train_sampled)
            probs_list = []
            
            probs = model.predict_proba(X_test)
            for l in probs:
                probs_list.append(l[1])
                
            print("Actual positives: "+str(np.sum(y_test))+"\tOut of: "+str(len(y_test)))
            print("Positives found: "+str(np.sum(probs[:, 1]))+"\tOut of: "+str(len(probs[:, 1])))
                
            pred_dict["obs"].extend(y_test)
            pred_dict["prob"].extend(probs_list)
            fold_list = [pred_idx] * len(probs_list)
            pred_dict["fold"].extend(fold_list)

            model_list = [classifier] * len(probs_list)
            pred_dict["model"].extend(model_list)

            #Update auc auprc dictionaries
            auc_dict[classifier].append(roc_auc_score(y_test, probs[:, 1]))
            precision, recall, _ = precision_recall_curve(y_test, probs[:, 1])
            auprc_dict[classifier].append(auc(recall, precision))
            
            #Update features table
            features_pred_dfs[classifier] = features_pred_dfs[classifier].append(X_test)
            pred_idx += 1
            
            print "AUC = "+str(auc_dict[classifier][-1])
            print "AUPRC = "+str(auprc_dict[classifier][-1])

        avg_auc = np.sum(auc_dict[classifier])/10.0
        print "avg auc = "+str(avg_auc)
        
        avg_auprc = np.sum(auprc_dict[classifier])/10.0
        print "avg auprc = "+str(avg_auprc)
            
        print "Finished "+ligand+" "+classifier
        break
    
    return features_pred_dfs

# %%
def combine_features_predictions(ligand, ordered_features, pred_df):
    
    pred_res = pred_df.copy(deep=True)
    for classifier in classifiers.keys():
        
        model_pred = pred_res[pred_res["model"] == classifier]
        model_pred.index = ordered_features[classifier].index
        
        #Creating the combined table
        features_pred = pd.concat([ordered_features[classifier], model_pred], axis=1)
        
        #Saving
        features_pred.to_csv(curr_dir[0]+"/feature_select_df/feature_pred/"+ligand+"_"+classifier+"_features_pred_whole_go.csv", sep='\t')

# %% [markdown]
# ### Test feature importance by isolating groups of features

# %%
# Create groups of features and print features in each group
group_names = ['population','conservation_genome','sub_matrix','selection','conservation_domain','sub_predictor',
               'chemical_major_allele','chemical_substitution','spider','whole_domain']
group_indices = [range(0,21),range(21,103),range(103,113),range(113,116)+range(149,166),range(116,138),range(138,149),
                 range(166,232),range(232,355),range(355,386),range(386,397)]

features_groups = dict(zip(group_names,group_indices))

features_list = np.array([c.encode('ascii','ignore') for c in ligands_features_df['dna'].columns])
for g in group_names:
    group_list = features_list[features_groups[g]]
    print("------- "+g+" --------")
    print("")
    for i in group_list:
        print(i)
    print("")
# Out:
# ------- population --------
#
# avg_maf_all
# avg_maf_altered
# maf_hist_0-0.001
# maf_hist_0.001-0.005
# maf_hist_0.005-0.01
# maf_hist_0.01-0.02
# maf_hist_0.02-0.04
# maf_hist_0.04-0.06
# maf_hist_0.06-0.08
# maf_hist_0.08-0.1
# maf_hist_0.1-0.2
# maf_hist_0.2-0.5
# alter_num_aa
# alter_num_aa_norm
# alter_num_snp
# alter_num_snp_norm
# avg_aa_polymorphisms
# frac_poly_aa
# rare_poly_0.5
# rare_poly_0.05
# rare_poly_0.005
#
# ------- conservation_genome --------
#
# phastCons1_avg
# phastCons2_avg
# phastCons3_avg
# phyloP1_avg
# phyloP2_avg
# phyloP3_avg
# phastCons1_hist_0.0-0.25
# phastCons1_hist_0.25-0.5
# phastCons1_hist_0.5-0.75
# phastCons1_hist_0.75-0.8
# phastCons1_hist_0.8-0.85
# phastCons1_hist_0.85-0.9
# phastCons1_hist_0.9-0.95
# phastCons1_hist_0.95-1.0
# phastCons2_hist_0.0-0.25
# phastCons2_hist_0.25-0.5
# phastCons2_hist_0.5-0.75
# phastCons2_hist_0.75-0.8
# phastCons2_hist_0.8-0.85
# phastCons2_hist_0.85-0.9
# phastCons2_hist_0.9-0.95
# phastCons2_hist_0.95-1.0
# phastCons3_hist_0.0-0.25
# phastCons3_hist_0.25-0.5
# phastCons3_hist_0.5-0.75
# phastCons3_hist_0.75-0.8
# phastCons3_hist_0.8-0.85
# phastCons3_hist_0.85-0.9
# phastCons3_hist_0.9-0.95
# phastCons3_hist_0.95-1.0
# phyloP1_hist_-14.0--1.0
# phyloP1_hist_-1.0-0.0
# phyloP1_hist_0.0-1.0
# phyloP1_hist_1.0-2.0
# phyloP1_hist_2.0-3.0
# phyloP1_hist_3.0-3.5
# phyloP1_hist_3.5-4.0
# phyloP1_hist_4.0-4.5
# phyloP1_hist_4.5-5.0
# phyloP1_hist_5.0-5.5
# phyloP1_hist_5.5-6.0
# phyloP2_hist_-14.0--1.0
# phyloP2_hist_-1.0-0.0
# phyloP2_hist_0.0-1.0
# phyloP2_hist_1.0-2.0
# phyloP2_hist_2.0-3.0
# phyloP2_hist_3.0-3.5
# phyloP2_hist_3.5-4.0
# phyloP2_hist_4.0-4.5
# phyloP2_hist_4.5-5.0
# phyloP2_hist_5.0-5.5
# phyloP2_hist_5.5-6.0
# phyloP3_hist_-14.0--1.0
# phyloP3_hist_-1.0-0.0
# phyloP3_hist_0.0-1.0
# phyloP3_hist_1.0-2.0
# phyloP3_hist_2.0-3.0
# phyloP3_hist_3.0-3.5
# phyloP3_hist_3.5-4.0
# phyloP3_hist_4.0-4.5
# phyloP3_hist_4.5-5.0
# phyloP3_hist_5.0-5.5
# phyloP3_hist_5.5-6.0
# phastCons_codons_hist_0.0-0.25
# phastCons_codons_hist_0.25-0.5
# phastCons_codons_hist_0.5-0.75
# phastCons_codons_hist_0.75-0.8
# phastCons_codons_hist_0.8-0.85
# phastCons_codons_hist_0.85-0.9
# phastCons_codons_hist_0.9-0.95
# phastCons_codons_hist_0.95-1.0
# phyloP_codons_hist_-14.0--1.0
# phyloP_codons_hist_-1.0-0.0
# phyloP_codons_hist_0.0-1.0
# phyloP_codons_hist_1.0-2.0
# phyloP_codons_hist_2.0-3.0
# phyloP_codons_hist_3.0-3.5
# phyloP_codons_hist_3.5-4.0
# phyloP_codons_hist_4.0-4.5
# phyloP_codons_hist_4.5-5.0
# phyloP_codons_hist_5.0-5.5
# phyloP_codons_hist_5.5-6.0
#
# ------- sub_matrix --------
#
# blosum_avg
# blosum_avg_weighted
# blosum_positive_num
# blosum_negative_num
# blosum_ratio
# pam_avg
# pam_avg_weighted
# pam_positive_num
# pam_negative_num
# pam_ratio
#
# ------- selection --------
#
# pseudo_nonsyn
# pseudo_syn
# pseudo_dNdS
# nonsyn_entropy
# instances_change_frac
# aa_ref_overlap
# aa_ref_SE
# aa_ref_jsd
# avg_jsd_100way_blosum
# med_jsd_100way_blosum
# instances_individuals_change_ratio
# aa_ref_overlap_individuals_change_ratio
# jsd_100way_instances_major_ratio
# jsd_100way_aa_not_used_ratio
# jsd_mul_aa_ref_SE
# jsd_SE_diff_ratio
# jsd_SE_sum
# SE_jsd_diff_ratio
# jsds_ratio
# jsds_subtraction
#
# ------- conservation_domain --------
#
# pfam_prob_max
# pfam_prob_A
# pfam_prob_C
# pfam_prob_D
# pfam_prob_E
# pfam_prob_F
# pfam_prob_G
# pfam_prob_H
# pfam_prob_I
# pfam_prob_K
# pfam_prob_L
# pfam_prob_M
# pfam_prob_N
# pfam_prob_P
# pfam_prob_Q
# pfam_prob_R
# pfam_prob_S
# pfam_prob_T
# pfam_prob_V
# pfam_prob_W
# pfam_prob_Y
# is_pfam_conserved
#
# ------- sub_predictor --------
#
# sift_avg
# sift_deleterious_num
# sift_tolerated_num
# sift_ratio
# sift_majority
# polyphen_avg
# polyphen_benign_num
# polyphen_possibly_num
# polyphen_probably_num
# polyphen_majority
# avg_clinvar_score
#
# ------- chemical_major_allele --------
#
# aa_ref_hist_A
# aa_ref_hist_C
# aa_ref_hist_D
# aa_ref_hist_E
# aa_ref_hist_F
# aa_ref_hist_G
# aa_ref_hist_H
# aa_ref_hist_I
# aa_ref_hist_K
# aa_ref_hist_L
# aa_ref_hist_M
# aa_ref_hist_N
# aa_ref_hist_P
# aa_ref_hist_Q
# aa_ref_hist_R
# aa_ref_hist_S
# aa_ref_hist_T
# aa_ref_hist_V
# aa_ref_hist_W
# aa_ref_hist_Y
# aa_ref_hist_*
# aa_ref_prob_A
# aa_ref_prob_C
# aa_ref_prob_D
# aa_ref_prob_E
# aa_ref_prob_F
# aa_ref_prob_G
# aa_ref_prob_H
# aa_ref_prob_I
# aa_ref_prob_K
# aa_ref_prob_L
# aa_ref_prob_M
# aa_ref_prob_N
# aa_ref_prob_P
# aa_ref_prob_Q
# aa_ref_prob_R
# aa_ref_prob_S
# aa_ref_prob_T
# aa_ref_prob_V
# aa_ref_prob_W
# aa_ref_prob_Y
# aa_ref_prob_*
# aa_ref_charge_positive_count
# aa_ref_charge_negative_count
# aa_ref_charge_neutral_count
# aa_ref_charge_majority
# hindex_avg
# hindex_pos_cnt
# hindex_neg_cnt
# vol_avg
# vol_tiny_cnt
# vol_small_cnt
# vol_big_cnt
# aa_ref_aa_functional_group.ALIPHATIC_count
# aa_ref_aa_functional_group.AROMATIC_count
# aa_ref_aa_functional_group.NEGATIVE_count
# aa_ref_aa_functional_group.POSITIVE_count
# aa_ref_aa_functional_group.POLAR_count
# aa_ref_alpha_prop_avg
# aa_ref_beta_prop_avg
# aa_ref_turn_prop_avg
# aa_ref_alpha_is_majority
# aa_ref_beta_is_majority
# aa_ref_turn_is_majority
# H_bond_donor_avg
# H_bond_acceptor_avg
#
# ------- chemical_substitution --------
#
# aa_alt_cnt_hist_A
# aa_alt_cnt_hist_C
# aa_alt_cnt_hist_D
# aa_alt_cnt_hist_E
# aa_alt_cnt_hist_F
# aa_alt_cnt_hist_G
# aa_alt_cnt_hist_H
# aa_alt_cnt_hist_I
# aa_alt_cnt_hist_K
# aa_alt_cnt_hist_L
# aa_alt_cnt_hist_M
# aa_alt_cnt_hist_N
# aa_alt_cnt_hist_P
# aa_alt_cnt_hist_Q
# aa_alt_cnt_hist_R
# aa_alt_cnt_hist_S
# aa_alt_cnt_hist_T
# aa_alt_cnt_hist_V
# aa_alt_cnt_hist_W
# aa_alt_cnt_hist_Y
# aa_alt_cnt_hist_*
# aa_alt_cnt_prob_A
# aa_alt_cnt_prob_C
# aa_alt_cnt_prob_D
# aa_alt_cnt_prob_E
# aa_alt_cnt_prob_F
# aa_alt_cnt_prob_G
# aa_alt_cnt_prob_H
# aa_alt_cnt_prob_I
# aa_alt_cnt_prob_K
# aa_alt_cnt_prob_L
# aa_alt_cnt_prob_M
# aa_alt_cnt_prob_N
# aa_alt_cnt_prob_P
# aa_alt_cnt_prob_Q
# aa_alt_cnt_prob_R
# aa_alt_cnt_prob_S
# aa_alt_cnt_prob_T
# aa_alt_cnt_prob_V
# aa_alt_cnt_prob_W
# aa_alt_cnt_prob_Y
# aa_alt_cnt_prob_*
# aa_alt_avg_freq_hist_A
# aa_alt_avg_freq_hist_C
# aa_alt_avg_freq_hist_D
# aa_alt_avg_freq_hist_E
# aa_alt_avg_freq_hist_F
# aa_alt_avg_freq_hist_G
# aa_alt_avg_freq_hist_H
# aa_alt_avg_freq_hist_I
# aa_alt_avg_freq_hist_K
# aa_alt_avg_freq_hist_L
# aa_alt_avg_freq_hist_M
# aa_alt_avg_freq_hist_N
# aa_alt_avg_freq_hist_P
# aa_alt_avg_freq_hist_Q
# aa_alt_avg_freq_hist_R
# aa_alt_avg_freq_hist_S
# aa_alt_avg_freq_hist_T
# aa_alt_avg_freq_hist_V
# aa_alt_avg_freq_hist_W
# aa_alt_avg_freq_hist_Y
# aa_alt_avg_freq_hist_*
# aa_alt_avg_freq_prob_A
# aa_alt_avg_freq_prob_C
# aa_alt_avg_freq_prob_D
# aa_alt_avg_freq_prob_E
# aa_alt_avg_freq_prob_F
# aa_alt_avg_freq_prob_G
# aa_alt_avg_freq_prob_H
# aa_alt_avg_freq_prob_I
# aa_alt_avg_freq_prob_K
# aa_alt_avg_freq_prob_L
# aa_alt_avg_freq_prob_M
# aa_alt_avg_freq_prob_N
# aa_alt_avg_freq_prob_P
# aa_alt_avg_freq_prob_Q
# aa_alt_avg_freq_prob_R
# aa_alt_avg_freq_prob_S
# aa_alt_avg_freq_prob_T
# aa_alt_avg_freq_prob_V
# aa_alt_avg_freq_prob_W
# aa_alt_avg_freq_prob_Y
# aa_alt_avg_freq_prob_*
# sub_diff_hindex_avg
# sub_diff_vol_avg
# sub_func_group_stay_cnt
# sub_func_group_move_cnt
# sub_func_group_trans_0-0
# sub_func_group_trans_0-1
# sub_func_group_trans_0-2
# sub_func_group_trans_0-3
# sub_func_group_trans_0-4
# sub_func_group_trans_0-5
# sub_func_group_trans_1-0
# sub_func_group_trans_1-1
# sub_func_group_trans_1-2
# sub_func_group_trans_1-3
# sub_func_group_trans_1-4
# sub_func_group_trans_1-5
# sub_func_group_trans_2-0
# sub_func_group_trans_2-1
# sub_func_group_trans_2-2
# sub_func_group_trans_2-3
# sub_func_group_trans_2-4
# sub_func_group_trans_2-5
# sub_func_group_trans_3-0
# sub_func_group_trans_3-1
# sub_func_group_trans_3-2
# sub_func_group_trans_3-3
# sub_func_group_trans_3-4
# sub_func_group_trans_3-5
# sub_func_group_trans_4-0
# sub_func_group_trans_4-1
# sub_func_group_trans_4-2
# sub_func_group_trans_4-3
# sub_func_group_trans_4-4
# sub_func_group_trans_4-5
# sub_diff_prop_avg_alpha
# sub_diff_prop_avg_beta
# sub_diff_prop_avg_turn
# donor_diff_avg
# acceptor_diff_avg
#
# ------- spider --------
#
# solvent_acc_avg
# solvent_acc_std
# hsa2_cn_avg
# hsa2_cn_std
# hsb2_cn_avg
# hsb2_cn_std
# backbone_Phi_angle_avg
# backbone_Phi_angle_std
# backbone_Psi_angle_avg
# backbone_Psi_angle_std
# c-alpha_tau_angle_avg
# c-alph_tau_angle_std
# c-alpha_theta_angle_avg
# c-alph_theta_angle_std
# helix_prob_avg
# helix_prob_std
# sheet_prob_avg
# sheet_prob_std
# turn_prob_avg
# turn_prob_std
# spd_helix_is_majority
# spd_sheet_is_majority
# spd_turn_is_majority
# hsa2_HSE-up_avg
# hsa2_HSE-up_std
# hsa2_HSE-down_avg
# hsa2_HSE-down_std
# hsb2_HSE-up_avg
# hsb2_HSE-up_std
# hsb2_HSE-down_avg
# hsb2_HSE-down_std
#
# ------- whole_domain --------
#
# whole_domain_phastCons_avg
# whole_domain_phastCons_std
# whole_domain_phyloP_avg
# whole_domain_phyloP_std
# GO:NO_TERM
# GO:NUCLEIC_ACID_BINDING
# GO:PROTEIN_BINDING
# GO:METAL_ION_BINDING
# GO:MEMBRANE
# GO:INTRACELLULAR
# GO:SIGNAL_TRANSDUCTION

# %%
## Train/test with each group individually

for ligand in ligands:
    n_features = ligands_features_df[ligand].shape[1]
    for group in features_groups:
        # Include features in the group
        features_included = np.zeros([n_features]).astype(bool)
        features_included[features_groups[group]] = True
        
        #Initialize dictionary
        pred_dict = defaultdict(list)
        auc_dict = defaultdict(list)
        auprc_dict = defaultdict(list)

        # Run classifier
        test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], non_binding_positions, ligand, "RandomUnderSampler", features_included)

        pred_df = pd.DataFrame.from_dict(pred_dict)
        auc_df = pd.DataFrame.from_dict(auc_dict)
        auprc_df = pd.DataFrame.from_dict(auprc_dict)

        #Save to file
        pred_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_indiv_0.1.csv", sep='\t')
        auc_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_indiv_0.1_auc.csv", sep='\t')
        auprc_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_indiv_0.1_auprc.csv", sep='\t')
# Out:
# avg auc = 0.648370504841
# avg auprc = 0.0492424794673
# Finished dna KNN
# avg auc = 0.61853372591
# avg auprc = 0.126590899541
# Finished dna SVM
# avg auc = 0.625785075406
# avg auprc = 0.0432144130668
# Finished dna Ridge
# avg auc = 0.638589321811
# avg auprc = 0.0377770331254
# Finished dna RF
# avg auc = 0.629860539637
# avg auprc = 0.0474099752082
# Finished dna Logistic
# avg auc = 0.564030443049
# avg auprc = 0.0599178289917
# Finished dna Lasso
# avg auc = 0.692536508284
# avg auprc = 0.0608786496104
# Finished dna KNN
# avg auc = 0.578931819141
# avg auprc = 0.0890787845652
# Finished dna SVM
# avg auc = 0.710863236614
# avg auprc = 0.0640442912353
# Finished dna Ridge
# avg auc = 0.708453082814
# avg auprc = 0.0555161893943
# Finished dna RF
# avg auc = 0.623089272885
# avg auprc = 0.0698119130962
# Finished dna Logistic
# avg auc = 0.635945387895
# avg auprc = 0.0651928101666
# Finished dna Lasso
# avg auc = 0.562816209453
# avg auprc = 0.0273949666257
# Finished dna KNN
# avg auc = 0.469311239557
# avg auprc = 0.0730112856261
# Finished dna SVM
# avg auc = 0.549289277022
# avg auprc = 0.0509305947002
# Finished dna Ridge
# avg auc = 0.613800950063
# avg auprc = 0.0326540221297
# Finished dna RF
# avg auc = 0.555332912645
# avg auprc = 0.0589917520585
# Finished dna Logistic
# avg auc = 0.548446323868
# avg auprc = 0.0754834777598
# Finished dna Lasso
# avg auc = 0.697417406164
# avg auprc = 0.0933447805074
# Finished dna KNN
# avg auc = 0.713156502062
# avg auprc = 0.103359429252
# Finished dna SVM
# avg auc = 0.690726554287
# avg auprc = 0.0780459589858
# Finished dna Ridge
# avg auc = 0.724770548967
# avg auprc = 0.105667728623
# Finished dna RF
# avg auc = 0.708914090434
# avg auprc = 0.0949830849992
# Finished dna Logistic
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# avg auc = 0.674458658892
# avg auprc = 0.0942629375471
# Finished dna Lasso
# avg auc = 0.715730550111
# avg auprc = 0.0868722036062
# Finished dna KNN
# avg auc = 0.73090161549
# avg auprc = 0.0836304165702
# Finished dna SVM
# avg auc = 0.693036832555
# avg auprc = 0.0910927895577
# Finished dna Ridge
# avg auc = 0.71008668844
# avg auprc = 0.0689719113774
# Finished dna RF
# avg auc = 0.713541975414
# avg auprc = 0.104963147165
# Finished dna Logistic
# avg auc = 0.715185281938
# avg auprc = 0.0992981278599
# Finished dna Lasso
# avg auc = 0.677440741921
# avg auprc = 0.044597359317
# Finished dna KNN
# avg auc = 0.663484880975
# avg auprc = 0.0428754200475
# Finished dna SVM
# avg auc = 0.704302335487
# avg auprc = 0.0572383530307
# Finished dna Ridge
# avg auc = 0.713583407186
# avg auprc = 0.0834823854506
# Finished dna RF
# avg auc = 0.711442806432
# avg auprc = 0.0595972746835
# Finished dna Logistic
# avg auc = 0.699812079655
# avg auprc = 0.0655484772952
# Finished dna Lasso
# avg auc = 0.676415124103
# avg auprc = 0.134112007254
# Finished dna KNN
# avg auc = 0.679842638916
# avg auprc = 0.173889271751
# Finished dna SVM
# avg auc = 0.732942315397
# avg auprc = 0.126780161774
# Finished dna Ridge
# avg auc = 0.648622832612
# avg auprc = 0.0959646423609
# Finished dna RF
# avg auc = 0.693102575357
# avg auprc = 0.159284958794
# Finished dna Logistic
# avg auc = 0.567515483254
# avg auprc = 0.297575155257
# Finished dna Lasso
# avg auc = 0.592070705532
# avg auprc = 0.026924945723
# Finished dna KNN
# avg auc = 0.636744186345
# avg auprc = 0.0611822145771
# Finished dna SVM
# avg auc = 0.639187201533
# avg auprc = 0.0742741512191
# Finished dna Ridge
# avg auc = 0.654876181249
# avg auprc = 0.0417238387514
# Finished dna RF
# avg auc = 0.644918528291
# avg auprc = 0.0701578051001
# Finished dna Logistic
# avg auc = 0.617987604391
# avg auprc = 0.0574764286788
# Finished dna Lasso
# avg auc = 0.697322169284
# avg auprc = 0.0844567709541
# Finished dna KNN
# avg auc = 0.679746240591
# avg auprc = 0.0781154892191
# Finished dna SVM
# avg auc = 0.70504535231
# avg auprc = 0.0873391079954
# Finished dna Ridge
# avg auc = 0.717685679849
# avg auprc = 0.0745067436931
# Finished dna RF
# avg auc = 0.706224856561
# avg auprc = 0.0833865490439
# Finished dna Logistic
# avg auc = 0.5
# avg auprc = 0.509827326887
# Finished dna Lasso
# avg auc = 0.681961405395
# avg auprc = 0.0444796671284
# Finished dna KNN
# avg auc = 0.533564966562
# avg auprc = 0.0328122339159
# Finished dna SVM
# avg auc = 0.694398900248
# avg auprc = 0.0758689699633
# Finished dna Ridge
# avg auc = 0.654772128815
# avg auprc = 0.0519610457192
# Finished dna RF
# avg auc = 0.699878694069
# avg auprc = 0.0847547037476
# Finished dna Logistic
# avg auc = 0.550980952477
# avg auprc = 0.0734540872696
# Finished dna Lasso
# avg auc = 0.64584914438
# avg auprc = 0.015801423622
# Finished dnabase KNN
# avg auc = 0.414484174267
# avg auprc = 0.0705136358052
# Finished dnabase SVM
# avg auc = 0.617137056501
# avg auprc = 0.0213628326059
# Finished dnabase Ridge
# avg auc = 0.610472080518
# avg auprc = 0.0125377038076
# Finished dnabase RF
# avg auc = 0.632887161767
# avg auprc = 0.0304155648457
# Finished dnabase Logistic
# avg auc = 0.620854796376
# avg auprc = 0.0235178881669
# Finished dnabase Lasso
# avg auc = 0.711023318824
# avg auprc = 0.0367987044678
# Finished dnabase KNN
# avg auc = 0.453365962263
# avg auprc = 0.210573979458
# Finished dnabase SVM
# avg auc = 0.767341975345
# avg auprc = 0.0326907722768
# Finished dnabase Ridge
# avg auc = 0.752334162464
# avg auprc = 0.0348670298954
# Finished dnabase RF
# avg auc = 0.644182082205
# avg auprc = 0.0482243154411
# Finished dnabase Logistic
# avg auc = 0.658851076426
# avg auprc = 0.0335413235177
# Finished dnabase Lasso
# avg auc = 0.544472306109
# avg auprc = 0.0374428077092
# Finished dnabase KNN
# avg auc = 0.419717229172
# avg auprc = 0.0580529470343
# Finished dnabase SVM
# avg auc = 0.559216656852
# avg auprc = 0.0298046491753
# Finished dnabase Ridge
# avg auc = 0.597332673796
# avg auprc = 0.0236508955461
# Finished dnabase RF
# avg auc = 0.560603488911
# avg auprc = 0.0581629127832
# Finished dnabase Logistic
# avg auc = 0.549075992932
# avg auprc = 0.061590990895
# Finished dnabase Lasso
# avg auc = 0.671926329349
# avg auprc = 0.0871645367351
# Finished dnabase KNN
# avg auc = 0.648390871209
# avg auprc = 0.0648016088995
# Finished dnabase SVM
# avg auc = 0.635217424564
# avg auprc = 0.0248149211159
# Finished dnabase Ridge
# avg auc = 0.664215489189
# avg auprc = 0.0387067019093
# Finished dnabase RF
# avg auc = 0.683254688826
# avg auprc = 0.0667695617499
# Finished dnabase Logistic
# avg auc = 0.652019881882
# avg auprc = 0.062295054212
# Finished dnabase Lasso
# avg auc = 0.709946657578
# avg auprc = 0.0442389359857
# Finished dnabase KNN
# avg auc = 0.701581165564
# avg auprc = 0.0645533111508
# Finished dnabase SVM
# avg auc = 0.633579799078
# avg auprc = 0.0388363104477
# Finished dnabase Ridge
# avg auc = 0.734435139956
# avg auprc = 0.0294019147838
# Finished dnabase RF
# avg auc = 0.688865766202
# avg auprc = 0.0810755097508
# Finished dnabase Logistic
# avg auc = 0.654670770451
# avg auprc = 0.0673104541518
# Finished dnabase Lasso
# avg auc = 0.643936619513
# avg auprc = 0.0160215906687
# Finished dnabase KNN
# avg auc = 0.408223954501
# avg auprc = 0.223851920271
# Finished dnabase SVM
# avg auc = 0.699975968533
# avg auprc = 0.0155129914146
# Finished dnabase Ridge
# avg auc = 0.692924846434
# avg auprc = 0.0265782006541
# Finished dnabase RF
# avg auc = 0.691500591482
# avg auprc = 0.0183441351505
# Finished dnabase Logistic
# avg auc = 0.660357416622
# avg auprc = 0.0156136565516
# Finished dnabase Lasso
# avg auc = 0.742660116634
# avg auprc = 0.138212931092
# Finished dnabase KNN
# avg auc = 0.444310553914
# avg auprc = 0.262110860145
# Finished dnabase SVM
# avg auc = 0.727061641486
# avg auprc = 0.114274585836
# Finished dnabase Ridge
# avg auc = 0.699982316487
# avg auprc = 0.0637673055436
# Finished dnabase RF
# avg auc = 0.687522973149
# avg auprc = 0.117153436658
# Finished dnabase Logistic
# avg auc = 0.475146260324
# avg auprc = 0.454274966349
# Finished dnabase Lasso
# avg auc = 0.559390184502
# avg auprc = 0.0260939497738
# Finished dnabase KNN
# avg auc = 0.48842882127
# avg auprc = 0.091200937641
# Finished dnabase SVM
# avg auc = 0.587696079283
# avg auprc = 0.0491804161534
# Finished dnabase Ridge
# avg auc = 0.615303297662
# avg auprc = 0.021435944373
# Finished dnabase RF
# avg auc = 0.592952317576
# avg auprc = 0.0697593336452
# Finished dnabase Logistic
# avg auc = 0.607699928634
# avg auprc = 0.0342111590961
# Finished dnabase Lasso
# avg auc = 0.679256700727
# avg auprc = 0.038630327761
# Finished dnabase KNN
# avg auc = 0.462661052464
# avg auprc = 0.0708858995274
# Finished dnabase SVM
# avg auc = 0.667394060113
# avg auprc = 0.0407541057678
# Finished dnabase Ridge
# avg auc = 0.698991702395
# avg auprc = 0.0221643667973
# Finished dnabase RF
# avg auc = 0.677125821121
# avg auprc = 0.0404841182458
# Finished dnabase Logistic
# avg auc = 0.5
# avg auprc = 0.503706354331
# Finished dnabase Lasso
# avg auc = 0.693843033622
# avg auprc = 0.0302029429269
# Finished dnabase KNN
# avg auc = 0.343954990177
# avg auprc = 0.105196436543
# Finished dnabase SVM
# avg auc = 0.683212685445
# avg auprc = 0.0450686161074
# Finished dnabase Ridge
# avg auc = 0.665126802354
# avg auprc = 0.0195627408461
# Finished dnabase RF
# avg auc = 0.686034470112
# avg auprc = 0.0611500847872
# Finished dnabase Logistic
# avg auc = 0.548097969171
# avg auprc = 0.0752314206527
# Finished dnabase Lasso
# avg auc = 0.651863635793
# avg auprc = 0.0299248371208
# Finished dnabackbone KNN
# avg auc = 0.548250563261
# avg auprc = 0.0476197522723
# Finished dnabackbone SVM
# avg auc = 0.637114277731
# avg auprc = 0.0489747124294
# Finished dnabackbone Ridge
# avg auc = 0.616347545068
# avg auprc = 0.0247780970121
# Finished dnabackbone RF
# avg auc = 0.650698118335
# avg auprc = 0.0492529095481
# Finished dnabackbone Logistic
# avg auc = 0.602201192507
# avg auprc = 0.0605796221198
# Finished dnabackbone Lasso
# avg auc = 0.681499348646
# avg auprc = 0.0452331625948
# Finished dnabackbone KNN
# avg auc = 0.531040564284
# avg auprc = 0.162788243643
# Finished dnabackbone SVM
# avg auc = 0.710601335897
# avg auprc = 0.0436625168588
# Finished dnabackbone Ridge
# avg auc = 0.700328063926
# avg auprc = 0.0486176473898
# Finished dnabackbone RF
# avg auc = 0.625513198222
# avg auprc = 0.0589938232578
# Finished dnabackbone Logistic
# avg auc = 0.66007493433
# avg auprc = 0.0518085424227
# Finished dnabackbone Lasso
# avg auc = 0.55548729064
# avg auprc = 0.0245703998307
# Finished dnabackbone KNN
# avg auc = 0.453164828758
# avg auprc = 0.211813763719
# Finished dnabackbone SVM
# avg auc = 0.53284050166
# avg auprc = 0.0422205526712
# Finished dnabackbone Ridge
# avg auc = 0.58835175537
# avg auprc = 0.0259925431508
# Finished dnabackbone RF
# avg auc = 0.557519161401
# avg auprc = 0.0556851573579
# Finished dnabackbone Logistic
# avg auc = 0.558232145426
# avg auprc = 0.0736025724905
# Finished dnabackbone Lasso
# avg auc = 0.709729476245
# avg auprc = 0.0893138524585
# Finished dnabackbone KNN
# avg auc = 0.724347588526
# avg auprc = 0.0892889526958
# Finished dnabackbone SVM
# avg auc = 0.713504648262
# avg auprc = 0.0778063927997
# Finished dnabackbone Ridge
# avg auc = 0.749780717154
# avg auprc = 0.099715280749
# Finished dnabackbone RF
# avg auc = 0.716392567345
# avg auprc = 0.0972510896741
# Finished dnabackbone Logistic
# avg auc = 0.675682844695
# avg auprc = 0.0864223684235
# Finished dnabackbone Lasso
# avg auc = 0.72747917499
# avg auprc = 0.0753060231518
# Finished dnabackbone KNN
# avg auc = 0.731593721572
# avg auprc = 0.0735772956325
# Finished dnabackbone SVM
# avg auc = 0.68822515614
# avg auprc = 0.0570863618678
# Finished dnabackbone Ridge
# avg auc = 0.721068168501
# avg auprc = 0.079472641206
# Finished dnabackbone RF
# avg auc = 0.720231861621
# avg auprc = 0.0939705239643
# Finished dnabackbone Logistic
# avg auc = 0.733381548806
# avg auprc = 0.0919994248152
# Finished dnabackbone Lasso
# avg auc = 0.686125750482
# avg auprc = 0.0430068904825
# Finished dnabackbone KNN
# avg auc = 0.664157322945
# avg auprc = 0.0435621817446
# Finished dnabackbone SVM
# avg auc = 0.695783725461
# avg auprc = 0.0524629329253
# Finished dnabackbone Ridge
# avg auc = 0.703294745605
# avg auprc = 0.0724969824296
# Finished dnabackbone RF
# avg auc = 0.710385896847
# avg auprc = 0.0708440907101
# Finished dnabackbone Logistic
# avg auc = 0.70113474299
# avg auprc = 0.0634376043378
# Finished dnabackbone Lasso
# avg auc = 0.673056653529
# avg auprc = 0.112572145508
# Finished dnabackbone KNN
# avg auc = 0.706957470461
# avg auprc = 0.16040861268
# Finished dnabackbone SVM
# avg auc = 0.744191953395
# avg auprc = 0.109629830268
# Finished dnabackbone Ridge
# avg auc = 0.615334125656
# avg auprc = 0.106248243332
# Finished dnabackbone RF
# avg auc = 0.698210908264
# avg auprc = 0.116444759623
# Finished dnabackbone Logistic
# avg auc = 0.679320887312
# avg auprc = 0.161395363911
# Finished dnabackbone Lasso
# avg auc = 0.580952251552
# avg auprc = 0.0203559323836
# Finished dnabackbone KNN
# avg auc = 0.624749383813
# avg auprc = 0.0477731766913
# Finished dnabackbone SVM
# avg auc = 0.641789963901
# avg auprc = 0.0548087985275
# Finished dnabackbone Ridge
# avg auc = 0.648089276159
# avg auprc = 0.037930839078
# Finished dnabackbone RF
# avg auc = 0.657139310019
# avg auprc = 0.0615695854047
# Finished dnabackbone Logistic
# avg auc = 0.61206094847
# avg auprc = 0.0484531727324
# Finished dnabackbone Lasso
# avg auc = 0.705502526739
# avg auprc = 0.0886823232061
# Finished dnabackbone KNN
# avg auc = 0.684613261123
# avg auprc = 0.0773542168058
# Finished dnabackbone SVM
# avg auc = 0.719175305494
# avg auprc = 0.0831324395673
# Finished dnabackbone Ridge
# avg auc = 0.720939889288
# avg auprc = 0.0755195066507
# Finished dnabackbone RF
# avg auc = 0.714982595347
# avg auprc = 0.0852818568507
# Finished dnabackbone Logistic
# avg auc = 0.5
# avg auprc = 0.508227138127
# Finished dnabackbone Lasso
# avg auc = 0.682325515374
# avg auprc = 0.0393800369924
# Finished dnabackbone KNN
# avg auc = 0.54094094684
# avg auprc = 0.120377933186
# Finished dnabackbone SVM
# avg auc = 0.691497486276
# avg auprc = 0.0582545109302
# Finished dnabackbone Ridge
# avg auc = 0.681310379206
# avg auprc = 0.0507041888476
# Finished dnabackbone RF
# avg auc = 0.707099472782
# avg auprc = 0.0628209218488
# Finished dnabackbone Logistic
# avg auc = 0.559380557059
# avg auprc = 0.075341975221
# Finished dnabackbone Lasso
# avg auc = 0.577255982439
# avg auprc = 0.0489650816924
# Finished rna KNN
# avg auc = 0.407067340433
# avg auprc = 0.111473971688
# Finished rna SVM
# avg auc = 0.532144990343
# avg auprc = 0.032222752867
# Finished rna Ridge
# avg auc = 0.575003658377
# avg auprc = 0.0243889152107
# Finished rna RF
# avg auc = 0.553905202197
# avg auprc = 0.0422646862448
# Finished rna Logistic
# avg auc = 0.497326678275
# avg auprc = 0.0726881556979
# Finished rna Lasso
# avg auc = 0.704338984531
# avg auprc = 0.0536443234695
# Finished rna KNN
# avg auc = 0.627862013896
# avg auprc = 0.0808501850236
# Finished rna SVM
# avg auc = 0.641272498428
# avg auprc = 0.0494368469639
# Finished rna Ridge
# avg auc = 0.715054981502
# avg auprc = 0.0516426018575
# Finished rna RF
# avg auc = 0.528688445219
# avg auprc = 0.0219540605448
# Finished rna Logistic
# avg auc = 0.604218734868
# avg auprc = 0.0364199164785
# Finished rna Lasso
# avg auc = 0.56913703791
# avg auprc = 0.0622207391377
# Finished rna KNN
# avg auc = 0.457035409257
# avg auprc = 0.0144950506482
# Finished rna SVM
# avg auc = 0.536172629234
# avg auprc = 0.0527107419767
# Finished rna Ridge
# avg auc = 0.582388063109
# avg auprc = 0.0588809265951
# Finished rna RF
# avg auc = 0.560899132024
# avg auprc = 0.0641478534469
# Finished rna Logistic
# avg auc = 0.501856770788
# avg auprc = 0.0823032784036
# Finished rna Lasso
# avg auc = 0.619991292778
# avg auprc = 0.083154393875
# Finished rna KNN
# avg auc = 0.609823890882
# avg auprc = 0.100928181286
# Finished rna SVM
# avg auc = 0.606654366589
# avg auprc = 0.0513813264006
# Finished rna Ridge
# avg auc = 0.698011749383
# avg auprc = 0.0404114572405
# Finished rna RF
# avg auc = 0.610124174106
# avg auprc = 0.0683168976773
# Finished rna Logistic
# avg auc = 0.606434980672
# avg auprc = 0.0837078969615
# Finished rna Lasso
# avg auc = 0.689934604478
# avg auprc = 0.0495729292923
# Finished rna KNN
# avg auc = 0.618778747005
# avg auprc = 0.126837328621
# Finished rna SVM
# avg auc = 0.65362316834
# avg auprc = 0.0787692015838
# Finished rna Ridge
# avg auc = 0.678482649172
# avg auprc = 0.0576961488897
# Finished rna RF
# avg auc = 0.616150272186
# avg auprc = 0.076557152027
# Finished rna Logistic
# avg auc = 0.656776543739
# avg auprc = 0.114508438731
# Finished rna Lasso
# avg auc = 0.626111127657
# avg auprc = 0.0304692324601
# Finished rna KNN
# avg auc = 0.65557801295
# avg auprc = 0.0337842807797
# Finished rna SVM
# avg auc = 0.653269213517
# avg auprc = 0.0319870487341
# Finished rna Ridge
# avg auc = 0.618998190501
# avg auprc = 0.0301633926283
# Finished rna RF
# avg auc = 0.646546449071
# avg auprc = 0.0318185820767
# Finished rna Logistic
# avg auc = 0.629564783374
# avg auprc = 0.0289784565364
# Finished rna Lasso
# avg auc = 0.690313561188
# avg auprc = 0.0752813116733
# Finished rna KNN
# avg auc = 0.708017664242
# avg auprc = 0.162211435569
# Finished rna SVM
# avg auc = 0.739832965375
# avg auprc = 0.131447808363
# Finished rna Ridge
# avg auc = 0.694973427146
# avg auprc = 0.1730729156
# Finished rna RF
# avg auc = 0.770875628844
# avg auprc = 0.136587440268
# Finished rna Logistic
# avg auc = 0.621080944658
# avg auprc = 0.107773112715
# Finished rna Lasso
# avg auc = 0.553140589211
# avg auprc = 0.0203108682675
# Finished rna KNN
# avg auc = 0.590828574761
# avg auprc = 0.0784191914036
# Finished rna SVM
# avg auc = 0.603595866954
# avg auprc = 0.0446720600434
# Finished rna Ridge
# avg auc = 0.624975634685
# avg auprc = 0.0322229307001
# Finished rna RF
# avg auc = 0.603029880948
# avg auprc = 0.0600720454862
# Finished rna Logistic
# avg auc = 0.574778728092
# avg auprc = 0.0635524111855
# Finished rna Lasso
# avg auc = 0.615233435196
# avg auprc = 0.0278328272288
# Finished rna KNN
# avg auc = 0.462506372999
# avg auprc = 0.114736053162
# Finished rna SVM
# avg auc = 0.627461573665
# avg auprc = 0.0360274468309
# Finished rna Ridge
# avg auc = 0.684225425931
# avg auprc = 0.0356757277097
# Finished rna RF
# avg auc = 0.617934238492
# avg auprc = 0.0361356616285
# Finished rna Logistic
# avg auc = 0.5
# avg auprc = 0.508278924156
# Finished rna Lasso
# avg auc = 0.619893289793
# avg auprc = 0.0309843473599
# Finished rna KNN
# avg auc = 0.457120958085
# avg auprc = 0.148179217435
# Finished rna SVM
# avg auc = 0.548858573097
# avg auprc = 0.0385306377942
# Finished rna Ridge
# avg auc = 0.65211958702
# avg auprc = 0.0448010755008
# Finished rna RF
# avg auc = 0.537888845567
# avg auprc = 0.053167680034
# Finished rna Logistic
# avg auc = 0.482994931733
# avg auprc = 0.0804449809613
# Finished rna Lasso
# avg auc = 0.547354533026
# avg auprc = 0.0175599223772
# Finished rnabase KNN
# avg auc = 0.457945568592
# avg auprc = 0.126239977728
# Finished rnabase SVM
# avg auc = 0.55256105019
# avg auprc = 0.0136392075814
# Finished rnabase Ridge
# avg auc = 0.553638537873
# avg auprc = 0.0160837514036
# Finished rnabase RF
# avg auc = 0.546108879024
# avg auprc = 0.0162956346574
# Finished rnabase Logistic
# avg auc = 0.476849864998
# avg auprc = 0.0255205756558
# Finished rnabase Lasso
# avg auc = 0.692135592682
# avg auprc = 0.0340900655439
# Finished rnabase KNN
# avg auc = 0.59029816594
# avg auprc = 0.125354345021
# Finished rnabase SVM
# avg auc = 0.643770629937
# avg auprc = 0.0418444198477
# Finished rnabase Ridge
# avg auc = 0.679587970824
# avg auprc = 0.0220387992882
# Finished rnabase RF
# avg auc = 0.545437259693
# avg auprc = 0.0109512246871
# Finished rnabase Logistic
# avg auc = 0.618703656464
# avg auprc = 0.020622145399
# Finished rnabase Lasso
# avg auc = 0.541260412784
# avg auprc = 0.0309965535822
# Finished rnabase KNN
# avg auc = 0.471987626885
# avg auprc = 0.1328478845
# Finished rnabase SVM
# avg auc = 0.534946528518
# avg auprc = 0.0288770704168
# Finished rnabase Ridge
# avg auc = 0.587499340557
# avg auprc = 0.0151569445821
# Finished rnabase RF
# avg auc = 0.513411441741
# avg auprc = 0.0221074152383
# Finished rnabase Logistic
# avg auc = 0.494196761109
# avg auprc = 0.0421453556462
# Finished rnabase Lasso
# avg auc = 0.638511309459
# avg auprc = 0.0577715132812
# Finished rnabase KNN
# avg auc = 0.560618789387
# avg auprc = 0.0532828922522
# Finished rnabase SVM
# avg auc = 0.598850553689
# avg auprc = 0.022430028978
# Finished rnabase Ridge
# avg auc = 0.695177343383
# avg auprc = 0.0267345157432
# Finished rnabase RF
# avg auc = 0.599123559891
# avg auprc = 0.0307761474489
# Finished rnabase Logistic
# avg auc = 0.604560991618
# avg auprc = 0.0449367311464
# Finished rnabase Lasso
# avg auc = 0.632867557868
# avg auprc = 0.0150295335954
# Finished rnabase KNN
# avg auc = 0.596686675487
# avg auprc = 0.0871337522662
# Finished rnabase SVM
# avg auc = 0.624446354867
# avg auprc = 0.0378171910397
# Finished rnabase Ridge
# avg auc = 0.725413548356
# avg auprc = 0.0418402413493
# Finished rnabase RF
# avg auc = 0.60354576464
# avg auprc = 0.0495721965383
# Finished rnabase Logistic
# avg auc = 0.641146904449
# avg auprc = 0.077958287564
# Finished rnabase Lasso
# avg auc = 0.630291945697
# avg auprc = 0.0151561738188
# Finished rnabase KNN
# avg auc = 0.513561778005
# avg auprc = 0.162593453028
# Finished rnabase SVM
# avg auc = 0.643103816314
# avg auprc = 0.0172809780084
# Finished rnabase Ridge
# avg auc = 0.650919883269
# avg auprc = 0.0224271020304
# Finished rnabase RF
# avg auc = 0.644261550452
# avg auprc = 0.0196061274419
# Finished rnabase Logistic
# avg auc = 0.637307639527
# avg auprc = 0.0201749021441
# Finished rnabase Lasso
# avg auc = 0.718793866081
# avg auprc = 0.109987613248
# Finished rnabase KNN
# avg auc = 0.496958214505
# avg auprc = 0.285032538697
# Finished rnabase SVM
# avg auc = 0.734692952153
# avg auprc = 0.135882702837
# Finished rnabase Ridge
# avg auc = 0.70670650368
# avg auprc = 0.0447504895018
# Finished rnabase RF
# avg auc = 0.745491975048
# avg auprc = 0.104428406536
# Finished rnabase Logistic
# avg auc = 0.652920932084
# avg auprc = 0.0744287000724
# Finished rnabase Lasso
# avg auc = 0.54746717177
# avg auprc = 0.0100856181018
# Finished rnabase KNN
# avg auc = 0.523785114391
# avg auprc = 0.0324115932692
# Finished rnabase SVM
# avg auc = 0.595162000791
# avg auprc = 0.0312430227397
# Finished rnabase Ridge
# avg auc = 0.663901180559
# avg auprc = 0.0218146387124
# Finished rnabase RF
# avg auc = 0.614870570079
# avg auprc = 0.0271316439627
# Finished rnabase Logistic
# avg auc = 0.605811292628
# avg auprc = 0.0329687194527
# Finished rnabase Lasso
# avg auc = 0.636539937317
# avg auprc = 0.0167092167502
# Finished rnabase KNN
# avg auc = 0.416438608025
# avg auprc = 0.106645624103
# Finished rnabase SVM
# avg auc = 0.639524377338
# avg auprc = 0.0184769184114
# Finished rnabase Ridge
# avg auc = 0.690466300946
# avg auprc = 0.0265400969004
# Finished rnabase RF
# avg auc = 0.642800735744
# avg auprc = 0.0231369751741
# Finished rnabase Logistic
# avg auc = 0.5
# avg auprc = 0.504272704134
# Finished rnabase Lasso
# avg auc = 0.587653453038
# avg auprc = 0.024434812355
# Finished rnabase KNN
# avg auc = 0.490152792984
# avg auprc = 0.00876764501891
# Finished rnabase SVM
# avg auc = 0.555731433883
# avg auprc = 0.0251188294115
# Finished rnabase Ridge
# avg auc = 0.62727335745
# avg auprc = 0.0260935863232
# Finished rnabase RF
# avg auc = 0.538095093289
# avg auprc = 0.0221208608143
# Finished rnabase Logistic
# avg auc = 0.475254229925
# avg auprc = 0.0355252764762
# Finished rnabase Lasso
# avg auc = 0.576297487197
# avg auprc = 0.0336424833801
# Finished rnabackbone KNN
# avg auc = 0.47574499657
# avg auprc = 0.105499111572
# Finished rnabackbone SVM
# avg auc = 0.536281720004
# avg auprc = 0.0195654560277
# Finished rnabackbone Ridge
# avg auc = 0.547899662164
# avg auprc = 0.017059306538
# Finished rnabackbone RF
# avg auc = 0.523149577542
# avg auprc = 0.0257020205449
# Finished rnabackbone Logistic
# avg auc = 0.438320592225
# avg auprc = 0.0363096802046
# Finished rnabackbone Lasso
# avg auc = 0.702624899275
# avg auprc = 0.0561235153311
# Finished rnabackbone KNN
# avg auc = 0.624744896607
# avg auprc = 0.109179420021
# Finished rnabackbone SVM
# avg auc = 0.648541982334
# avg auprc = 0.0341093486585
# Finished rnabackbone Ridge
# avg auc = 0.691007438906
# avg auprc = 0.03872035405
# Finished rnabackbone RF
# avg auc = 0.514770960981
# avg auprc = 0.0154671541104
# Finished rnabackbone Logistic
# avg auc = 0.605474851867
# avg auprc = 0.028143157079
# Finished rnabackbone Lasso
# avg auc = 0.568266529088
# avg auprc = 0.0395706938909
# Finished rnabackbone KNN
# avg auc = 0.51496379332
# avg auprc = 0.0631421759946
# Finished rnabackbone SVM
# avg auc = 0.545548026159
# avg auprc = 0.0321894841516
# Finished rnabackbone Ridge
# avg auc = 0.585733774659
# avg auprc = 0.0204983754775
# Finished rnabackbone RF
# avg auc = 0.546826659493
# avg auprc = 0.0348240711592
# Finished rnabackbone Logistic
# avg auc = 0.476803688821
# avg auprc = 0.0588427497508
# Finished rnabackbone Lasso
# avg auc = 0.611495574421
# avg auprc = 0.0468609050029
# Finished rnabackbone KNN
# avg auc = 0.623405900937
# avg auprc = 0.0702691224712
# Finished rnabackbone SVM
# avg auc = 0.612393659384
# avg auprc = 0.0437963766466
# Finished rnabackbone Ridge
# avg auc = 0.735482299653
# avg auprc = 0.0416866946172
# Finished rnabackbone RF
# avg auc = 0.615277800219
# avg auprc = 0.0581605739384
# Finished rnabackbone Logistic
# avg auc = 0.608286939871
# avg auprc = 0.0580505430875
# Finished rnabackbone Lasso
# avg auc = 0.647503421602
# avg auprc = 0.0343982746272
# Finished rnabackbone KNN
# avg auc = 0.58056399904
# avg auprc = 0.0783066179404
# Finished rnabackbone SVM
# avg auc = 0.664097954543
# avg auprc = 0.0589469955536
# Finished rnabackbone Ridge
# avg auc = 0.705571953567
# avg auprc = 0.0536186411733
# Finished rnabackbone RF
# avg auc = 0.623752391924
# avg auprc = 0.0529647008956
# Finished rnabackbone Logistic
# avg auc = 0.647225326253
# avg auprc = 0.0826189651044
# Finished rnabackbone Lasso
# avg auc = 0.633088023473
# avg auprc = 0.0190655956867
# Finished rnabackbone KNN
# avg auc = 0.60608088149
# avg auprc = 0.0246993845319
# Finished rnabackbone SVM
# avg auc = 0.635961774316
# avg auprc = 0.021948931623
# Finished rnabackbone Ridge
# avg auc = 0.617285521193
# avg auprc = 0.0235367637843
# Finished rnabackbone RF
# avg auc = 0.639554978447
# avg auprc = 0.0208721743013
# Finished rnabackbone Logistic
# avg auc = 0.600029819821
# avg auprc = 0.0211895749584
# Finished rnabackbone Lasso
# avg auc = 0.72193020892
# avg auprc = 0.0776263967306
# Finished rnabackbone KNN
# avg auc = 0.650095459505
# avg auprc = 0.190176543218
# Finished rnabackbone SVM
# avg auc = 0.760842376099
# avg auprc = 0.139899435261
# Finished rnabackbone Ridge
# avg auc = 0.740299869692
# avg auprc = 0.20087665583
# Finished rnabackbone RF
# avg auc = 0.773305368223
# avg auprc = 0.138886559155
# Finished rnabackbone Logistic
# avg auc = 0.564428637883
# avg auprc = 0.124406693578
# Finished rnabackbone Lasso
# avg auc = 0.490622279779
# avg auprc = 0.0124426241927
# Finished rnabackbone KNN
# avg auc = 0.567428785203
# avg auprc = 0.0570390365334
# Finished rnabackbone SVM
# avg auc = 0.608154060635
# avg auprc = 0.0348862555776
# Finished rnabackbone Ridge
# avg auc = 0.619144706218
# avg auprc = 0.0232791145977
# Finished rnabackbone RF
# avg auc = 0.597595300431
# avg auprc = 0.0339853925341
# Finished rnabackbone Logistic
# avg auc = 0.567665701831
# avg auprc = 0.0340425892828
# Finished rnabackbone Lasso
# avg auc = 0.64996602308
# avg auprc = 0.025775452839
# Finished rnabackbone KNN
# avg auc = 0.465668182147
# avg auprc = 0.158081869353
# Finished rnabackbone SVM
# avg auc = 0.641728485996
# avg auprc = 0.0294095976859
# Finished rnabackbone Ridge
# avg auc = 0.700082750566
# avg auprc = 0.0382200250858
# Finished rnabackbone RF
# avg auc = 0.643647214754
# avg auprc = 0.0281602478765
# Finished rnabackbone Logistic
# avg auc = 0.5
# avg auprc = 0.506055469476
# Finished rnabackbone Lasso
# avg auc = 0.608934450241
# avg auprc = 0.018106602231
# Finished rnabackbone KNN
# avg auc = 0.486171600061
# avg auprc = 0.0811734288919
# Finished rnabackbone SVM
# avg auc = 0.517500502507
# avg auprc = 0.0224792852336
# Finished rnabackbone Ridge
# avg auc = 0.626185003773
# avg auprc = 0.028282759106
# Finished rnabackbone RF
# avg auc = 0.526022842384
# avg auprc = 0.0249305780379
# Finished rnabackbone Logistic
# avg auc = 0.466330374652
# avg auprc = 0.0510917190461
# Finished rnabackbone Lasso
# avg auc = 0.581798999914
# avg auprc = 0.103818652519
# Finished peptide KNN
# avg auc = 0.614103937557
# avg auprc = 0.139354106713
# Finished peptide SVM
# avg auc = 0.605630828795
# avg auprc = 0.134759785209
# Finished peptide Ridge
# avg auc = 0.565788675466
# avg auprc = 0.0897459003605
# Finished peptide RF
# avg auc = 0.606201505181
# avg auprc = 0.129774162085
# Finished peptide Logistic
# avg auc = 0.625047519817
# avg auprc = 0.143196697791
# Finished peptide Lasso
# avg auc = 0.642874401106
# avg auprc = 0.145758651162
# Finished peptide KNN
# avg auc = 0.619475867996
# avg auprc = 0.143541040569
# Finished peptide SVM
# avg auc = 0.656338723208
# avg auprc = 0.146212879448
# Finished peptide Ridge
# avg auc = 0.621594789336
# avg auprc = 0.111750220353
# Finished peptide RF
# avg auc = 0.617637075805
# avg auprc = 0.101270220981
# Finished peptide Logistic
# avg auc = 0.636218027872
# avg auprc = 0.144903249074
# Finished peptide Lasso
# avg auc = 0.5864591572
# avg auprc = 0.132727944635
# Finished peptide KNN
# avg auc = 0.609305129966
# avg auprc = 0.131599641684
# Finished peptide SVM
# avg auc = 0.598298629577
# avg auprc = 0.122239270885
# Finished peptide Ridge
# avg auc = 0.568639365865
# avg auprc = 0.095131525683
# Finished peptide RF
# avg auc = 0.600156565554
# avg auprc = 0.129939790074
# Finished peptide Logistic
# avg auc = 0.611371974683
# avg auprc = 0.134968063497
# Finished peptide Lasso
# avg auc = 0.622368770476
# avg auprc = 0.13967633389
# Finished peptide KNN
# avg auc = 0.660650908473
# avg auprc = 0.170283122163
# Finished peptide SVM
# avg auc = 0.635037325443
# avg auprc = 0.138201070658
# Finished peptide Ridge
# avg auc = 0.610739829577
# avg auprc = 0.112238368073
# Finished peptide RF
# avg auc = 0.639401268719
# avg auprc = 0.150451134061
# Finished peptide Logistic
# avg auc = 0.645245330177
# avg auprc = 0.160265619946
# Finished peptide Lasso
# avg auc = 0.629683162598
# avg auprc = 0.15838898256
# Finished peptide KNN
# avg auc = 0.647832445411
# avg auprc = 0.187210660814
# Finished peptide SVM
# avg auc = 0.617774194548
# avg auprc = 0.153415381568
# Finished peptide Ridge
# avg auc = 0.636689297876
# avg auprc = 0.142867037788
# Finished peptide RF
# avg auc = 0.628862218322
# avg auprc = 0.161538376369
# Finished peptide Logistic
# avg auc = 0.657233710387
# avg auprc = 0.184226734507
# Finished peptide Lasso
# avg auc = 0.578260748103
# avg auprc = 0.076815880164
# Finished peptide KNN
# avg auc = 0.55657595992
# avg auprc = 0.0772099146212
# Finished peptide SVM
# avg auc = 0.576368082614
# avg auprc = 0.0765472988111
# Finished peptide Ridge
# avg auc = 0.591357338796
# avg auprc = 0.0953496285811
# Finished peptide RF
# avg auc = 0.583566242592
# avg auprc = 0.0773885797985
# Finished peptide Logistic
# avg auc = 0.542659708509
# avg auprc = 0.0627598818844
# Finished peptide Lasso
# avg auc = 0.553452949677
# avg auprc = 0.0889837477435
# Finished peptide KNN
# avg auc = 0.60201229249
# avg auprc = 0.119309605666
# Finished peptide SVM
# avg auc = 0.66261217344
# avg auprc = 0.121123720652
# Finished peptide Ridge
# avg auc = 0.401986642706
# avg auprc = 0.078042891769
# Finished peptide RF
# avg auc = 0.641769874181
# avg auprc = 0.136646637119
# Finished peptide Logistic
# avg auc = 0.5
# avg auprc = 0.527484056499
# Finished peptide Lasso
# avg auc = 0.581489142614
# avg auprc = 0.0922704130111
# Finished peptide KNN
# avg auc = 0.623228351412
# avg auprc = 0.136229052038
# Finished peptide SVM
# avg auc = 0.577550059131
# avg auprc = 0.104392575126
# Finished peptide Ridge
# avg auc = 0.587665216219
# avg auprc = 0.0861481217002
# Finished peptide RF
# avg auc = 0.588206759007
# avg auprc = 0.112087416106
# Finished peptide Logistic
# avg auc = 0.604765761169
# avg auprc = 0.123980670929
# Finished peptide Lasso
# avg auc = 0.560804672179
# avg auprc = 0.0709849328911
# Finished peptide KNN
# avg auc = 0.510245434051
# avg auprc = 0.248928435744
# Finished peptide SVM
# avg auc = 0.569761455747
# avg auprc = 0.0738107121481
# Finished peptide Ridge
# avg auc = 0.58350123084
# avg auprc = 0.0755550923814
# Finished peptide RF
# avg auc = 0.572587756796
# avg auprc = 0.0735113429525
# Finished peptide Logistic
# avg auc = 0.5
# avg auprc = 0.527484056499
# Finished peptide Lasso
# avg auc = 0.605774559656
# avg auprc = 0.102311075526
# Finished peptide KNN
# avg auc = 0.626044635041
# avg auprc = 0.132119666563
# Finished peptide SVM
# avg auc = 0.618267842127
# avg auprc = 0.128820092243
# Finished peptide Ridge
# avg auc = 0.574144435068
# avg auprc = 0.0870220971233
# Finished peptide RF
# avg auc = 0.625740234971
# avg auprc = 0.133300806086
# Finished peptide Logistic
# avg auc = 0.610355771706
# avg auprc = 0.139951941316
# Finished peptide Lasso
# avg auc = 0.606400391254
# avg auprc = 0.0799144657999
# Finished ion KNN
# avg auc = 0.607498466851
# avg auprc = 0.107818085175
# Finished ion SVM
# avg auc = 0.62200759258
# avg auprc = 0.0744031938105
# Finished ion Ridge
# avg auc = 0.582682527938
# avg auprc = 0.0673716731736
# Finished ion RF
# avg auc = 0.627544952125
# avg auprc = 0.0878440566885
# Finished ion Logistic
# avg auc = 0.603374710988
# avg auprc = 0.0885190809606
# Finished ion Lasso
# avg auc = 0.630157839011
# avg auprc = 0.135974841035
# Finished ion KNN
# avg auc = 0.594683203178
# avg auprc = 0.0877848389992
# Finished ion SVM
# avg auc = 0.626460775426
# avg auprc = 0.114662366166
# Finished ion Ridge
# avg auc = 0.632250515031
# avg auprc = 0.144342319406
# Finished ion RF
# avg auc = 0.605458105689
# avg auprc = 0.0725972873991
# Finished ion Logistic
# avg auc = 0.602761679805
# avg auprc = 0.0801306961808
# Finished ion Lasso
# avg auc = 0.582662955886
# avg auprc = 0.0693461568686
# Finished ion KNN
# avg auc = 0.505811581006
# avg auprc = 0.198286278053
# Finished ion SVM
# avg auc = 0.580110073651
# avg auprc = 0.0709850719592
# Finished ion Ridge
# avg auc = 0.569272666208
# avg auprc = 0.0656273592378
# Finished ion RF
# avg auc = 0.582639432106
# avg auprc = 0.0775497392745
# Finished ion Logistic
# avg auc = 0.552885026862
# avg auprc = 0.0723800035617
# Finished ion Lasso
# avg auc = 0.703447752459
# avg auprc = 0.177731061632
# Finished ion KNN
# avg auc = 0.697384868409
# avg auprc = 0.159534990669
# Finished ion SVM
# avg auc = 0.705743875688
# avg auprc = 0.160402770041
# Finished ion Ridge
# avg auc = 0.690604161803
# avg auprc = 0.16913946244
# Finished ion RF
# avg auc = 0.704159267139
# avg auprc = 0.157819287287
# Finished ion Logistic
# avg auc = 0.628486073073
# avg auprc = 0.124143813925
# Finished ion Lasso
# avg auc = 0.640110476395
# avg auprc = 0.106940150762
# Finished ion KNN
# avg auc = 0.636923881352
# avg auprc = 0.0945625272473
# Finished ion SVM
# avg auc = 0.637091511114
# avg auprc = 0.101385114978
# Finished ion Ridge
# avg auc = 0.627208120641
# avg auprc = 0.115388409993
# Finished ion RF
# avg auc = 0.63804575068
# avg auprc = 0.101634153544
# Finished ion Logistic
# avg auc = 0.644927034973
# avg auprc = 0.105746512098
# Finished ion Lasso
# avg auc = 0.625194904343
# avg auprc = 0.0738339224889
# Finished ion KNN
# avg auc = 0.561886830776
# avg auprc = 0.111822265288
# Finished ion SVM
# avg auc = 0.632315410945
# avg auprc = 0.0754237870913
# Finished ion Ridge
# avg auc = 0.667474613256
# avg auprc = 0.113207031289
# Finished ion RF
# avg auc = 0.642118872031
# avg auprc = 0.0763837172474
# Finished ion Logistic
# avg auc = 0.585328806027
# avg auprc = 0.0575669652391
# Finished ion Lasso
# avg auc = 0.503102964323
# avg auprc = 0.0803257541959
# Finished ion KNN
# avg auc = 0.54348419038
# avg auprc = 0.151904708311
# Finished ion SVM
# avg auc = 0.594225180007
# avg auprc = 0.1032148609
# Finished ion Ridge
# avg auc = 0.288496552191
# avg auprc = 0.0418329994224
# Finished ion RF
# avg auc = 0.605794221632
# avg auprc = 0.11136712805
# Finished ion Logistic
# avg auc = 0.5
# avg auprc = 0.521651725559
# Finished ion Lasso
# avg auc = 0.618641633457
# avg auprc = 0.0880166266716
# Finished ion KNN
# avg auc = 0.63065692756
# avg auprc = 0.0881585228115
# Finished ion SVM
# avg auc = 0.627243092306
# avg auprc = 0.0866095375501
# Finished ion Ridge
# avg auc = 0.63329672077
# avg auprc = 0.108839890129
# Finished ion RF
# avg auc = 0.623147687086
# avg auprc = 0.0885200991143
# Finished ion Logistic
# avg auc = 0.572089560586
# avg auprc = 0.0755775380147
# Finished ion Lasso
# avg auc = 0.709901981812
# avg auprc = 0.211120565776
# Finished ion KNN
# avg auc = 0.701662899824
# avg auprc = 0.219781917006
# Finished ion SVM
# avg auc = 0.711502866622
# avg auprc = 0.22989792787
# Finished ion Ridge
# avg auc = 0.696043428755
# avg auprc = 0.177939959562
# Finished ion RF
# avg auc = 0.710439837396
# avg auprc = 0.226894323608
# Finished ion Logistic
# avg auc = 0.5
# avg auprc = 0.521651725559
# Finished ion Lasso
# avg auc = 0.552060532954
# avg auprc = 0.0783098472521
# Finished ion KNN
# avg auc = 0.46455991945
# avg auprc = 0.232541060595
# Finished ion SVM
# avg auc = 0.560289090836
# avg auprc = 0.0644635171222
# Finished ion Ridge
# avg auc = 0.524924502989
# avg auprc = 0.0507767256663
# Finished ion RF
# avg auc = 0.571495247301
# avg auprc = 0.0700708207315
# Finished ion Logistic
# avg auc = 0.544317022143
# avg auprc = 0.0663093760954
# Finished ion Lasso
# avg auc = 0.578413368762
# avg auprc = 0.0791700256924
# Finished metabolite KNN
# avg auc = 0.583755208619
# avg auprc = 0.0990077804818
# Finished metabolite SVM
# avg auc = 0.597978732389
# avg auprc = 0.0887930728466
# Finished metabolite Ridge
# avg auc = 0.544991136562
# avg auprc = 0.0639289362125
# Finished metabolite RF
# avg auc = 0.596700112677
# avg auprc = 0.0868857891697
# Finished metabolite Logistic
# avg auc = 0.574372807957
# avg auprc = 0.0894529477046
# Finished metabolite Lasso
# avg auc = 0.545534223722
# avg auprc = 0.0701264953682
# Finished metabolite KNN
# avg auc = 0.49628610319
# avg auprc = 0.28158015729
# Finished metabolite SVM
# avg auc = 0.573277537766
# avg auprc = 0.075465335609
# Finished metabolite Ridge
# avg auc = 0.52742120557
# avg auprc = 0.0623057507533
# Finished metabolite RF
# avg auc = 0.47920960879
# avg auprc = 0.0553958793031
# Finished metabolite Logistic
# avg auc = 0.45097565295
# avg auprc = 0.0527648692839
# Finished metabolite Lasso
# avg auc = 0.519065628231
# avg auprc = 0.0684032735177
# Finished metabolite KNN
# avg auc = 0.502699979133
# avg auprc = 0.147337426596
# Finished metabolite SVM
# avg auc = 0.513945595847
# avg auprc = 0.0639762747058
# Finished metabolite Ridge
# avg auc = 0.515650993925
# avg auprc = 0.0594149297023
# Finished metabolite RF
# avg auc = 0.522500058863
# avg auprc = 0.0684190380827
# Finished metabolite Logistic
# avg auc = 0.513816821614
# avg auprc = 0.0787552007068
# Finished metabolite Lasso
# avg auc = 0.602631559591
# avg auprc = 0.0866047184591
# Finished metabolite KNN
# avg auc = 0.584260451273
# avg auprc = 0.0936785523818
# Finished metabolite SVM
# avg auc = 0.591007396166
# avg auprc = 0.0847797361325
# Finished metabolite Ridge
# avg auc = 0.575852647528
# avg auprc = 0.0755908975936
# Finished metabolite RF
# avg auc = 0.585478441833
# avg auprc = 0.0842595989738
# Finished metabolite Logistic
# avg auc = 0.538834004826
# avg auprc = 0.0826427507182
# Finished metabolite Lasso
# avg auc = 0.563037871288
# avg auprc = 0.0807819903344
# Finished metabolite KNN
# avg auc = 0.578265195716
# avg auprc = 0.0904143978164
# Finished metabolite SVM
# avg auc = 0.56801657385
# avg auprc = 0.0819078729835
# Finished metabolite Ridge
# avg auc = 0.544998337094
# avg auprc = 0.0688001970252
# Finished metabolite RF
# avg auc = 0.566352007378
# avg auprc = 0.0809328481083
# Finished metabolite Logistic
# avg auc = 0.559782814056
# avg auprc = 0.0861130742994
# Finished metabolite Lasso
# avg auc = 0.597091731857
# avg auprc = 0.0846287310624
# Finished metabolite KNN
# avg auc = 0.579606088577
# avg auprc = 0.0674733955408
# Finished metabolite SVM
# avg auc = 0.608451273359
# avg auprc = 0.0874423455171
# Finished metabolite Ridge
# avg auc = 0.591840190429
# avg auprc = 0.0904045609857
# Finished metabolite RF
# avg auc = 0.616753629344
# avg auprc = 0.0892043935844
# Finished metabolite Logistic
# avg auc = 0.596265540636
# avg auprc = 0.0747399004088
# Finished metabolite Lasso
# avg auc = 0.447531670602
# avg auprc = 0.0646820492891
# Finished metabolite KNN
# avg auc = 0.498246318608
# avg auprc = 0.476717842208
# Finished metabolite SVM
# avg auc = 0.481881741958
# avg auprc = 0.059818286407
# Finished metabolite Ridge
# avg auc = 0.260025928517
# avg auprc = 0.0364980273266
# Finished metabolite RF
# avg auc = 0.45595954791
# avg auprc = 0.0566982015729
# Finished metabolite Logistic
# avg auc = 0.5
# avg auprc = 0.526717842208
# Finished metabolite Lasso
# avg auc = 0.516429019684
# avg auprc = 0.0758519616224
# Finished metabolite KNN
# avg auc = 0.529842849303
# avg auprc = 0.117488800965
# Finished metabolite SVM
# avg auc = 0.527380216891
# avg auprc = 0.067565418053
# Finished metabolite Ridge
# avg auc = 0.543741661628
# avg auprc = 0.0626760449533
# Finished metabolite RF
# avg auc = 0.530850108312
# avg auprc = 0.0674747463274
# Finished metabolite Logistic
# avg auc = 0.526619520604
# avg auprc = 0.0736390874873
# Finished metabolite Lasso
# avg auc = 0.641783960838
# avg auprc = 0.110023625372
# Finished metabolite KNN
# avg auc = 0.59511355
# avg auprc = 0.0999598108402
# Finished metabolite SVM
# avg auc = 0.610656983857
# avg auprc = 0.102003360218
# Finished metabolite Ridge
# avg auc = 0.637611339794
# avg auprc = 0.10740025365
# Finished metabolite RF
# avg auc = 0.603099985301
# avg auprc = 0.100339296968
# Finished metabolite Logistic
# avg auc = 0.5
# avg auprc = 0.526717842208
# Finished metabolite Lasso
# avg auc = 0.501387653694
# avg auprc = 0.0750148900831
# Finished metabolite KNN
# avg auc = 0.488390005535
# avg auprc = 0.108267685814
# Finished metabolite SVM
# avg auc = 0.514864537901
# avg auprc = 0.062824155097
# Finished metabolite Ridge
# avg auc = 0.483173190337
# avg auprc = 0.0571076969012
# Finished metabolite RF
# avg auc = 0.517111033065
# avg auprc = 0.070209155423
# Finished metabolite Logistic
# avg auc = 0.511049833123
# avg auprc = 0.0792424464948
# Finished metabolite Lasso

# %%
## Train/test with all groups except one

for ligand in ligands:
    n_features = ligands_features_df[ligand].shape[1]
    for group in features_groups:
        # Include features in the group
        features_included = np.ones([n_features]).astype(bool)
        features_included[features_groups[group]] = False
        
        #Initialize dictionary
        pred_dict = defaultdict(list)
        auc_dict = defaultdict(list)
        auprc_dict = defaultdict(list)
        
        # Run classifier
        test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], non_binding_positions, ligand, "RandomUnderSampler", features_included)

        pred_df = pd.DataFrame.from_dict(pred_dict)
        auc_df = pd.DataFrame.from_dict(auc_dict)
        auprc_df = pd.DataFrame.from_dict(auprc_dict)

        #Save to file
        pred_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_except_0.1.csv", sep='\t')
        auc_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_except_0.1_auc.csv", sep='\t')
        auprc_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_except_0.1_auprc.csv", sep='\t')
# Out:
# avg auc = 0.814565819735
# avg auprc = 0.192756804642
# Finished dna KNN
# avg auc = 0.835090990348
# avg auprc = 0.173970932746
# Finished dna SVM
# avg auc = 0.859977747516
# avg auprc = 0.154337272846
# Finished dna Ridge
# avg auc = 0.941330202032
# avg auprc = 0.406146730726
# Finished dna RF
# avg auc = 0.729297598791
# avg auprc = 0.0901585031407
# Finished dna Logistic
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# avg auc = 0.784781241408
# avg auprc = 0.141583628992
# Finished dna Lasso
# avg auc = 0.820083094653
# avg auprc = 0.193837183323
# Finished dna KNN
# avg auc = 0.838407975866
# avg auprc = 0.157872939196
# Finished dna SVM
# avg auc = 0.864605982702
# avg auprc = 0.163841119411
# Finished dna Ridge
# avg auc = 0.934250171587
# avg auprc = 0.371487997821
# Finished dna RF
# avg auc = 0.859525734223
# avg auprc = 0.19680021758
# Finished dna Logistic
# avg auc = 0.778684943722
# avg auprc = 0.136919459879
# Finished dna Lasso
# avg auc = 0.8181646965
# avg auprc = 0.18405811867
# Finished dna KNN
# avg auc = 0.837682595343
# avg auprc = 0.170213238444
# Finished dna SVM
# avg auc = 0.867171840476
# avg auprc = 0.185269724593
# Finished dna Ridge
# avg auc = 0.942087941964
# avg auprc = 0.413116035798
# Finished dna RF
# avg auc = 0.716291347073
# avg auprc = 0.0891231672439
# Finished dna Logistic
# avg auc = 0.78653073571
# avg auprc = 0.13249135799
# Finished dna Lasso
# avg auc = 0.824913310669
# avg auprc = 0.185059470486
# Finished dna KNN
# avg auc = 0.83716774012
# avg auprc = 0.14460893992
# Finished dna SVM
# avg auc = 0.868546036452
# avg auprc = 0.17525236284
# Finished dna Ridge
# avg auc = 0.93899277607
# avg auprc = 0.373028657227
# Finished dna RF
# avg auc = 0.704316306994
# avg auprc = 0.082794939856
# Finished dna Logistic
# avg auc = 0.780075548756
# avg auprc = 0.137738290063
# Finished dna Lasso
# avg auc = 0.811384968642
# avg auprc = 0.169707659985
# Finished dna KNN
# avg auc = 0.835711183081
# avg auprc = 0.164209699593
# Finished dna SVM
# avg auc = 0.870388652126
# avg auprc = 0.188551686147
# Finished dna Ridge
# avg auc = 0.932814428112
# avg auprc = 0.357498675916
# Finished dna RF
# avg auc = 0.701190592569
# avg auprc = 0.0845492722911
# Finished dna Logistic
# avg auc = 0.77014748362
# avg auprc = 0.129773360884
# Finished dna Lasso
# avg auc = 0.797393077238
# avg auprc = 0.147642275456
# Finished dna KNN
# avg auc = 0.82328329329
# avg auprc = 0.148996286043
# Finished dna SVM
# avg auc = 0.849108435246
# avg auprc = 0.158959723045
# Finished dna Ridge
# avg auc = 0.943386965498
# avg auprc = 0.378967072982
# Finished dna RF
# avg auc = 0.696187982596
# avg auprc = 0.0894536407497
# Finished dna Logistic
# avg auc = 0.7464270286
# avg auprc = 0.0998979140951
# Finished dna Lasso
# avg auc = 0.792953900735
# avg auprc = 0.153532795091
# Finished dna KNN
# avg auc = 0.812900485268
# avg auprc = 0.14422055724
# Finished dna SVM
# avg auc = 0.828430992911
# avg auprc = 0.124984960028
# Finished dna Ridge
# avg auc = 0.880227978682
# avg auprc = 0.272215691835
# Finished dna RF
# avg auc = 0.71382758621
# avg auprc = 0.0903856798211
# Finished dna Logistic
# avg auc = 0.789586572964
# avg auprc = 0.14159356505
# Finished dna Lasso
# avg auc = 0.834267505851
# avg auprc = 0.203582879766
# Finished dna KNN
# avg auc = 0.839858840478
# avg auprc = 0.172834884269
# Finished dna SVM
# avg auc = 0.890324809239
# avg auprc = 0.196497220357
# Finished dna Ridge
# avg auc = 0.934678844301
# avg auprc = 0.370875322758
# Finished dna RF
# avg auc = 0.719571166468
# avg auprc = 0.0913383458765
# Finished dna Logistic
# avg auc = 0.788522496878
# avg auprc = 0.13455759286
# Finished dna Lasso
# avg auc = 0.816270561595
# avg auprc = 0.198080759557
# Finished dna KNN
# avg auc = 0.837643864421
# avg auprc = 0.171653854131
# Finished dna SVM
# avg auc = 0.865331597393
# avg auprc = 0.183049075853
# Finished dna Ridge
# avg auc = 0.935458288388
# avg auprc = 0.383863527718
# Finished dna RF
# avg auc = 0.710213040406
# avg auprc = 0.0914956804197
# Finished dna Logistic
# avg auc = 0.788651275356
# avg auprc = 0.14611600255
# Finished dna Lasso
# avg auc = 0.820388044064
# avg auprc = 0.179380100098
# Finished dna KNN
# avg auc = 0.834439565078
# avg auprc = 0.159063033283
# Finished dna SVM
# avg auc = 0.867077888536
# avg auprc = 0.161036108386
# Finished dna Ridge
# avg auc = 0.934543464674
# avg auprc = 0.367984498836
# Finished dna RF
# avg auc = 0.718050797631
# avg auprc = 0.0890059086975
# Finished dna Logistic
# avg auc = 0.786872642295
# avg auprc = 0.134509308037
# Finished dna Lasso
# avg auc = 0.807520115423
# avg auprc = 0.0920916619183
# Finished dnabase KNN
# avg auc = 0.811679002538
# avg auprc = 0.0653678715792
# Finished dnabase SVM
# avg auc = 0.792820875687
# avg auprc = 0.0417643419627
# Finished dnabase Ridge
# avg auc = 0.910868974929
# avg auprc = 0.218855634783
# Finished dnabase RF
# avg auc = 0.712559455596
# avg auprc = 0.07227581494
# Finished dnabase Logistic
# avg auc = 0.770314794682
# avg auprc = 0.0764263528425
# Finished dnabase Lasso
# avg auc = 0.812142065054
# avg auprc = 0.109436342009
# Finished dnabase KNN
# avg auc = 0.825054791652
# avg auprc = 0.0537329329171
# Finished dnabase SVM
# avg auc = 0.803678736819
# avg auprc = 0.0528971139115
# Finished dnabase Ridge
# avg auc = 0.914450333198
# avg auprc = 0.237354167546
# Finished dnabase RF
# avg auc = 0.817466913443
# avg auprc = 0.0872780081005
# Finished dnabase Logistic
# avg auc = 0.75734761116
# avg auprc = 0.0647381616881
# Finished dnabase Lasso
# avg auc = 0.818537353128
# avg auprc = 0.101968230295
# Finished dnabase KNN
# avg auc = 0.818006011257
# avg auprc = 0.0613004164403
# Finished dnabase SVM
# avg auc = 0.804818699993
# avg auprc = 0.046195151645
# Finished dnabase Ridge
# avg auc = 0.917638150458
# avg auprc = 0.222397312488
# Finished dnabase RF
# avg auc = 0.712902784193
# avg auprc = 0.0631892091001
# Finished dnabase Logistic
# avg auc = 0.759873392059
# avg auprc = 0.0673660051332
# Finished dnabase Lasso
# avg auc = 0.821304797534
# avg auprc = 0.100500057674
# Finished dnabase KNN
# avg auc = 0.819649445542
# avg auprc = 0.050981052465
# Finished dnabase SVM
# avg auc = 0.814506169891
# avg auprc = 0.0552707692879
# Finished dnabase Ridge
# avg auc = 0.918617642245
# avg auprc = 0.225110006641
# Finished dnabase RF
# avg auc = 0.699771154028
# avg auprc = 0.0663435725285
# Finished dnabase Logistic
# avg auc = 0.75516930345
# avg auprc = 0.0633147025785
# Finished dnabase Lasso
# avg auc = 0.797914786504
# avg auprc = 0.087866975943
# Finished dnabase KNN
# avg auc = 0.821454819776
# avg auprc = 0.0662605373948
# Finished dnabase SVM
# avg auc = 0.834075726333
# avg auprc = 0.0620432857778
# Finished dnabase Ridge
# avg auc = 0.911764705638
# avg auprc = 0.181054796374
# Finished dnabase RF
# avg auc = 0.70192934548
# avg auprc = 0.0614407107984
# Finished dnabase Logistic
# avg auc = 0.75833341679
# avg auprc = 0.0539832607388
# Finished dnabase Lasso
# avg auc = 0.801708016244
# avg auprc = 0.0861528335321
# Finished dnabase KNN
# avg auc = 0.811044646003
# avg auprc = 0.0684362056371
# Finished dnabase SVM
# avg auc = 0.79506841246
# avg auprc = 0.0423425652978
# Finished dnabase Ridge
# avg auc = 0.917176733604
# avg auprc = 0.202829911156
# Finished dnabase RF
# avg auc = 0.683646235502
# avg auprc = 0.0553028946786
# Finished dnabase Logistic
# avg auc = 0.738339841679
# avg auprc = 0.065873726475
# Finished dnabase Lasso
# avg auc = 0.789419934112
# avg auprc = 0.0762373759994
# Finished dnabase KNN
# avg auc = 0.79180258548
# avg auprc = 0.0549272991398
# Finished dnabase SVM
# avg auc = 0.734711753593
# avg auprc = 0.0318959178212
# Finished dnabase Ridge
# avg auc = 0.865066465681
# avg auprc = 0.15429347497
# Finished dnabase RF
# avg auc = 0.720209354985
# avg auprc = 0.0650933494445
# Finished dnabase Logistic
# avg auc = 0.755630195914
# avg auprc = 0.0633342355349
# Finished dnabase Lasso
# avg auc = 0.822304892241
# avg auprc = 0.0842984378483
# Finished dnabase KNN
# avg auc = 0.827108973719
# avg auprc = 0.0545875684336
# Finished dnabase SVM
# avg auc = 0.839475889426
# avg auprc = 0.0582338579584
# Finished dnabase Ridge
# avg auc = 0.92150511843
# avg auprc = 0.225508969381
# Finished dnabase RF
# avg auc = 0.707819198867
# avg auprc = 0.0673784629223
# Finished dnabase Logistic
# avg auc = 0.753370317629
# avg auprc = 0.0622246035383
# Finished dnabase Lasso
# avg auc = 0.816968145417
# avg auprc = 0.0948409893087
# Finished dnabase KNN
# avg auc = 0.821974343478
# avg auprc = 0.0540914347437
# Finished dnabase SVM
# avg auc = 0.808059556165
# avg auprc = 0.0473718223986
# Finished dnabase Ridge
# avg auc = 0.921077602356
# avg auprc = 0.240497206141
# Finished dnabase RF
# avg auc = 0.702288538797
# avg auprc = 0.0603493747057
# Finished dnabase Logistic
# avg auc = 0.766650026931
# avg auprc = 0.0677357864321
# Finished dnabase Lasso
# avg auc = 0.81375001301
# avg auprc = 0.0874052115382
# Finished dnabase KNN
# avg auc = 0.820917130685
# avg auprc = 0.0631133880851
# Finished dnabase SVM
# avg auc = 0.80587009528
# avg auprc = 0.0567209807188
# Finished dnabase Ridge
# avg auc = 0.922798046815
# avg auprc = 0.230145888864
# Finished dnabase RF
# avg auc = 0.705959733609
# avg auprc = 0.0708302139343
# Finished dnabase Logistic
# avg auc = 0.778495184546
# avg auprc = 0.053161188757
# Finished dnabase Lasso
# avg auc = 0.816254471634
# avg auprc = 0.187867906326
# Finished dnabackbone KNN
# avg auc = 0.834217925252
# avg auprc = 0.144926513588
# Finished dnabackbone SVM
# avg auc = 0.858209537
# avg auprc = 0.133631384955
# Finished dnabackbone Ridge
# avg auc = 0.927033851005
# avg auprc = 0.373971705176
# Finished dnabackbone RF
# avg auc = 0.720097226831
# avg auprc = 0.0788650054876
# Finished dnabackbone Logistic
# avg auc = 0.795785562675
# avg auprc = 0.128680154418
# Finished dnabackbone Lasso
# avg auc = 0.818201768167
# avg auprc = 0.179996723001
# Finished dnabackbone KNN
# avg auc = 0.837432874736
# avg auprc = 0.143956707411
# Finished dnabackbone SVM
# avg auc = 0.849514692593
# avg auprc = 0.1442805967
# Finished dnabackbone Ridge
# avg auc = 0.932578675856
# avg auprc = 0.372675519884
# Finished dnabackbone RF
# avg auc = 0.846711735377
# avg auprc = 0.155360019035
# Finished dnabackbone Logistic
# avg auc = 0.794361574307
# avg auprc = 0.142488688147
# Finished dnabackbone Lasso
# avg auc = 0.816338678789
# avg auprc = 0.178445013131
# Finished dnabackbone KNN
# avg auc = 0.841069345478
# avg auprc = 0.151454369615
# Finished dnabackbone SVM
# avg auc = 0.860691272294
# avg auprc = 0.155616582722
# Finished dnabackbone Ridge
# avg auc = 0.934958745256
# avg auprc = 0.365457913398
# Finished dnabackbone RF
# avg auc = 0.729364411979
# avg auprc = 0.0838854332769
# Finished dnabackbone Logistic
# avg auc = 0.798588416597
# avg auprc = 0.132653875444
# Finished dnabackbone Lasso
# avg auc = 0.822493003052
# avg auprc = 0.191874150918
# Finished dnabackbone KNN
# avg auc = 0.839310246319
# avg auprc = 0.12818997341
# Finished dnabackbone SVM
# avg auc = 0.865980070629
# avg auprc = 0.150264533059
# Finished dnabackbone Ridge
# avg auc = 0.94021428916
# avg auprc = 0.380961385745
# Finished dnabackbone RF
# avg auc = 0.692579704329
# avg auprc = 0.0732448346777
# Finished dnabackbone Logistic
# avg auc = 0.793480154199
# avg auprc = 0.125483250064
# Finished dnabackbone Lasso
# avg auc = 0.806175883295
# avg auprc = 0.176326606954
# Finished dnabackbone KNN
# avg auc = 0.836244855754
# avg auprc = 0.136894615728
# Finished dnabackbone SVM
# avg auc = 0.862997807517
# avg auprc = 0.151149212428
# Finished dnabackbone Ridge
# avg auc = 0.923475909835
# avg auprc = 0.333210979395
# Finished dnabackbone RF
# avg auc = 0.719373739725
# avg auprc = 0.079753544238
# Finished dnabackbone Logistic
# avg auc = 0.780507082917
# avg auprc = 0.130223346945
# Finished dnabackbone Lasso
# avg auc = 0.804639641152
# avg auprc = 0.133963420563
# Finished dnabackbone KNN
# avg auc = 0.827042523287
# avg auprc = 0.115905856443
# Finished dnabackbone SVM
# avg auc = 0.85143333791
# avg auprc = 0.130715605264
# Finished dnabackbone Ridge
# avg auc = 0.94122401556
# avg auprc = 0.37400798826
# Finished dnabackbone RF
# avg auc = 0.712103695061
# avg auprc = 0.0791605773543
# Finished dnabackbone Logistic
# avg auc = 0.766859852317
# avg auprc = 0.102688630564
# Finished dnabackbone Lasso
# avg auc = 0.800856805842
# avg auprc = 0.154409541684
# Finished dnabackbone KNN
# avg auc = 0.818888284498
# avg auprc = 0.114309434412
# Finished dnabackbone SVM
# avg auc = 0.82773622064
# avg auprc = 0.11642311534
# Finished dnabackbone Ridge
# avg auc = 0.871038488011
# avg auprc = 0.266926702804
# Finished dnabackbone RF
# avg auc = 0.715452137231
# avg auprc = 0.0775661355244
# Finished dnabackbone Logistic
# avg auc = 0.803922992896
# avg auprc = 0.131106171645
# Finished dnabackbone Lasso
# avg auc = 0.822310591344
# avg auprc = 0.174586703985
# Finished dnabackbone KNN
# avg auc = 0.841617075959
# avg auprc = 0.145368383858
# Finished dnabackbone SVM
# avg auc = 0.875683746938
# avg auprc = 0.165453273588
# Finished dnabackbone Ridge
# avg auc = 0.935572262968
# avg auprc = 0.355883825725
# Finished dnabackbone RF
# avg auc = 0.71836160387
# avg auprc = 0.0814541508797
# Finished dnabackbone Logistic
# avg auc = 0.80218881141
# avg auprc = 0.132247237932
# Finished dnabackbone Lasso
# avg auc = 0.815757970339
# avg auprc = 0.184194289955
# Finished dnabackbone KNN
# avg auc = 0.837570177426
# avg auprc = 0.140890236901
# Finished dnabackbone SVM
# avg auc = 0.863250075449
# avg auprc = 0.14301172977
# Finished dnabackbone Ridge
# avg auc = 0.931044112548
# avg auprc = 0.348309610466
# Finished dnabackbone RF
# avg auc = 0.7104162864
# avg auprc = 0.0820989417685
# Finished dnabackbone Logistic
# avg auc = 0.80129758562
# avg auprc = 0.132186201337
# Finished dnabackbone Lasso
# avg auc = 0.819317892349
# avg auprc = 0.17185004893
# Finished dnabackbone KNN
# avg auc = 0.834900627997
# avg auprc = 0.134470058474
# Finished dnabackbone SVM
# avg auc = 0.864744900604
# avg auprc = 0.138121004387
# Finished dnabackbone Ridge
# avg auc = 0.934289701352
# avg auprc = 0.373454491305
# Finished dnabackbone RF
# avg auc = 0.724485618822
# avg auprc = 0.0825225889265
# Finished dnabackbone Logistic
# avg auc = 0.800087579073
# avg auprc = 0.124832274711
# Finished dnabackbone Lasso
# avg auc = 0.804961764285
# avg auprc = 0.0777367397466
# Finished rna KNN
# avg auc = 0.824259336824
# avg auprc = 0.110691592666
# Finished rna SVM
# avg auc = 0.858309146089
# avg auprc = 0.108573285313
# Finished rna Ridge
# avg auc = 0.960146918752
# avg auprc = 0.28870039602
# Finished rna RF
# avg auc = 0.695127362224
# avg auprc = 0.0614049873504
# Finished rna Logistic
# avg auc = 0.766753653618
# avg auprc = 0.0742469578072
# Finished rna Lasso
# avg auc = 0.808121497294
# avg auprc = 0.0753809749575
# Finished rna KNN
# avg auc = 0.825097347488
# avg auprc = 0.108430127803
# Finished rna SVM
# avg auc = 0.858149337929
# avg auprc = 0.111131012151
# Finished rna Ridge
# avg auc = 0.957841872462
# avg auprc = 0.298042371617
# Finished rna RF
# avg auc = 0.855263650609
# avg auprc = 0.114929559517
# Finished rna Logistic
# avg auc = 0.752330874563
# avg auprc = 0.0867244484217
# Finished rna Lasso
# avg auc = 0.805992859741
# avg auprc = 0.0809558061774
# Finished rna KNN
# avg auc = 0.825220872438
# avg auprc = 0.109154385218
# Finished rna SVM
# avg auc = 0.868816959982
# avg auprc = 0.119625405292
# Finished rna Ridge
# avg auc = 0.955100654859
# avg auprc = 0.256749881485
# Finished rna RF
# avg auc = 0.689622470118
# avg auprc = 0.0581677302187
# Finished rna Logistic
# avg auc = 0.767412031479
# avg auprc = 0.0735967091415
# Finished rna Lasso
# avg auc = 0.811846769613
# avg auprc = 0.0839769622215
# Finished rna KNN
# avg auc = 0.828779414374
# avg auprc = 0.114720692814
# Finished rna SVM
# avg auc = 0.874938338631
# avg auprc = 0.111438835652
# Finished rna Ridge
# avg auc = 0.959080395548
# avg auprc = 0.269735983318
# Finished rna RF
# avg auc = 0.686771596463
# avg auprc = 0.0665413412337
# Finished rna Logistic
# avg auc = 0.759316754151
# avg auprc = 0.0737596721516
# Finished rna Lasso
# avg auc = 0.791185074391
# avg auprc = 0.0695126400711
# Finished rna KNN
# avg auc = 0.812089470765
# avg auprc = 0.079499455913
# Finished rna SVM
# avg auc = 0.871304769498
# avg auprc = 0.116738644241
# Finished rna Ridge
# avg auc = 0.957595405354
# avg auprc = 0.245630979469
# Finished rna RF
# avg auc = 0.666568492365
# avg auprc = 0.0433873509041
# Finished rna Logistic
# avg auc = 0.704264672376
# avg auprc = 0.0630376070579
# Finished rna Lasso
# avg auc = 0.797891641479
# avg auprc = 0.0684821950021
# Finished rna KNN
# avg auc = 0.807898630378
# avg auprc = 0.108667728515
# Finished rna SVM
# avg auc = 0.853859121543
# avg auprc = 0.107612206862
# Finished rna Ridge
# avg auc = 0.963783574616
# avg auprc = 0.253803507852
# Finished rna RF
# avg auc = 0.674429282734
# avg auprc = 0.0586616895505
# Finished rna Logistic
# avg auc = 0.749264954541
# avg auprc = 0.0654861658852
# Finished rna Lasso
# avg auc = 0.768896168061
# avg auprc = 0.0668674901773
# Finished rna KNN
# avg auc = 0.761102471012
# avg auprc = 0.0890812522949
# Finished rna SVM
# avg auc = 0.804125171583
# avg auprc = 0.0749522944571
# Finished rna Ridge
# avg auc = 0.892810300217
# avg auprc = 0.151390120262
# Finished rna RF
# avg auc = 0.691389934989
# avg auprc = 0.0611174470125
# Finished rna Logistic
# avg auc = 0.765622430845
# avg auprc = 0.080866795665
# Finished rna Lasso
# avg auc = 0.825863736575
# avg auprc = 0.0935949162475
# Finished rna KNN
# avg auc = 0.826123198723
# avg auprc = 0.11365253796
# Finished rna SVM
# avg auc = 0.884697760309
# avg auprc = 0.130523877897
# Finished rna Ridge
# avg auc = 0.959465761189
# avg auprc = 0.303324594135
# Finished rna RF
# avg auc = 0.688863147489
# avg auprc = 0.0655934044907
# Finished rna Logistic
# avg auc = 0.768954068609
# avg auprc = 0.0762816115221
# Finished rna Lasso
# avg auc = 0.802983954125
# avg auprc = 0.0753935427769
# Finished rna KNN
# avg auc = 0.823366685559
# avg auprc = 0.12139163417
# Finished rna SVM
# avg auc = 0.855660262301
# avg auprc = 0.112728662117
# Finished rna Ridge
# avg auc = 0.955673650519
# avg auprc = 0.257876307019
# Finished rna RF
# avg auc = 0.684649386053
# avg auprc = 0.0541553847311
# Finished rna Logistic
# avg auc = 0.766757878935
# avg auprc = 0.0727545046028
# Finished rna Lasso
# avg auc = 0.814177681296
# avg auprc = 0.0854053324825
# Finished rna KNN
# avg auc = 0.822737563404
# avg auprc = 0.10750263476
# Finished rna SVM
# avg auc = 0.870170571272
# avg auprc = 0.115007102291
# Finished rna Ridge
# avg auc = 0.954270083224
# avg auprc = 0.274359466714
# Finished rna RF
# avg auc = 0.712397986741
# avg auprc = 0.0703740355778
# Finished rna Logistic
# avg auc = 0.770461098251
# avg auprc = 0.0743486428181
# Finished rna Lasso
# avg auc = 0.819479560677
# avg auprc = 0.0429912671106
# Finished rnabase KNN
# avg auc = 0.808706506685
# avg auprc = 0.075220204512
# Finished rnabase SVM
# avg auc = 0.826036713222
# avg auprc = 0.0529288442538
# Finished rnabase Ridge
# avg auc = 0.937307198578
# avg auprc = 0.211043705056
# Finished rnabase RF
# avg auc = 0.686941696955
# avg auprc = 0.0329580430166
# Finished rnabase Logistic
# avg auc = 0.772229467131
# avg auprc = 0.0389468544922
# Finished rnabase Lasso
# avg auc = 0.820989047246
# avg auprc = 0.0442459136792
# Finished rnabase KNN
# avg auc = 0.833317495841
# avg auprc = 0.0595521976721
# Finished rnabase SVM
# avg auc = 0.819661266672
# avg auprc = 0.0513975576396
# Finished rnabase Ridge
# avg auc = 0.92757798216
# avg auprc = 0.184997852907
# Finished rnabase RF
# avg auc = 0.824156827044
# avg auprc = 0.0536874193941
# Finished rnabase Logistic
# avg auc = 0.761894846069
# avg auprc = 0.0517433194441
# Finished rnabase Lasso
# avg auc = 0.809785140059
# avg auprc = 0.0454340206859
# Finished rnabase KNN
# avg auc = 0.82193800134
# avg auprc = 0.062214034578
# Finished rnabase SVM
# avg auc = 0.826000418377
# avg auprc = 0.0467030934365
# Finished rnabase Ridge
# avg auc = 0.937606819262
# avg auprc = 0.200677531458
# Finished rnabase RF
# avg auc = 0.673922255171
# avg auprc = 0.0369359973392
# Finished rnabase Logistic
# avg auc = 0.763083288906
# avg auprc = 0.0475935241506
# Finished rnabase Lasso
# avg auc = 0.818240298913
# avg auprc = 0.0384254632397
# Finished rnabase KNN
# avg auc = 0.81957789305
# avg auprc = 0.0664381492328
# Finished rnabase SVM
# avg auc = 0.83872141069
# avg auprc = 0.0532352569685
# Finished rnabase Ridge
# avg auc = 0.930850695371
# avg auprc = 0.177896521808
# Finished rnabase RF
# avg auc = 0.69403728803
# avg auprc = 0.0305807980514
# Finished rnabase Logistic
# avg auc = 0.756911038462
# avg auprc = 0.0427176665954
# Finished rnabase Lasso
# avg auc = 0.814798257222
# avg auprc = 0.0516161135942
# Finished rnabase KNN
# avg auc = 0.807062396502
# avg auprc = 0.0436920159966
# Finished rnabase SVM
# avg auc = 0.848826250288
# avg auprc = 0.0650832127411
# Finished rnabase Ridge
# avg auc = 0.927123671996
# avg auprc = 0.209130752097
# Finished rnabase RF
# avg auc = 0.67019480573
# avg auprc = 0.0336529594793
# Finished rnabase Logistic
# avg auc = 0.720813407579
# avg auprc = 0.0394358505598
# Finished rnabase Lasso
# avg auc = 0.798683048494
# avg auprc = 0.0407885939705
# Finished rnabase KNN
# avg auc = 0.798270245752
# avg auprc = 0.0677259414055
# Finished rnabase SVM
# avg auc = 0.796857611811
# avg auprc = 0.0379079758128
# Finished rnabase Ridge
# avg auc = 0.936674734076
# avg auprc = 0.173473151186
# Finished rnabase RF
# avg auc = 0.641533811378
# avg auprc = 0.0275151294925
# Finished rnabase Logistic
# avg auc = 0.742618184641
# avg auprc = 0.0394754127998
# Finished rnabase Lasso
# avg auc = 0.773070713643
# avg auprc = 0.032368033318
# Finished rnabase KNN
# avg auc = 0.771520312349
# avg auprc = 0.0685643716031
# Finished rnabase SVM
# avg auc = 0.75153859971
# avg auprc = 0.0315500449459
# Finished rnabase Ridge
# avg auc = 0.880912273738
# avg auprc = 0.099001621671
# Finished rnabase RF
# avg auc = 0.690787343721
# avg auprc = 0.035211906592
# Finished rnabase Logistic
# avg auc = 0.761090746271
# avg auprc = 0.0379741528467
# Finished rnabase Lasso
# avg auc = 0.829218552974
# avg auprc = 0.0499328871337
# Finished rnabase KNN
# avg auc = 0.818509214552
# avg auprc = 0.0690679512839
# Finished rnabase SVM
# avg auc = 0.855018851646
# avg auprc = 0.0632704569397
# Finished rnabase Ridge
# avg auc = 0.931210485262
# avg auprc = 0.207071926772
# Finished rnabase RF
# avg auc = 0.682821298313
# avg auprc = 0.0292573014326
# Finished rnabase Logistic
# avg auc = 0.763615323177
# avg auprc = 0.0345931218002
# Finished rnabase Lasso
# avg auc = 0.807161041347
# avg auprc = 0.0376799522948
# Finished rnabase KNN
# avg auc = 0.819572728135
# avg auprc = 0.0749638876439
# Finished rnabase SVM
# avg auc = 0.822017469108
# avg auprc = 0.0455339685479
# Finished rnabase Ridge
# avg auc = 0.927669760481
# avg auprc = 0.185645530851
# Finished rnabase RF
# avg auc = 0.680905290892
# avg auprc = 0.0302908686054
# Finished rnabase Logistic
# avg auc = 0.76621853162
# avg auprc = 0.0346648838483
# Finished rnabase Lasso
# avg auc = 0.8154480921
# avg auprc = 0.0418977494557
# Finished rnabase KNN
# avg auc = 0.811510150715
# avg auprc = 0.0660357729568
# Finished rnabase SVM
# avg auc = 0.81523356896
# avg auprc = 0.0480674260656
# Finished rnabase Ridge
# avg auc = 0.93435655572
# avg auprc = 0.197398778272
# Finished rnabase RF
# avg auc = 0.66961725428
# avg auprc = 0.0453781232448
# Finished rnabase Logistic
# avg auc = 0.765022784344
# avg auprc = 0.0374582097101
# Finished rnabase Lasso
# avg auc = 0.796690230691
# avg auprc = 0.0511569749262
# Finished rnabackbone KNN
# avg auc = 0.805589543047
# avg auprc = 0.0774705974477
# Finished rnabackbone SVM
# avg auc = 0.833800812376
# avg auprc = 0.066330969656
# Finished rnabackbone Ridge
# avg auc = 0.933578345902
# avg auprc = 0.168019968163
# Finished rnabackbone RF
# avg auc = 0.667637264873
# avg auprc = 0.0319186557792
# Finished rnabackbone Logistic
# avg auc = 0.751088897944
# avg auprc = 0.0484140302993
# Finished rnabackbone Lasso
# avg auc = 0.786269441897
# avg auprc = 0.0446458836342
# Finished rnabackbone KNN
# avg auc = 0.810141956217
# avg auprc = 0.0733587105674
# Finished rnabackbone SVM
# avg auc = 0.829840080377
# avg auprc = 0.066489005793
# Finished rnabackbone Ridge
# avg auc = 0.941429217667
# avg auprc = 0.201730360407
# Finished rnabackbone RF
# avg auc = 0.828512826612
# avg auprc = 0.0706180814195
# Finished rnabackbone Logistic
# avg auc = 0.738769650544
# avg auprc = 0.0570304310826
# Finished rnabackbone Lasso
# avg auc = 0.781980590923
# avg auprc = 0.0433011581426
# Finished rnabackbone KNN
# avg auc = 0.805553550902
# avg auprc = 0.0869440896773
# Finished rnabackbone SVM
# avg auc = 0.852042061999
# avg auprc = 0.0776751805673
# Finished rnabackbone Ridge
# avg auc = 0.944012175551
# avg auprc = 0.19592015612
# Finished rnabackbone RF
# avg auc = 0.684157949584
# avg auprc = 0.0381903228887
# Finished rnabackbone Logistic
# avg auc = 0.749263074972
# avg auprc = 0.0426113475611
# Finished rnabackbone Lasso
# avg auc = 0.795791964558
# avg auprc = 0.0490100942531
# Finished rnabackbone KNN
# avg auc = 0.806144369251
# avg auprc = 0.0707219417987
# Finished rnabackbone SVM
# avg auc = 0.849071604566
# avg auprc = 0.0779557025824
# Finished rnabackbone Ridge
# avg auc = 0.939216823694
# avg auprc = 0.186206717778
# Finished rnabackbone RF
# avg auc = 0.669507651799
# avg auprc = 0.0321318321101
# Finished rnabackbone Logistic
# avg auc = 0.746407113802
# avg auprc = 0.0435690679491
# Finished rnabackbone Lasso
# avg auc = 0.785745946125
# avg auprc = 0.053607639179
# Finished rnabackbone KNN
# avg auc = 0.786633332763
# avg auprc = 0.0562531728989
# Finished rnabackbone SVM
# avg auc = 0.856780733817
# avg auprc = 0.0743339720156
# Finished rnabackbone Ridge
# avg auc = 0.938491410673
# avg auprc = 0.184832750301
# Finished rnabackbone RF
# avg auc = 0.648465802269
# avg auprc = 0.0278129852773
# Finished rnabackbone Logistic
# avg auc = 0.693495411138
# avg auprc = 0.0362246408431
# Finished rnabackbone Lasso
# avg auc = 0.785091484128
# avg auprc = 0.0444870504963
# Finished rnabackbone KNN
# avg auc = 0.795005289058
# avg auprc = 0.0690578043077
# Finished rnabackbone SVM
# avg auc = 0.8265980019
# avg auprc = 0.064935987936
# Finished rnabackbone Ridge
# avg auc = 0.945611695839
# avg auprc = 0.186186447716
# Finished rnabackbone RF
# avg auc = 0.656433614651
# avg auprc = 0.0309240318159
# Finished rnabackbone Logistic
# avg auc = 0.73858235691
# avg auprc = 0.0461654327433
# Finished rnabackbone Lasso
# avg auc = 0.754350673453
# avg auprc = 0.0400447628585
# Finished rnabackbone KNN
# avg auc = 0.741127102726
# avg auprc = 0.058119767573
# Finished rnabackbone SVM
# avg auc = 0.766872800699
# avg auprc = 0.0467367707786
# Finished rnabackbone Ridge
# avg auc = 0.887879534124
# avg auprc = 0.134435983063
# Finished rnabackbone RF
# avg auc = 0.681846739525
# avg auprc = 0.0338893712045
# Finished rnabackbone Logistic
# avg auc = 0.74859195798
# avg auprc = 0.046381826056
# Finished rnabackbone Lasso
# avg auc = 0.819088968371
# avg auprc = 0.0583998790815
# Finished rnabackbone KNN
# avg auc = 0.80647548366
# avg auprc = 0.0721169543395
# Finished rnabackbone SVM
# avg auc = 0.866071311095
# avg auprc = 0.0845576615714
# Finished rnabackbone Ridge
# avg auc = 0.943829638515
# avg auprc = 0.215583852013
# Finished rnabackbone RF
# avg auc = 0.674010160754
# avg auprc = 0.0326764841701
# Finished rnabackbone Logistic
# avg auc = 0.764982796728
# avg auprc = 0.0489985967079
# Finished rnabackbone Lasso
# avg auc = 0.782496895207
# avg auprc = 0.0536581543231
# Finished rnabackbone KNN
# avg auc = 0.800934814297
# avg auprc = 0.065602466109
# Finished rnabackbone SVM
# avg auc = 0.836738222902
# avg auprc = 0.0683255084484
# Finished rnabackbone Ridge
# avg auc = 0.933489315116
# avg auprc = 0.190723984292
# Finished rnabackbone RF
# avg auc = 0.65947631503
# avg auprc = 0.0343202221759
# Finished rnabackbone Logistic
# avg auc = 0.750205317562
# avg auprc = 0.0441624435173
# Finished rnabackbone Lasso
# avg auc = 0.797757833591
# avg auprc = 0.0507247336772
# Finished rnabackbone KNN
# avg auc = 0.802290337281
# avg auprc = 0.0659710335384
# Finished rnabackbone SVM
# avg auc = 0.847844603384
# avg auprc = 0.080192986094
# Finished rnabackbone Ridge
# avg auc = 0.930734587725
# avg auprc = 0.18325231431
# Finished rnabackbone RF
# avg auc = 0.6733320535
# avg auprc = 0.0328468672584
# Finished rnabackbone Logistic
# avg auc = 0.757581133241
# avg auprc = 0.0423121368066
# Finished rnabackbone Lasso
# avg auc = 0.709567798488
# avg auprc = 0.186229154424
# Finished peptide KNN
# avg auc = 0.727972721683
# avg auprc = 0.200730035849
# Finished peptide SVM
# avg auc = 0.739405808641
# avg auprc = 0.177252742375
# Finished peptide Ridge
# avg auc = 0.869561557863
# avg auprc = 0.335176504398
# Finished peptide RF
# avg auc = 0.65781417122
# avg auprc = 0.14233373157
# Finished peptide Logistic
# avg auc = 0.672313531763
# avg auprc = 0.153126369943
# Finished peptide Lasso
# avg auc = 0.707987182377
# avg auprc = 0.184877461239
# Finished peptide KNN
# avg auc = 0.731405618844
# avg auprc = 0.192937207828
# Finished peptide SVM
# avg auc = 0.73503753029
# avg auprc = 0.165877462695
# Finished peptide Ridge
# avg auc = 0.877543943966
# avg auprc = 0.352567641996
# Finished peptide RF
# avg auc = 0.738088033655
# avg auprc = 0.181146460908
# Finished peptide Logistic
# avg auc = 0.658172412094
# avg auprc = 0.154258301518
# Finished peptide Lasso
# avg auc = 0.712936281102
# avg auprc = 0.184191178956
# Finished peptide KNN
# avg auc = 0.729838014413
# avg auprc = 0.201633667236
# Finished peptide SVM
# avg auc = 0.742626575412
# avg auprc = 0.176752413216
# Finished peptide Ridge
# avg auc = 0.873386861078
# avg auprc = 0.338962623967
# Finished peptide RF
# avg auc = 0.653187133597
# avg auprc = 0.139750256179
# Finished peptide Logistic
# avg auc = 0.673032117502
# avg auprc = 0.156758821875
# Finished peptide Lasso
# avg auc = 0.717657749297
# avg auprc = 0.196847947031
# Finished peptide KNN
# avg auc = 0.730046746604
# avg auprc = 0.197111672243
# Finished peptide SVM
# avg auc = 0.743136210855
# avg auprc = 0.172438577021
# Finished peptide Ridge
# avg auc = 0.875384779535
# avg auprc = 0.340091615874
# Finished peptide RF
# avg auc = 0.653581195298
# avg auprc = 0.130459313583
# Finished peptide Logistic
# avg auc = 0.6674139474
# avg auprc = 0.154340288615
# Finished peptide Lasso
# avg auc = 0.70342174748
# avg auprc = 0.167431810824
# Finished peptide KNN
# avg auc = 0.724660783166
# avg auprc = 0.181298503828
# Finished peptide SVM
# avg auc = 0.745378318481
# avg auprc = 0.181243572024
# Finished peptide Ridge
# avg auc = 0.862530555196
# avg auprc = 0.319133374926
# Finished peptide RF
# avg auc = 0.653034718415
# avg auprc = 0.124983754954
# Finished peptide Logistic
# avg auc = 0.666436283505
# avg auprc = 0.143244788439
# Finished peptide Lasso
# avg auc = 0.705847047646
# avg auprc = 0.189980211938
# Finished peptide KNN
# avg auc = 0.728709343139
# avg auprc = 0.198711886253
# Finished peptide SVM
# avg auc = 0.739115551925
# avg auprc = 0.175480357905
# Finished peptide Ridge
# avg auc = 0.872109923197
# avg auprc = 0.329924087869
# Finished peptide RF
# avg auc = 0.649900276902
# avg auprc = 0.141131259822
# Finished peptide Logistic
# avg auc = 0.665454216854
# avg auprc = 0.154939247413
# Finished peptide Lasso
# avg auc = 0.680188147211
# avg auprc = 0.169174470369
# Finished peptide KNN
# avg auc = 0.690931772584
# avg auprc = 0.188048169253
# Finished peptide SVM
# avg auc = 0.697241987642
# avg auprc = 0.159163853121
# Finished peptide Ridge
# avg auc = 0.754597794207
# avg auprc = 0.24606115955
# Finished peptide RF
# avg auc = 0.660098212641
# avg auprc = 0.139495188203
# Finished peptide Logistic
# avg auc = 0.679866908096
# avg auprc = 0.156781242652
# Finished peptide Lasso
# avg auc = 0.735283775684
# avg auprc = 0.203771699297
# Finished peptide KNN
# avg auc = 0.732223840519
# avg auprc = 0.207389056324
# Finished peptide SVM
# avg auc = 0.749496879628
# avg auprc = 0.184045670074
# Finished peptide Ridge
# avg auc = 0.875858328326
# avg auprc = 0.345453276053
# Finished peptide RF
# avg auc = 0.656724821798
# avg auprc = 0.139151417411
# Finished peptide Logistic
# avg auc = 0.673167451081
# avg auprc = 0.154155211108
# Finished peptide Lasso
# avg auc = 0.714461331435
# avg auprc = 0.191416957493
# Finished peptide KNN
# avg auc = 0.727512673217
# avg auprc = 0.203243794156
# Finished peptide SVM
# avg auc = 0.74046708808
# avg auprc = 0.176187842694
# Finished peptide Ridge
# avg auc = 0.876718613615
# avg auprc = 0.341938102959
# Finished peptide RF
# avg auc = 0.657707201112
# avg auprc = 0.139438570308
# Finished peptide Logistic
# avg auc = 0.666999805983
# avg auprc = 0.158122547804
# Finished peptide Lasso
# avg auc = 0.713109225017
# avg auprc = 0.193685851419
# Finished peptide KNN
# avg auc = 0.729576739185
# avg auprc = 0.200606639721
# Finished peptide SVM
# avg auc = 0.743597490215
# avg auprc = 0.178948373841
# Finished peptide Ridge
# avg auc = 0.877750633651
# avg auprc = 0.340427705821
# Finished peptide RF
# avg auc = 0.655232100099
# avg auprc = 0.139713881481
# Finished peptide Logistic
# avg auc = 0.670399803335
# avg auprc = 0.155811227488
# Finished peptide Lasso
# avg auc = 0.738099899513
# avg auprc = 0.23400167351
# Finished ion KNN
# avg auc = 0.737067916157
# avg auprc = 0.206886699291
# Finished ion SVM
# avg auc = 0.735310935832
# avg auprc = 0.160492835077
# Finished ion Ridge
# avg auc = 0.782920750697
# avg auprc = 0.261088745484
# Finished ion RF
# avg auc = 0.697866384622
# avg auprc = 0.162681725651
# Finished ion Logistic
# avg auc = 0.685318074314
# avg auprc = 0.131236323446
# Finished ion Lasso
# avg auc = 0.740639216782
# avg auprc = 0.235920199867
# Finished ion KNN
# avg auc = 0.742654136375
# avg auprc = 0.210507369429
# Finished ion SVM
# avg auc = 0.738245882858
# avg auprc = 0.161196340346
# Finished ion Ridge
# avg auc = 0.782268856493
# avg auprc = 0.269754848272
# Finished ion RF
# avg auc = 0.740965294333
# avg auprc = 0.179524663035
# Finished ion Logistic
# avg auc = 0.680898526114
# avg auprc = 0.121755747823
# Finished ion Lasso
# avg auc = 0.73796782769
# avg auprc = 0.226598931045
# Finished ion KNN
# avg auc = 0.73605819576
# avg auprc = 0.205549106159
# Finished ion SVM
# avg auc = 0.737934341357
# avg auprc = 0.165042692401
# Finished ion Ridge
# avg auc = 0.781999199437
# avg auprc = 0.267819660077
# Finished ion RF
# avg auc = 0.696779109272
# avg auprc = 0.159001527355
# Finished ion Logistic
# avg auc = 0.687415265275
# avg auprc = 0.133313310137
# Finished ion Lasso
# avg auc = 0.73620396249
# avg auprc = 0.226335268327
# Finished ion KNN
# avg auc = 0.732866409103
# avg auprc = 0.204901137121
# Finished ion SVM
# avg auc = 0.741027107104
# avg auprc = 0.1650349771
# Finished ion Ridge
# avg auc = 0.779906265517
# avg auprc = 0.25953719298
# Finished ion RF
# avg auc = 0.68059955512
# avg auprc = 0.136504320371
# Finished ion Logistic
# avg auc = 0.669321132307
# avg auprc = 0.125817624388
# Finished ion Lasso
# avg auc = 0.730099739223
# avg auprc = 0.224629380179
# Finished ion KNN
# avg auc = 0.733297868878
# avg auprc = 0.198058972341
# Finished ion SVM
# avg auc = 0.74163897106
# avg auprc = 0.169946363051
# Finished ion Ridge
# avg auc = 0.781700090366
# avg auprc = 0.266666242605
# Finished ion RF
# avg auc = 0.695194919591
# avg auprc = 0.15951682859
# Finished ion Logistic
# avg auc = 0.674779516426
# avg auprc = 0.122633606488
# Finished ion Lasso
# avg auc = 0.725321512037
# avg auprc = 0.219077341381
# Finished ion KNN
# avg auc = 0.729117993213
# avg auprc = 0.20632088537
# Finished ion SVM
# avg auc = 0.732686222135
# avg auprc = 0.156269588869
# Finished ion Ridge
# avg auc = 0.770112255508
# avg auprc = 0.247205282853
# Finished ion RF
# avg auc = 0.688883637068
# avg auprc = 0.163910735407
# Finished ion Logistic
# avg auc = 0.665969009242
# avg auprc = 0.1254243044
# Finished ion Lasso
# avg auc = 0.729054212639
# avg auprc = 0.212481402655
# Finished ion KNN
# avg auc = 0.724346154228
# avg auprc = 0.200877998866
# Finished ion SVM
# avg auc = 0.725676472574
# avg auprc = 0.156708174536
# Finished ion Ridge
# avg auc = 0.758901240521
# avg auprc = 0.25760308632
# Finished ion RF
# avg auc = 0.696291025731
# avg auprc = 0.160811366837
# Finished ion Logistic
# avg auc = 0.681135323092
# avg auprc = 0.136479599111
# Finished ion Lasso
# avg auc = 0.745720499177
# avg auprc = 0.24598746963
# Finished ion KNN
# avg auc = 0.740476178108
# avg auprc = 0.209394425257
# Finished ion SVM
# avg auc = 0.746509681364
# avg auprc = 0.175834679083
# Finished ion Ridge
# avg auc = 0.787052415249
# avg auprc = 0.267434897089
# Finished ion RF
# avg auc = 0.700573578436
# avg auprc = 0.16744273003
# Finished ion Logistic
# avg auc = 0.685459759311
# avg auprc = 0.134982845537
# Finished ion Lasso
# avg auc = 0.727431794282
# avg auprc = 0.204435728084
# Finished ion KNN
# avg auc = 0.726129146481
# avg auprc = 0.188276208136
# Finished ion SVM
# avg auc = 0.734045790411
# avg auprc = 0.152118431924
# Finished ion Ridge
# avg auc = 0.776445055143
# avg auprc = 0.267563950523
# Finished ion RF
# avg auc = 0.698952540158
# avg auprc = 0.165363317455
# Finished ion Logistic
# avg auc = 0.688187787128
# avg auprc = 0.136064129323
# Finished ion Lasso
# avg auc = 0.740100236102
# avg auprc = 0.236026125873
# Finished ion KNN
# avg auc = 0.737555691825
# avg auprc = 0.209670186539
# Finished ion SVM
# avg auc = 0.742016444436
# avg auprc = 0.167484689867
# Finished ion Ridge
# avg auc = 0.785494925938
# avg auprc = 0.266716644367
# Finished ion RF
# avg auc = 0.701484298922
# avg auprc = 0.163925696781
# Finished ion Logistic
# avg auc = 0.681050702642
# avg auprc = 0.132314382091
# Finished ion Lasso
# avg auc = 0.650235215646
# avg auprc = 0.112728802093
# Finished metabolite KNN
# avg auc = 0.672215966329
# avg auprc = 0.121459431468
# Finished metabolite SVM
# avg auc = 0.700400022241
# avg auprc = 0.125365264877
# Finished metabolite Ridge
# avg auc = 0.758684851688
# avg auprc = 0.189447593727
# Finished metabolite RF
# avg auc = 0.664575393941
# avg auprc = 0.106812098676
# Finished metabolite Logistic
# avg auc = 0.622843084848
# avg auprc = 0.0959184889168
# Finished metabolite Lasso
# avg auc = 0.646379452851
# avg auprc = 0.113606675247
# Finished metabolite KNN
# avg auc = 0.677724505521
# avg auprc = 0.125561334111
# Finished metabolite SVM
# avg auc = 0.698060038967
# avg auprc = 0.124790964708
# Finished metabolite Ridge
# avg auc = 0.747042572689
# avg auprc = 0.182353575112
# Finished metabolite RF
# avg auc = 0.695649721605
# avg auprc = 0.125420712117
# Finished metabolite Logistic
# avg auc = 0.632866677597
# avg auprc = 0.0957224874465
# Finished metabolite Lasso
# avg auc = 0.648054432982
# avg auprc = 0.115260496349
# Finished metabolite KNN
# avg auc = 0.679525017402
# avg auprc = 0.12809778169
# Finished metabolite SVM
# avg auc = 0.702881644369
# avg auprc = 0.129823509631
# Finished metabolite Ridge
# avg auc = 0.75041852013
# avg auprc = 0.181541939617
# Finished metabolite RF
# avg auc = 0.669532044454
# avg auprc = 0.112691024161
# Finished metabolite Logistic
# avg auc = 0.630794895096
# avg auprc = 0.0974029009574
# Finished metabolite Lasso
# avg auc = 0.66335169647
# avg auprc = 0.11938533345
# Finished metabolite KNN
# avg auc = 0.674284169377
# avg auprc = 0.124185025334
# Finished metabolite SVM
# avg auc = 0.70142319557
# avg auprc = 0.128179508552
# Finished metabolite Ridge
# avg auc = 0.751756053171
# avg auprc = 0.182973460203
# Finished metabolite RF
# avg auc = 0.654573561845
# avg auprc = 0.106134681525
# Finished metabolite Logistic
# avg auc = 0.620265495046
# avg auprc = 0.0935480281819
# Finished metabolite Lasso
# avg auc = 0.643411647291
# avg auprc = 0.11382414163
# Finished metabolite KNN
# avg auc = 0.674758667093
# avg auprc = 0.118468417532
# Finished metabolite SVM
# avg auc = 0.69758356583
# avg auprc = 0.130704416932
# Finished metabolite Ridge
# avg auc = 0.742537690761
# avg auprc = 0.177464978836
# Finished metabolite RF
# avg auc = 0.663351764476
# avg auprc = 0.109487067172
# Finished metabolite Logistic
# avg auc = 0.622775160658
# avg auprc = 0.0906994457531
# Finished metabolite Lasso
# avg auc = 0.637017543155
# avg auprc = 0.110790367561
# Finished metabolite KNN
# avg auc = 0.661630777664
# avg auprc = 0.117772024956
# Finished metabolite SVM
# avg auc = 0.686290084645
# avg auprc = 0.120554779274
# Finished metabolite Ridge
# avg auc = 0.742804107927
# avg auprc = 0.168739100203
# Finished metabolite RF
# avg auc = 0.645772963291
# avg auprc = 0.102209204162
# Finished metabolite Logistic
# avg auc = 0.599511210344
# avg auprc = 0.0882461855136
# Finished metabolite Lasso
# avg auc = 0.641796990646
# avg auprc = 0.110250824122
# Finished metabolite KNN
# avg auc = 0.655839573992
# avg auprc = 0.115814225843
# Finished metabolite SVM
# avg auc = 0.671135707322
# avg auprc = 0.115879793406
# Finished metabolite Ridge
# avg auc = 0.708406197884
# avg auprc = 0.152687921528
# Finished metabolite RF
# avg auc = 0.659199854798
# avg auprc = 0.109020416611
# Finished metabolite Logistic
# avg auc = 0.629381840992
# avg auprc = 0.094450199097
# Finished metabolite Lasso
# avg auc = 0.673773598707
# avg auprc = 0.12154126061
# Finished metabolite KNN
# avg auc = 0.679853264017
# avg auprc = 0.129272982349
# Finished metabolite SVM
# avg auc = 0.710924924206
# avg auprc = 0.137204406705
# Finished metabolite Ridge
# avg auc = 0.75792925227
# avg auprc = 0.188212458406
# Finished metabolite RF
# avg auc = 0.663423547144
# avg auprc = 0.113296308332
# Finished metabolite Logistic
# avg auc = 0.629560123463
# avg auprc = 0.0953460431063
# Finished metabolite Lasso
# avg auc = 0.647119606741
# avg auprc = 0.099546012563
# Finished metabolite KNN
# avg auc = 0.674227610414
# avg auprc = 0.118193221559
# Finished metabolite SVM
# avg auc = 0.702798505705
# avg auprc = 0.126819339219
# Finished metabolite Ridge
# avg auc = 0.751773683863
# avg auprc = 0.184246839115
# Finished metabolite RF
# avg auc = 0.669902721398
# avg auprc = 0.111608896333
# Finished metabolite Logistic
# avg auc = 0.62669025208
# avg auprc = 0.0954037976375
# Finished metabolite Lasso
# avg auc = 0.654717868903
# avg auprc = 0.11153260953
# Finished metabolite KNN
# avg auc = 0.676928290611
# avg auprc = 0.125645818299
# Finished metabolite SVM
# avg auc = 0.708196662135
# avg auprc = 0.134831131852
# Finished metabolite Ridge
# avg auc = 0.753944211461
# avg auprc = 0.183170710438
# Finished metabolite RF
# avg auc = 0.660947819944
# avg auprc = 0.10837036787
# Finished metabolite Logistic
# avg auc = 0.629413496457
# avg auprc = 0.0984064303367
# Finished metabolite Lasso

# %%
downsample_method = 'NoDown'
classifier_method = 'XGB'

# %%
#Run XGB without GO terms
classifiers = {}
classifiers["XGB"] = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=0, max_depth=6, min_child_weight=0.05, colsample_bytree=0.5)

for ligand in ligands:
    # Include features in the group
    n_features = ligands_features_df[ligand].shape[1]
    cutoff = np.where(features_list == "GO:NO_TERM")[0][0]
    features_included = np.ones([n_features]).astype(bool)
    features_included[cutoff:] = False

    #Initialize dictionary
    pred_dict = defaultdict(list)
    auc_dict = defaultdict(list)
    auprc_dict = defaultdict(list)

    # Run classifier
    test_model(pred_dict, auc_dict, auprc_dict, ligands_features_df[ligand], non_binding_positions, ligand, downsample_method, features_included)

    #pred_df = pd.DataFrame.from_dict(pred_dict)
    #auc_df = pd.DataFrame.from_dict(auc_dict)
    #auprc_df = pd.DataFrame.from_dict(auprc_dict)

    #Save to file
    #pred_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_except_0.1.csv", sep='\t')
    #auc_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_except_0.1_auc.csv", sep='\t')
    #auprc_df.to_csv(curr_dir[0]+"/feature_select_df/"+ligand+"_"+group+"_except_0.1_auprc.csv", sep='\t')
# Out:
# fold #: 1
# Actual positives: 51	Out of: 2771
# Positives found: 16.0211	Out of: 2771
# AUC = 0.975064878893
# AUPRC = 0.68577735002
# fold #: 2
# Actual positives: 50	Out of: 2769
# Positives found: 20.568	Out of: 2769
# AUC = 0.974174328797
# AUPRC = 0.564163708137
# fold #: 3
# Actual positives: 50	Out of: 2769
# Positives found: 21.9655	Out of: 2769
# AUC = 0.967392423685
# AUPRC = 0.64359184405
# fold #: 4
# Actual positives: 50	Out of: 2769
# Positives found: 18.0058	Out of: 2769
# AUC = 0.982500919456
# AUPRC = 0.66027978471
# fold #: 5
# Actual positives: 50	Out of: 2769
# Positives found: 15.7574	Out of: 2769
# AUC = 0.975064361898
# AUPRC = 0.606604378002
# fold #: 6
# Actual positives: 50	Out of: 2769
# Positives found: 19.246	Out of: 2769
# AUC = 0.985465244575
# AUPRC = 0.631652207645
# fold #: 7
# Actual positives: 50	Out of: 2769
# Positives found: 21.2359	Out of: 2769
# AUC = 0.965171018757
# AUPRC = 0.697254314102
# fold #: 8
# Actual positives: 50	Out of: 2769
# Positives found: 23.2301	Out of: 2769
# AUC = 0.982118425892
# AUPRC = 0.684243832397
# fold #: 9
# Actual positives: 50	Out of: 2769
# Positives found: 22.6846	Out of: 2769
# AUC = 0.983832291284
# AUPRC = 0.615904621303
# fold #: 10
# Actual positives: 50	Out of: 2769
# Positives found: 20.7736	Out of: 2769
# AUC = 0.945509378448
# AUPRC = 0.487530986292
# avg auc = 0.973629327168
# avg auprc = 0.627700302666
# Finished dna XGB
# fold #: 1
# Actual positives: 20	Out of: 2740
# Positives found: 2.87096	Out of: 2740
# AUC = 0.955275735294
# AUPRC = 0.49386957682
# fold #: 2
# Actual positives: 20	Out of: 2739
# Positives found: 4.99425	Out of: 2739
# AUC = 0.951838911364
# AUPRC = 0.52759015267
# fold #: 3
# Actual positives: 20	Out of: 2739
# Positives found: 3.14753	Out of: 2739
# AUC = 0.979900698786
# AUPRC = 0.397063791153
# fold #: 4
# Actual positives: 19	Out of: 2738
# Positives found: 2.73297	Out of: 2738
# AUC = 0.983372369873
# AUPRC = 0.480079283848
# fold #: 5
# Actual positives: 19	Out of: 2738
# Positives found: 1.2429	Out of: 2738
# AUC = 0.942296897079
# AUPRC = 0.299520261366
# fold #: 6
# Actual positives: 19	Out of: 2738
# Positives found: 5.12005	Out of: 2738
# AUC = 0.992876638083
# AUPRC = 0.55390807701
# fold #: 7
# Actual positives: 19	Out of: 2738
# Positives found: 3.09902	Out of: 2738
# AUC = 0.982056096475
# AUPRC = 0.497311743698
# fold #: 8
# Actual positives: 19	Out of: 2738
# Positives found: 3.04227	Out of: 2738
# AUC = 0.966899595439
# AUPRC = 0.255317764467
# fold #: 9
# Actual positives: 19	Out of: 2738
# Positives found: 3.88801	Out of: 2738
# AUC = 0.986566268558
# AUPRC = 0.40353978913
# fold #: 10
# Actual positives: 19	Out of: 2738
# Positives found: 4.34296	Out of: 2738
# AUC = 0.990553802675
# AUPRC = 0.524527080063
# avg auc = 0.973163701363
# avg auprc = 0.443272752022
# Finished dnabase XGB
# fold #: 1
# Actual positives: 41	Out of: 2761
# Positives found: 12.6484	Out of: 2761
# AUC = 0.986970946915
# AUPRC = 0.620096683171
# fold #: 2
# Actual positives: 41	Out of: 2760
# Positives found: 12.9718	Out of: 2760
# AUC = 0.933314794715
# AUPRC = 0.477840259471
# fold #: 3
# Actual positives: 41	Out of: 2760
# Positives found: 16.4792	Out of: 2760
# AUC = 0.964253357135
# AUPRC = 0.626707365268
# fold #: 4
# Actual positives: 41	Out of: 2760
# Positives found: 11.3094	Out of: 2760
# AUC = 0.961481534639
# AUPRC = 0.557319069553
# fold #: 5
# Actual positives: 41	Out of: 2760
# Positives found: 16.4494	Out of: 2760
# AUC = 0.986499699495
# AUPRC = 0.677407505863
# fold #: 6
# Actual positives: 41	Out of: 2760
# Positives found: 14.8371	Out of: 2760
# AUC = 0.976623399923
# AUPRC = 0.570307970859
# fold #: 7
# Actual positives: 41	Out of: 2760
# Positives found: 15.2282	Out of: 2760
# AUC = 0.967348110406
# AUPRC = 0.639779771186
# fold #: 8
# Actual positives: 41	Out of: 2760
# Positives found: 14.1092	Out of: 2760
# AUC = 0.97897361835
# AUPRC = 0.511932009933
# fold #: 9
# Actual positives: 40	Out of: 2759
# Positives found: 12.8573	Out of: 2759
# AUC = 0.968628172122
# AUPRC = 0.592878620886
# fold #: 10
# Actual positives: 40	Out of: 2759
# Positives found: 15.9511	Out of: 2759
# AUC = 0.980774181684
# AUPRC = 0.555341232025
# avg auc = 0.970486781538
# avg auprc = 0.582961048821
# Finished dnabackbone XGB
# fold #: 1
# Actual positives: 44	Out of: 2764
# Positives found: 13.0511	Out of: 2764
# AUC = 0.979436831551
# AUPRC = 0.504519583793
# fold #: 2
# Actual positives: 44	Out of: 2763
# Positives found: 15.7729	Out of: 2763
# AUC = 0.986567588351
# AUPRC = 0.584086920622
# fold #: 3
# Actual positives: 44	Out of: 2763
# Positives found: 14.8567	Out of: 2763
# AUC = 0.98188672306
# AUPRC = 0.491198970585
# fold #: 4
# Actual positives: 43	Out of: 2762
# Positives found: 17.3986	Out of: 2762
# AUC = 0.990523191666
# AUPRC = 0.651680883148
# fold #: 5
# Actual positives: 43	Out of: 2762
# Positives found: 15.1436	Out of: 2762
# AUC = 0.990121197089
# AUPRC = 0.712239680947
# fold #: 6
# Actual positives: 43	Out of: 2762
# Positives found: 16.3596	Out of: 2762
# AUC = 0.989317207934
# AUPRC = 0.5806015432
# fold #: 7
# Actual positives: 43	Out of: 2762
# Positives found: 15.6148	Out of: 2762
# AUC = 0.979720656534
# AUPRC = 0.594713205819
# fold #: 8
# Actual positives: 43	Out of: 2762
# Positives found: 15.4064	Out of: 2762
# AUC = 0.980028567274
# AUPRC = 0.578959915041
# fold #: 9
# Actual positives: 43	Out of: 2762
# Positives found: 14.2377	Out of: 2762
# AUC = 0.979985801894
# AUPRC = 0.489635924618
# fold #: 10
# Actual positives: 43	Out of: 2762
# Positives found: 16.667	Out of: 2762
# AUC = 0.984390636092
# AUPRC = 0.546878960643
# avg auc = 0.984197840144
# avg auprc = 0.573451558842
# Finished rna XGB
# fold #: 1
# Actual positives: 23	Out of: 2743
# Positives found: 5.06185	Out of: 2743
# AUC = 0.974600383632
# AUPRC = 0.461908414392
# fold #: 2
# Actual positives: 23	Out of: 2742
# Positives found: 2.4702	Out of: 2742
# AUC = 0.97777315829
# AUPRC = 0.38884797903
# fold #: 3
# Actual positives: 23	Out of: 2742
# Positives found: 3.70184	Out of: 2742
# AUC = 0.972160480995
# AUPRC = 0.423779966551
# fold #: 4
# Actual positives: 23	Out of: 2742
# Positives found: 5.57575	Out of: 2742
# AUC = 0.991812846795
# AUPRC = 0.606297011684
# fold #: 5
# Actual positives: 22	Out of: 2741
# Positives found: 4.36952	Out of: 2741
# AUC = 0.979454344846
# AUPRC = 0.578284964552
# fold #: 6
# Actual positives: 22	Out of: 2741
# Positives found: 7.1398	Out of: 2741
# AUC = 0.958005951386
# AUPRC = 0.35132771413
# fold #: 7
# Actual positives: 22	Out of: 2741
# Positives found: 4.92511	Out of: 2741
# AUC = 0.97597713063
# AUPRC = 0.531999472343
# fold #: 8
# Actual positives: 22	Out of: 2741
# Positives found: 6.16058	Out of: 2741
# AUC = 0.990454378281
# AUPRC = 0.509683126335
# fold #: 9
# Actual positives: 22	Out of: 2741
# Positives found: 7.86326	Out of: 2741
# AUC = 0.980524256913
# AUPRC = 0.509127000963
# fold #: 10
# Actual positives: 22	Out of: 2741
# Positives found: 5.13248	Out of: 2741
# AUC = 0.967217225584
# AUPRC = 0.343040097945
# avg auc = 0.976798015735
# avg auprc = 0.470429574793
# Finished rnabase XGB
# fold #: 1
# Actual positives: 31	Out of: 2751
# Positives found: 8.4353	Out of: 2751
# AUC = 0.975806451613
# AUPRC = 0.496023911962
# fold #: 2
# Actual positives: 31	Out of: 2750
# Positives found: 8.93351	Out of: 2750
# AUC = 0.979724519214
# AUPRC = 0.559358923402
# fold #: 3
# Actual positives: 31	Out of: 2750
# Positives found: 7.86482	Out of: 2750
# AUC = 0.987281851724
# AUPRC = 0.390986905726
# fold #: 4
# Actual positives: 31	Out of: 2750
# Positives found: 8.23341	Out of: 2750
# AUC = 0.986463239569
# AUPRC = 0.597389140534
# fold #: 5
# Actual positives: 31	Out of: 2750
# Positives found: 6.90003	Out of: 2750
# AUC = 0.988658069262
# AUPRC = 0.627358168789
# fold #: 6
# Actual positives: 31	Out of: 2750
# Positives found: 10.8817	Out of: 2750
# AUC = 0.984659920037
# AUPRC = 0.462545464272
# fold #: 7
# Actual positives: 31	Out of: 2750
# Positives found: 7.46216	Out of: 2750
# AUC = 0.981515974801
# AUPRC = 0.559167200419
# fold #: 8
# Actual positives: 31	Out of: 2750
# Positives found: 9.68987	Out of: 2750
# AUC = 0.984814151313
# AUPRC = 0.560011963732
# fold #: 9
# Actual positives: 30	Out of: 2749
# Positives found: 5.4354	Out of: 2749
# AUC = 0.961811940664
# AUPRC = 0.410606351189
# fold #: 10
# Actual positives: 30	Out of: 2749
# Positives found: 9.01507	Out of: 2749
# AUC = 0.982015446855
# AUPRC = 0.506652048085
# avg auc = 0.981275156505
# avg auprc = 0.517010007811
# Finished rnabackbone XGB
# fold #: 1
# Actual positives: 150	Out of: 2870
# Positives found: 37.8924	Out of: 2870
# AUC = 0.893056372549
# AUPRC = 0.356719783256
# fold #: 2
# Actual positives: 150	Out of: 2869
# Positives found: 36.6462	Out of: 2869
# AUC = 0.903263454701
# AUPRC = 0.391871152485
# fold #: 3
# Actual positives: 150	Out of: 2869
# Positives found: 35.9513	Out of: 2869
# AUC = 0.894870663234
# AUPRC = 0.451983890444
# fold #: 4
# Actual positives: 150	Out of: 2869
# Positives found: 31.4033	Out of: 2869
# AUC = 0.898394017408
# AUPRC = 0.351239722695
# fold #: 5
# Actual positives: 150	Out of: 2869
# Positives found: 26.803	Out of: 2869
# AUC = 0.889885987495
# AUPRC = 0.376472581012
# fold #: 6
# Actual positives: 150	Out of: 2869
# Positives found: 36.7481	Out of: 2869
# AUC = 0.903707245311
# AUPRC = 0.444572504593
# fold #: 7
# Actual positives: 149	Out of: 2868
# Positives found: 33.7845	Out of: 2868
# AUC = 0.898157632963
# AUPRC = 0.428882369932
# fold #: 8
# Actual positives: 149	Out of: 2868
# Positives found: 35.3026	Out of: 2868
# AUC = 0.890699551503
# AUPRC = 0.453546094452
# fold #: 9
# Actual positives: 149	Out of: 2868
# Positives found: 44.6504	Out of: 2868
# AUC = 0.899163480454
# AUPRC = 0.402204321974
# fold #: 10
# Actual positives: 149	Out of: 2868
# Positives found: 39.6768	Out of: 2868
# AUC = 0.922407813769
# AUPRC = 0.488780358777
# avg auc = 0.899360621939
# avg auprc = 0.414627277962
# Finished peptide XGB
# fold #: 1
# Actual positives: 110	Out of: 2830
# Positives found: 17.8478	Out of: 2830
# AUC = 0.773643048128
# AUPRC = 0.280119650847
# fold #: 2
# Actual positives: 110	Out of: 2829
# Positives found: 18.3688	Out of: 2829
# AUC = 0.784061653683
# AUPRC = 0.245351496886
# fold #: 3
# Actual positives: 110	Out of: 2829
# Positives found: 22.9277	Out of: 2829
# AUC = 0.803677822729
# AUPRC = 0.385021225381
# fold #: 4
# Actual positives: 109	Out of: 2828
# Positives found: 24.0065	Out of: 2828
# AUC = 0.787944839407
# AUPRC = 0.314490674232
# fold #: 5
# Actual positives: 109	Out of: 2828
# Positives found: 22.7303	Out of: 2828
# AUC = 0.794241001987
# AUPRC = 0.333812026197
# fold #: 6
# Actual positives: 109	Out of: 2828
# Positives found: 26.1105	Out of: 2828
# AUC = 0.832821024999
# AUPRC = 0.426042535295
# fold #: 7
# Actual positives: 109	Out of: 2828
# Positives found: 21.8763	Out of: 2828
# AUC = 0.779975098778
# AUPRC = 0.289886425725
# fold #: 8
# Actual positives: 109	Out of: 2828
# Positives found: 27.2471	Out of: 2828
# AUC = 0.817080618549
# AUPRC = 0.382244970315
# fold #: 9
# Actual positives: 109	Out of: 2828
# Positives found: 20.3295	Out of: 2828
# AUC = 0.81006238802
# AUPRC = 0.33154659722
# fold #: 10
# Actual positives: 109	Out of: 2828
# Positives found: 18.9158	Out of: 2828
# AUC = 0.818200836114
# AUPRC = 0.300039511487
# avg auc = 0.80017083324
# avg auprc = 0.328855511359
# Finished ion XGB
# fold #: 1
# Actual positives: 153	Out of: 2873
# Positives found: 21.0287	Out of: 2873
# AUC = 0.791089965398
# AUPRC = 0.258542350743
# fold #: 2
# Actual positives: 153	Out of: 2872
# Positives found: 20.4181	Out of: 2872
# AUC = 0.775537430861
# AUPRC = 0.229972985579
# fold #: 3
# Actual positives: 153	Out of: 2872
# Positives found: 17.1583	Out of: 2872
# AUC = 0.835925837786
# AUPRC = 0.282292098735
# fold #: 4
# Actual positives: 153	Out of: 2872
# Positives found: 22.6232	Out of: 2872
# AUC = 0.796186121868
# AUPRC = 0.265167265463
# fold #: 5
# Actual positives: 153	Out of: 2872
# Positives found: 20.8295	Out of: 2872
# AUC = 0.807842175733
# AUPRC = 0.245763089747
# fold #: 6
# Actual positives: 152	Out of: 2871
# Positives found: 21.6008	Out of: 2871
# AUC = 0.809319409226
# AUPRC = 0.289365582909
# fold #: 7
# Actual positives: 152	Out of: 2871
# Positives found: 19.6493	Out of: 2871
# AUC = 0.813527128782
# AUPRC = 0.218963567029
# fold #: 8
# Actual positives: 152	Out of: 2871
# Positives found: 22.8114	Out of: 2871
# AUC = 0.809179071253
# AUPRC = 0.276233169355
# fold #: 9
# Actual positives: 152	Out of: 2871
# Positives found: 26.1941	Out of: 2871
# AUC = 0.815022454076
# AUPRC = 0.306038683485
# fold #: 10
# Actual positives: 152	Out of: 2871
# Positives found: 22.0297	Out of: 2871
# AUC = 0.76598401115
# AUPRC = 0.228618230751
# avg auc = 0.801961360613
# avg auprc = 0.26009570238
# Finished metabolite XGB
