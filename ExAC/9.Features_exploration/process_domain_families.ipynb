# %%
import numpy as np
import pandas as pd
import pickle
from collections import defaultdict
import operator

curr_dir = !pwd
instance_cutoff = "10"

# Read the list of filtered domains
with open(curr_dir[0] + "/../5.domains_stats/filtered"+instance_cutoff+"_list.pik", 'rb') as handle:
    filtered_domains_list = pickle.load(handle)
filtered_domains_list.sort()

domains_dict = defaultdict(defaultdict)
# Read GO terms line by line
with open(curr_dir[0] + '/../pfam2GO/pfam2go.txt','r') as f:
    for line in f.readlines():
        # Skip heading
        if line[0] != 'P':
            continue
        # Skip domains that are not included in the analysis
        domain = line[13:line.find('>')-1]
        if not domain in filtered_domains_list:
            continue
        # Map domain to descriptions and GO numbers
        tokens = line.split('GO:')
        name = tokens[1][0:len(tokens[1])-3]
        number = int(tokens[2])
        # If domain not already present, create a new dictionary and add it
        if not domain in domains_dict:
            temp = defaultdict(list)
            temp['names'].append(name)
            temp['numbers'].append(number)
            domains_dict[domain] = temp
        # Otherwise, append to the existing dictionary
        else:
            domains_dict[domain]['names'].append(name)
            domains_dict[domain]['numbers'].append(number)
            
# Compute frequency counts
counts = {}
numbers_to_names = {}
numbers_to_domains = {}
for k in domains_dict.keys():
    for i in range(0,len(domains_dict[k]['numbers'])):
        num = domains_dict[k]['numbers'][i]
        if num in counts:
            counts[num] += 1
        else:
            counts[num] = 1
        if not num in numbers_to_names.keys():
            numbers_to_names[num] = domains_dict[k]['names'][i]
            numbers_to_domains[num] = k
        else:
            numbers_to_domains[num] += "." + k
sorted_counts = sorted(counts.items(),key=operator.itemgetter(1),reverse=True)

# Add to dataframe
all_counts = pd.DataFrame(columns=['number','count','name','domains'])
i = 1
for c in sorted_counts:
    all_counts.loc[i,'number'] = c[0]
    all_counts.loc[i,'count'] = c[1]
    all_counts.loc[i,'name'] = numbers_to_names[c[0]]
    all_counts.loc[i,'domains'] = numbers_to_domains[c[0]]
    i += 1
    
# Save to csv
all_counts.to_csv('freq_counts' + instance_cutoff + '.csv')

# %%
# Reorganize by domain — traverse GO term tree first!
import numpy as np
import pandas as pd

instance_cutoff = "10"

# Read file
freq_counts_broad = pd.read_csv("freq_counts_broad"+instance_cutoff,index_col=0)

domain_counts = pd.DataFrame(columns=["count","groups"])
for row in freq_counts_broad.iterrows():
    for d in freq_counts_broad.loc[row[0],"domains"].split("."):
        if d in domain_counts.index:
            domain_counts.loc[d,"count"] += 1
            domain_counts.loc[d,"groups"] += "." + freq_counts_broad.loc[row[0],"name"]
        else:
            domain_counts.loc[d,"count"] = 1
            domain_counts.loc[d,"groups"] = freq_counts_broad.loc[row[0],"name"]

domain_counts.sort_index()
# Out:
#                 count                                             groups
# 2OG-FeII_Oxy_3      8  oxidation-reduction process.metabolic process....
# 7tm_1              26  integral component of membrane.membrane.G-prot...
# 7tm_2              26  integral component of membrane.membrane.G-prot...
# 7tm_3              26  integral component of membrane.membrane.G-prot...
# 7tm_4              26  integral component of membrane.membrane.G-prot...
# A2M                 2  endopeptidase inhibitor activity.endopeptidase...
# A2M_N               8  endopeptidase inhibitor activity.peptidase inh...
# A2M_comp            4  extracellular region.extracellular space.cellu...
# A2M_recep           2            extracellular region.cellular_component
# AAA                10  ATP binding.purine ribonucleoside binding.aden...
# AAA_5              28  ATP binding.catalytic activity.hydrolase activ...
# AA_permease        12  membrane.transmembrane transport.transport.cel...
# AA_permease_2      35  membrane.transmembrane transport.transport.tra...
# ABC_membrane       52  integral component of membrane.membrane.ATP bi...
# ABC_tran           28  ATP binding.catalytic activity.hydrolase activ...
# ADH_N               5  oxidation-reduction process.metabolic process....
# ADH_zinc_N          5  oxidation-reduction process.metabolic process....
# AMP-binding         4  metabolic process.catalytic activity.biologica...
# ANATO               2            extracellular region.cellular_component
# APC_r              15  signal transduction.Wnt signaling pathway.cell...
# APOBEC_N           11  zinc ion binding.catalytic activity.metal ion ...
# ARID                6  DNA binding.nucleic acid binding.binding.organ...
# Acetyltransf_1      8  catalytic activity.transferase activity, trans...
# Acyl-CoA_dh_1       9  oxidation-reduction process.metabolic process....
# Acyl-CoA_dh_M       9  oxidation-reduction process.metabolic process....
# Acyl-CoA_dh_N      20  oxidation-reduction process.metabolic process....
# Acyltransferase     6  metabolic process.catalytic activity.transfera...
# Adaptin_N          30  membrane.transport.intracellular.cytoplasm.int...
# Aldedh              8  oxidation-reduction process.metabolic process....
# Aminotran_1_2      11  metabolic process.biosynthetic process.pyridox...
# ...               ...                                                ...
# Xin                18  protein binding.actin binding.cell junction.ac...
# Xlink               8  cell adhesion.hyaluronic acid binding.binding....
# Y_phosphatase      25  metabolic process.catalytic activity.hydrolase...
# ZZ                  7  zinc ion binding.metal ion binding.binding.tra...
# Zip                24  membrane.transmembrane transport.transport.tra...
# bZIP_1             51  regulation of transcription, DNA-templated.tra...
# bZIP_2             51  regulation of transcription, DNA-templated.tra...
# bZIP_Maf           64  regulation of transcription, DNA-templated.nuc...
# fn1                 2            extracellular region.cellular_component
# fn3                 3         protein binding.binding.molecular_function
# p450               19  oxidation-reduction process.metabolic process....
# tRNA-synt_1        71  ATP binding.metabolic process.catalytic activi...
# tRNA_int_endo      37  metabolic process.catalytic activity.hydrolase...
# ubiquitin           3         protein binding.binding.molecular_function
# wnt                26  protein binding.extracellular region.signal tr...
# zf-A20             11  zinc ion binding.DNA binding.nucleic acid bind...
# zf-AN1              7  zinc ion binding.metal ion binding.binding.tra...
# zf-BED              6  DNA binding.nucleic acid binding.binding.organ...
# zf-B_box           11  zinc ion binding.intracellular.metal ion bindi...
# zf-C2HC            67  regulation of transcription, DNA-templated.zin...
# zf-C3HC4            5  metal ion binding.binding.molecular_function.c...
# zf-C4              72  regulation of transcription, DNA-templated.zin...
# zf-CCCH             5  metal ion binding.binding.molecular_function.c...
# zf-CCHC            10  zinc ion binding.nucleic acid binding.metal io...
# zf-CXXC            11  zinc ion binding.DNA binding.nucleic acid bind...
# zf-FCS              7  zinc ion binding.metal ion binding.binding.tra...
# zf-NF-X1           67  regulation of transcription, DNA-templated.zin...
# zf-TRAF             7  zinc ion binding.metal ion binding.binding.tra...
# zf-UBP              7  zinc ion binding.metal ion binding.binding.tra...
# zf-rbx1             7  zinc ion binding.metal ion binding.binding.tra...
#
# [339 rows x 2 columns]

# %%
# For domains that have no pfam GO term, find domain with GO term from the same family if possible
import numpy as np
import pandas as pd
import pickle

curr_dir = !pwd

# Read the list of filtered domains
with open(curr_dir[0] + "/../5.domains_stats/filtered"+instance_cutoff+"_list.pik", 'rb') as handle:
    filtered_domains_list = pickle.load(handle)
filtered_domains_list.sort()

# Map family to domain name
# Any match is fine, so overwriting on repeats is allowable
fam_map = {}
for row in domain_counts.iterrows():
    fam = row[0].replace('-','_').split('_')[0].lower()
    fam_map[fam] = row[0]
    
# Find matches
for domain in filtered_domains_list:
    if not domain in domain_counts.index:
        fam = domain.replace('-','_').split('_')[0].lower()
        if not fam in fam_map:
            continue
        close_domain = fam_map[fam]
        # Copy row
        domain_counts.loc[domain,"count"] = domain_counts.loc[close_domain,"count"]
        domain_counts.loc[domain,"groups"] = domain_counts.loc[close_domain,"groups"]
        # Update freq_counts
        terms = domain_counts.loc[domain,"groups"].split(".")
        for t in terms:
            freq_counts_broad.loc[freq_counts_broad.loc[:,"name"] == t,"domains"] += "." + domain
            freq_counts_broad.loc[freq_counts_broad.loc[:,"name"] == t,"count"] += 1

# %%
# Check which domains are omitted
count = 0
f = open("unmapped_domains", 'w')
for domain in filtered_domains_list:
    if not domain in domain_counts.index:
        count += 1
        f.write(domain + '\n')
print(count)
f.close()
# Out:
# 260

# %%
# Save to csv
freq_counts_broad.to_csv('freq_counts_expanded' + instance_cutoff + '.csv')
# Print
freq_counts_broad.sort_values(["count"],ascending=False)
# Out:
#       number  count                                               name  \
# 244     3674    337                                 molecular_function
# 216     5488    231                                            binding
# 238     8150    189                                 biological_process
# 443     9987    111                                   cellular process
# 218     5575    107                                 cellular_component
# 1       5515    105                                    protein binding
# 26      3824     93                                 catalytic activity
# 19      8152     92                                  metabolic process
# 451    43167     91                                        ion binding
# 442    44699     91                            single-organism process
# 231    44763     68                   single-organism cellular process
# 27     46872     66                                  metal ion binding
# 588    65007     66                              biological regulation
# 446    50789     66                   regulation of biological process
# 245    43169     66                                     cation binding
# 235    50794     65                     regulation of cellular process
# 386    71704     64                organic substance metabolic process
# 385    44238     64                          primary metabolic process
# 228    97159     62                    organic cyclic compound binding
# 229  1901363     62                      heterocyclic compound binding
# 449    43170     58                    macromolecule metabolic process
# 3      16020     56                                           membrane
# 569    44237     51                         cellular metabolic process
# 529    44260     47           cellular macromolecule metabolic process
# 240    50896     46                               response to stimulus
# 40     16787     45                                 hydrolase activity
# 243    44464     41                                          cell part
# 450     5623     41                                               cell
# 25      5622     39                                      intracellular
# 11      3676     37                               nucleic acid binding
# ..       ...    ...                                                ...
# 288    51128      1      regulation of cellular component organization
# 290     1871      1                                    pattern binding
# 494    16278      1                lysine N-methyltransferase activity
# 291      301      1  retrograde transport, vesicle recycling within...
# 292     6605      1                                  protein targeting
# 293    16482      1                              cytoplasmic transport
# 294    34067      1            protein localization to Golgi apparatus
# 295    72600      1     establishment of protein localization to Golgi
# 296  1902580      1              single-organism cellular localization
# 297    32813      1  tumor necrosis factor receptor superfamily bin...
# 204     5086      1     ARF guanyl-nucleotide exchange factor activity
# 202    30170      1                        pyridoxal phosphate binding
# 200    46983      1                      protein dimerization activity
# 199     8138      1  protein tyrosine/serine/threonine phosphatase ...
# 493     8276      1                 protein methyltransferase activity
# 188    51015      1                             actin filament binding
# 490     8238      1                              exopeptidase activity
# 488    50790      1                   regulation of catalytic activity
# 191     8009      1                                 chemokine activity
# 192     6644      1                     phospholipid metabolic process
# 485    72594      1  establishment of protein localization to organ...
# 484    33365      1                  protein localization to organelle
# 483     6891      1             intra-Golgi vesicle-mediated transport
# 193    70588      1                calcium ion transmembrane transport
# 481    40007      1                                             growth
# 195     8641      1           small protein activating enzyme activity
# 196    31683      1       G-protein beta/gamma-subunit complex binding
# 197    15299      1                  solute:proton antiporter activity
# 198     4553      1  hydrolase activity, hydrolyzing O-glycosyl com...
# 379    32309      1                                icosanoid secretion
#
#                                                domains
# 244  ECH_1.PP2C.Prenyltrans.Epimerase.AMP-binding.M...
# 216  LRR_6.WW.EF-hand_4.Fz.Kazal_2.Kazal_1.Spectrin...
# 238  Methyltransf_11.Aldedh.ECH_1.Sulfatase.Acyltra...
# 443  Zip.Ion_trans.Sugar_tr.ABC_membrane.AA_permeas...
# 218  Zip.Ion_trans.AA_permease_2.MIP.Frizzled.HRM.L...
# 1    LRR_6.WW.EF-hand_4.Fz.Kazal_2.Kazal_1.Spectrin...
# 26   ECH_1.PP2C.Prenyltrans.Epimerase.AMP-binding.A...
# 19   Methyltransf_11.Aldedh.ECH_1.Sulfatase.Acyltra...
# 451  FYVE.HMA.zf-CCCH.zf-C3HC4.Metallothio.EF-hand_...
# 442  Acyl-CoA_dh_N.Acyl-CoA_dh_M.Aldedh.2OG-FeII_Ox...
# 231  Zip.Ion_trans.Sugar_tr.ABC_membrane.AA_permeas...
# 27   FYVE.HMA.zf-CCCH.zf-C3HC4.Metallothio.EF-hand_...
# 588  RA.TIR.PI-PLC-Y.TIR_2.Death.PDEase_I.RhoGAP.HR...
# 446  RA.TIR.PI-PLC-Y.TIR_2.Death.PDEase_I.RhoGAP.HR...
# 245  FYVE.HMA.zf-CCCH.zf-C3HC4.Metallothio.EF-hand_...
# 235  RA.TIR.PI-PLC-Y.TIR_2.Death.PDEase_I.RhoGAP.HR...
# 386  Glyco_hydro_31.PI-PLC-Y.Phospholip_A2_1.Peptid...
# 385  Glyco_hydro_31.PI-PLC-Y.Peptidase_M14.Peptidas...
# 228  DDE_1.DEAD.THAP.S1.R3H.KRAB.zf-CCHC.TFIIS_C.RR...
# 229  DDE_1.DEAD.THAP.S1.R3H.KRAB.zf-CCHC.TFIIS_C.RR...
# 449  Peptidase_M14.Peptidase_C2.Peptidase_C1.Peptid...
# 3    Zip.Ion_trans.AA_permease_2.MIP.Frizzled.HRM.L...
# 569  PPTA.Phospholip_A2_1.TFIIS_C.Hairy_orange.PAS....
# 529  TFIIS_C.Hairy_orange.PAS.E2F_TDP.zf-C2HC.KRAB....
# 240  Somatomedin_B.MHC_I_C.MHC_II_alpha.IL8.TNF.MHC...
# 40   ResIII.NUDIX.Metallophos.PLAC.UCH.Sulfatase.Ph...
# 243  Cofilin_ADF.KRAB.Peptidase_C2.MH1.NTF2.zf-B_bo...
# 450  Cofilin_ADF.KRAB.Peptidase_C2.MH1.NTF2.zf-B_bo...
# 25   Cofilin_ADF.KRAB.Peptidase_C2.MH1.NTF2.zf-B_bo...
# 11   DDE_1.DEAD.THAP.S1.R3H.KRAB.zf-CCHC.TFIIS_C.RR...
# ..                                                 ...
# 288                                              IGFBP
# 290                                      Somatomedin_B
# 494                                            Pre-SET
# 291                                               GRIP
# 292                                               GRIP
# 293                                               GRIP
# 294                                               GRIP
# 295                                               GRIP
# 296                                               GRIP
# 297                                                TNF
# 204                                               Sec7
# 202                                      Aminotran_1_2
# 200                                                HLH
# 199                                               DSPc
# 493                                            Pre-SET
# 188                                             Fascin
# 490                                      Peptidase_M14
# 488                                             RasGAP
# 191                                                IL8
# 192                                    Phospholip_A2_1
# 485                                               GRIP
# 484                                               GRIP
# 483                                               GRIP
# 193                                          RYDR_ITPR
# 481                                              IGFBP
# 195                                               ThiF
# 196                                            G-alpha
# 197                                     Na_H_Exchanger
# 198                                     Glyco_hydro_31
# 379                                    Phospholip_A2_1
#
# [695 rows x 4 columns]

# %%
# Modify freq_counts_broad for logical operations
for row in freq_counts_broad.iterrows():
    domains = freq_counts_broad.loc[row[0],"domains"]
    # This cell may be rerun, so be sure to only append once
    if domains[0] != '.':
        freq_counts_broad.loc[row[0],"domains"] = "." + freq_counts_broad.loc[row[0],"domains"] + "."
        
# The union of domains in two or more groups
def combine(groups):
    domains_combined = "."
    for g in groups:
        # A list of terms can also be a string separated by periods
        terms = g.split(".")
        for t in terms:
            domains = freq_counts_broad.loc[freq_counts_broad.loc[:,"name"] == t,"domains"].values[0].split(".")
            for d in domains:
                if len(d) > 0 and not "." + d + "." in domains_combined:
                    domains_combined += d + "."
    return(domains_combined)

# Manually curate group forming
comb_test = combine(["nucleic acid binding","nucleotide binding","ATP binding"]).split(".")
comb_binding = combine(["ATP binding","DNA binding","protein binding","nucleic acid binding","metal ion binding"]).split(".")
comb_other = combine(["catalytic activity","metabolic process","membrane","signal transduction",
                      "intracellular"]).split(".")
comb_all = combine(["ATP binding","DNA binding","protein binding","nucleic acid binding","metal ion binding",
                    "nucleotide binding","catalytic activity","metabolic process","membrane","signal transduction","intracellular",
                    "enzyme regulator activity"]).split(".")
print(len(comb_test)-2)
print(len(comb_binding)-2)
print(len(comb_other)-2)
print(len(comb_all)-2)
# Out:
# 69
# 221
# 220
# 410

# %%
# Remove one or more groups and all domains associated from freq_counts_broad
def remove(groups):
    freq_counts_removed = freq_counts_broad.copy()
    for g in groups:
        for d in freq_counts_removed.loc[freq_counts_removed.loc[:,"name"] == g,"domains"].values[0].split("."):
            for row in freq_counts_removed.iterrows():
                if "." + d + "." in freq_counts_removed.loc[row[0],"domains"]:
                    freq_counts_removed.loc[row[0],"count"] -= 1
                    freq_counts_removed.loc[row[0],"domains"] = freq_counts_removed.loc[row[0],"domains"].replace(d + ".","")
    # Remove rows with no entries left
    freq_counts_removed = freq_counts_removed.drop(freq_counts_removed.loc[freq_counts_removed.loc[:,"count"] == 0,:].index)
    return(freq_counts_removed)

# Check for more groups to include
freq_counts_removed = remove(["ATP binding","DNA binding","protein binding","nucleic acid binding","metal ion binding",
        "nucleotide binding", "lipid binding","catalytic activity","metabolic process","membrane","signal transduction","intracellular",
        "extracellular region", "enzyme regulator activity","transport"]).sort_values(["count"],ascending=False)

# %%
# Organize categories into a table
import pandas as pd

# List of groups — a '.' indicates a group is a combination of GO terms
groups = ["ATP binding","DNA binding","nucleic acid binding.nucleotide binding","protein binding.enzyme regulator activity",
          "metal ion binding","catalytic activity","metabolic process","membrane","signal transduction",
          "intracellular"]
copy = ["ATP binding","DNA binding","nucleic acid binding.nucleotide binding","protein binding.enzyme regulator activity",
        "metal ion binding","catalytic activity","metabolic process","membrane","signal transduction",
        "intracellular"]

comb = combine(groups).split(".")

# Initialize and populate dataframe
categories = pd.DataFrame(columns=["domains","total overlap","ATP binding overlap"])
for g in groups:
    terms = g.split(".")
    categories.loc[terms[0],"domains"] = 0
    for t in terms:
        categories.loc[terms[0],"domains"] += freq_counts_broad.loc[freq_counts_broad.loc[:,"name"] == t,"count"].values[0]
    term = combine(terms).split(".")
    copy.remove(g)
    others = combine(copy).split(".")
    categories.loc[terms[0],"total overlap"] = len(term) + len(others) - len(comb) - 2
    for other_group in copy:
        other_terms = other_group.split(".")
        other = combine(other_terms).split(".")
        both = combine(terms+other_terms).split(".")
        categories.loc[terms[0],other_terms[0]+" overlap"] = len(term) + len(other) - len(both) - 2
    copy.append(g)
categories
# Out:
#                      domains total overlap ATP binding overlap  \
# ATP binding               24            14                 NaN
# DNA binding               22            22                   2
# nucleic acid binding      62            45                  14
# protein binding          111            10                   1
# metal ion binding         66            16                   0
# catalytic activity        93            73                   9
# metabolic process         92            77                   3
# membrane                  56            14                   1
# signal transduction       35            20                   0
# intracellular             39            27                   2
#
#                       DNA binding overlap  nucleic acid binding overlap  \
# ATP binding                           2.0                          14.0
# DNA binding                           NaN                          22.0
# nucleic acid binding                 22.0                           NaN
# protein binding                       0.0                           3.0
# metal ion binding                     4.0                           6.0
# catalytic activity                    1.0                          14.0
# metabolic process                    10.0                          16.0
# membrane                              0.0                           1.0
# signal transduction                   0.0                           2.0
# intracellular                         5.0                           8.0
#
#                       protein binding overlap  metal ion binding overlap  \
# ATP binding                               1.0                        0.0
# DNA binding                               0.0                        4.0
# nucleic acid binding                      3.0                        6.0
# protein binding                           NaN                        0.0
# metal ion binding                         0.0                        NaN
# catalytic activity                        2.0                        6.0
# metabolic process                         0.0                        9.0
# membrane                                  0.0                        1.0
# signal transduction                       5.0                        0.0
# intracellular                             3.0                        5.0
#
#                       catalytic activity overlap  metabolic process overlap  \
# ATP binding                                  9.0                        3.0
# DNA binding                                  1.0                       10.0
# nucleic acid binding                        14.0                       16.0
# protein binding                              2.0                        0.0
# metal ion binding                            6.0                        9.0
# catalytic activity                           NaN                       56.0
# metabolic process                           56.0                        NaN
# membrane                                     3.0                        1.0
# signal transduction                          6.0                        5.0
# intracellular                                7.0                       14.0
#
#                       membrane overlap  signal transduction overlap  \
# ATP binding                        1.0                          0.0
# DNA binding                        0.0                          0.0
# nucleic acid binding               1.0                          2.0
# protein binding                    0.0                          5.0
# metal ion binding                  1.0                          0.0
# catalytic activity                 3.0                          6.0
# metabolic process                  1.0                          5.0
# membrane                           NaN                          8.0
# signal transduction                8.0                          NaN
# intracellular                      3.0                          1.0
#
#                       intracellular overlap
# ATP binding                             2.0
# DNA binding                             5.0
# nucleic acid binding                    8.0
# protein binding                         3.0
# metal ion binding                       5.0
# catalytic activity                      7.0
# metabolic process                      14.0
# membrane                                3.0
# signal transduction                     1.0
# intracellular                           NaN
