# %%
import pandas as pd
import numpy as np
import pickle
from collections import defaultdict
import os
import sys

#Helper functions to classify positives/negatives by position
curr_dir = os.getcwd()
sys.path.append(curr_dir+"/../10.Prediction/utils")
from prop_threshold_funcs import create_negatives_datasets_combined, create_positives_datasets_combined

# %% [markdown]
# ### Obtain position labels

# %%
def read_labels(input_path, filename):   
    features_all = pd.read_csv(input_path+filename, sep='\t', index_col=0)
    
    #Remove feature columns and save labels
    for col in features_all.columns:
        if not "prop_th" in col and not "propensity" in col and not "domain_length" in col:
            del features_all[col]
            
    return features_all

# %%
#If pre-parsed file is not available, get labels from features table

#Domains >10 instances
train_datafile_date = "08.06.18"
if not os.path.exists("train_position_labels_"+train_datafile_date+".csv"):
    input_path = curr_dir+"/../10.Prediction/domains_similarity/filtered_features_table/"
    filename = "windowed_positions_features_mediode_filter_"+train_datafile_date+".csv"
    train_position_labels = read_labels(input_path, filename)
            
    train_position_labels.to_csv("train_position_labels_"+train_datafile_date+".csv", sep='\t')
else:
    train_position_labels = pd.read_csv("train_position_labels_"+train_datafile_date+".csv", sep='\t', index_col=0)
    
#Domains <10 instances
not_train_datafile_date = "01.22.19"
if not os.path.exists("not_train_position_labels_"+not_train_datafile_date+".csv"):
    input_path = curr_dir+"/../9.Features_exploration/features_tables_v31/"
    filename = "windowed_positions_features_less_than_10_"+not_train_datafile_date+".csv"
    not_train_position_labels = read_labels(input_path, filename)
            
    not_train_position_labels.to_csv("not_train_position_labels_"+not_train_datafile_date+".csv", sep='\t')
else:
    not_train_position_labels = pd.read_csv("not_train_position_labels_"+not_train_datafile_date+".csv", sep='\t', index_col=0)

# %%
train_position_labels
# Out:
#                    domain_length  dna_propensity  dna_prop_th_0.1  \
# 2OG-FeII_Oxy_3_1              96              -1               -1
# 2OG-FeII_Oxy_3_10             96              -1               -1
# 2OG-FeII_Oxy_3_11             96              -1               -1
# 2OG-FeII_Oxy_3_12             96              -1               -1
# 2OG-FeII_Oxy_3_13             96              -1               -1
# 2OG-FeII_Oxy_3_14             96              -1               -1
# 2OG-FeII_Oxy_3_15             96              -1               -1
# 2OG-FeII_Oxy_3_16             96              -1               -1
# 2OG-FeII_Oxy_3_17             96              -1               -1
# 2OG-FeII_Oxy_3_18             96              -1               -1
# 2OG-FeII_Oxy_3_19             96              -1               -1
# 2OG-FeII_Oxy_3_2              96              -1               -1
# 2OG-FeII_Oxy_3_20             96              -1               -1
# 2OG-FeII_Oxy_3_21             96              -1               -1
# 2OG-FeII_Oxy_3_22             96              -1               -1
# 2OG-FeII_Oxy_3_23             96              -1               -1
# 2OG-FeII_Oxy_3_24             96              -1               -1
# 2OG-FeII_Oxy_3_25             96              -1               -1
# 2OG-FeII_Oxy_3_26             96              -1               -1
# 2OG-FeII_Oxy_3_27             96              -1               -1
# 2OG-FeII_Oxy_3_28             96              -1               -1
# 2OG-FeII_Oxy_3_29             96              -1               -1
# 2OG-FeII_Oxy_3_3              96              -1               -1
# 2OG-FeII_Oxy_3_30             96              -1               -1
# 2OG-FeII_Oxy_3_31             96              -1               -1
# 2OG-FeII_Oxy_3_32             96              -1               -1
# 2OG-FeII_Oxy_3_33             96              -1               -1
# 2OG-FeII_Oxy_3_34             96              -1               -1
# 2OG-FeII_Oxy_3_35             96              -1               -1
# 2OG-FeII_Oxy_3_36             96              -1               -1
# ...                          ...             ...              ...
# zf-UBP_40                     64              -1               -1
# zf-UBP_41                     64              -1               -1
# zf-UBP_42                     64              -1               -1
# zf-UBP_43                     64              -1               -1
# zf-UBP_44                     64              -1               -1
# zf-UBP_45                     64              -1               -1
# zf-UBP_46                     64              -1               -1
# zf-UBP_47                     64              -1               -1
# zf-UBP_48                     64              -1               -1
# zf-UBP_49                     64              -1               -1
# zf-UBP_5                      64              -1               -1
# zf-UBP_50                     64              -1               -1
# zf-UBP_51                     64              -1               -1
# zf-UBP_52                     64              -1               -1
# zf-UBP_53                     64              -1               -1
# zf-UBP_54                     64              -1               -1
# zf-UBP_55                     64              -1               -1
# zf-UBP_56                     64              -1               -1
# zf-UBP_57                     64              -1               -1
# zf-UBP_58                     64              -1               -1
# zf-UBP_59                     64              -1               -1
# zf-UBP_6                      64              -1               -1
# zf-UBP_60                     64              -1               -1
# zf-UBP_61                     64              -1               -1
# zf-UBP_62                     64              -1               -1
# zf-UBP_63                     64              -1               -1
# zf-UBP_64                     64              -1               -1
# zf-UBP_7                      64              -1               -1
# zf-UBP_8                      64              -1               -1
# zf-UBP_9                      64              -1               -1
#
#                    dna_prop_th_0.25  dna_prop_th_0.5  dna_prop_th_0.75  \
# 2OG-FeII_Oxy_3_1                 -1               -1                -1
# 2OG-FeII_Oxy_3_10                -1               -1                -1
# 2OG-FeII_Oxy_3_11                -1               -1                -1
# 2OG-FeII_Oxy_3_12                -1               -1                -1
# 2OG-FeII_Oxy_3_13                -1               -1                -1
# 2OG-FeII_Oxy_3_14                -1               -1                -1
# 2OG-FeII_Oxy_3_15                -1               -1                -1
# 2OG-FeII_Oxy_3_16                -1               -1                -1
# 2OG-FeII_Oxy_3_17                -1               -1                -1
# 2OG-FeII_Oxy_3_18                -1               -1                -1
# 2OG-FeII_Oxy_3_19                -1               -1                -1
# 2OG-FeII_Oxy_3_2                 -1               -1                -1
# 2OG-FeII_Oxy_3_20                -1               -1                -1
# 2OG-FeII_Oxy_3_21                -1               -1                -1
# 2OG-FeII_Oxy_3_22                -1               -1                -1
# 2OG-FeII_Oxy_3_23                -1               -1                -1
# 2OG-FeII_Oxy_3_24                -1               -1                -1
# 2OG-FeII_Oxy_3_25                -1               -1                -1
# 2OG-FeII_Oxy_3_26                -1               -1                -1
# 2OG-FeII_Oxy_3_27                -1               -1                -1
# 2OG-FeII_Oxy_3_28                -1               -1                -1
# 2OG-FeII_Oxy_3_29                -1               -1                -1
# 2OG-FeII_Oxy_3_3                 -1               -1                -1
# 2OG-FeII_Oxy_3_30                -1               -1                -1
# 2OG-FeII_Oxy_3_31                -1               -1                -1
# 2OG-FeII_Oxy_3_32                -1               -1                -1
# 2OG-FeII_Oxy_3_33                -1               -1                -1
# 2OG-FeII_Oxy_3_34                -1               -1                -1
# 2OG-FeII_Oxy_3_35                -1               -1                -1
# 2OG-FeII_Oxy_3_36                -1               -1                -1
# ...                             ...              ...               ...
# zf-UBP_40                        -1               -1                -1
# zf-UBP_41                        -1               -1                -1
# zf-UBP_42                        -1               -1                -1
# zf-UBP_43                        -1               -1                -1
# zf-UBP_44                        -1               -1                -1
# zf-UBP_45                        -1               -1                -1
# zf-UBP_46                        -1               -1                -1
# zf-UBP_47                        -1               -1                -1
# zf-UBP_48                        -1               -1                -1
# zf-UBP_49                        -1               -1                -1
# zf-UBP_5                         -1               -1                -1
# zf-UBP_50                        -1               -1                -1
# zf-UBP_51                        -1               -1                -1
# zf-UBP_52                        -1               -1                -1
# zf-UBP_53                        -1               -1                -1
# zf-UBP_54                        -1               -1                -1
# zf-UBP_55                        -1               -1                -1
# zf-UBP_56                        -1               -1                -1
# zf-UBP_57                        -1               -1                -1
# zf-UBP_58                        -1               -1                -1
# zf-UBP_59                        -1               -1                -1
# zf-UBP_6                         -1               -1                -1
# zf-UBP_60                        -1               -1                -1
# zf-UBP_61                        -1               -1                -1
# zf-UBP_62                        -1               -1                -1
# zf-UBP_63                        -1               -1                -1
# zf-UBP_64                        -1               -1                -1
# zf-UBP_7                         -1               -1                -1
# zf-UBP_8                         -1               -1                -1
# zf-UBP_9                         -1               -1                -1
#
#                    dnabase_propensity  dnabase_prop_th_0.1  \
# 2OG-FeII_Oxy_3_1                   -1                   -1
# 2OG-FeII_Oxy_3_10                  -1                   -1
# 2OG-FeII_Oxy_3_11                  -1                   -1
# 2OG-FeII_Oxy_3_12                  -1                   -1
# 2OG-FeII_Oxy_3_13                  -1                   -1
# 2OG-FeII_Oxy_3_14                  -1                   -1
# 2OG-FeII_Oxy_3_15                  -1                   -1
# 2OG-FeII_Oxy_3_16                  -1                   -1
# 2OG-FeII_Oxy_3_17                  -1                   -1
# 2OG-FeII_Oxy_3_18                  -1                   -1
# 2OG-FeII_Oxy_3_19                  -1                   -1
# 2OG-FeII_Oxy_3_2                   -1                   -1
# 2OG-FeII_Oxy_3_20                  -1                   -1
# 2OG-FeII_Oxy_3_21                  -1                   -1
# 2OG-FeII_Oxy_3_22                  -1                   -1
# 2OG-FeII_Oxy_3_23                  -1                   -1
# 2OG-FeII_Oxy_3_24                  -1                   -1
# 2OG-FeII_Oxy_3_25                  -1                   -1
# 2OG-FeII_Oxy_3_26                  -1                   -1
# 2OG-FeII_Oxy_3_27                  -1                   -1
# 2OG-FeII_Oxy_3_28                  -1                   -1
# 2OG-FeII_Oxy_3_29                  -1                   -1
# 2OG-FeII_Oxy_3_3                   -1                   -1
# 2OG-FeII_Oxy_3_30                  -1                   -1
# 2OG-FeII_Oxy_3_31                  -1                   -1
# 2OG-FeII_Oxy_3_32                  -1                   -1
# 2OG-FeII_Oxy_3_33                  -1                   -1
# 2OG-FeII_Oxy_3_34                  -1                   -1
# 2OG-FeII_Oxy_3_35                  -1                   -1
# 2OG-FeII_Oxy_3_36                  -1                   -1
# ...                               ...                  ...
# zf-UBP_40                          -1                   -1
# zf-UBP_41                          -1                   -1
# zf-UBP_42                          -1                   -1
# zf-UBP_43                          -1                   -1
# zf-UBP_44                          -1                   -1
# zf-UBP_45                          -1                   -1
# zf-UBP_46                          -1                   -1
# zf-UBP_47                          -1                   -1
# zf-UBP_48                          -1                   -1
# zf-UBP_49                          -1                   -1
# zf-UBP_5                           -1                   -1
# zf-UBP_50                          -1                   -1
# zf-UBP_51                          -1                   -1
# zf-UBP_52                          -1                   -1
# zf-UBP_53                          -1                   -1
# zf-UBP_54                          -1                   -1
# zf-UBP_55                          -1                   -1
# zf-UBP_56                          -1                   -1
# zf-UBP_57                          -1                   -1
# zf-UBP_58                          -1                   -1
# zf-UBP_59                          -1                   -1
# zf-UBP_6                           -1                   -1
# zf-UBP_60                          -1                   -1
# zf-UBP_61                          -1                   -1
# zf-UBP_62                          -1                   -1
# zf-UBP_63                          -1                   -1
# zf-UBP_64                          -1                   -1
# zf-UBP_7                           -1                   -1
# zf-UBP_8                           -1                   -1
# zf-UBP_9                           -1                   -1
#
#                    dnabase_prop_th_0.25  dnabase_prop_th_0.5  \
# 2OG-FeII_Oxy_3_1                     -1                   -1
# 2OG-FeII_Oxy_3_10                    -1                   -1
# 2OG-FeII_Oxy_3_11                    -1                   -1
# 2OG-FeII_Oxy_3_12                    -1                   -1
# 2OG-FeII_Oxy_3_13                    -1                   -1
# 2OG-FeII_Oxy_3_14                    -1                   -1
# 2OG-FeII_Oxy_3_15                    -1                   -1
# 2OG-FeII_Oxy_3_16                    -1                   -1
# 2OG-FeII_Oxy_3_17                    -1                   -1
# 2OG-FeII_Oxy_3_18                    -1                   -1
# 2OG-FeII_Oxy_3_19                    -1                   -1
# 2OG-FeII_Oxy_3_2                     -1                   -1
# 2OG-FeII_Oxy_3_20                    -1                   -1
# 2OG-FeII_Oxy_3_21                    -1                   -1
# 2OG-FeII_Oxy_3_22                    -1                   -1
# 2OG-FeII_Oxy_3_23                    -1                   -1
# 2OG-FeII_Oxy_3_24                    -1                   -1
# 2OG-FeII_Oxy_3_25                    -1                   -1
# 2OG-FeII_Oxy_3_26                    -1                   -1
# 2OG-FeII_Oxy_3_27                    -1                   -1
# 2OG-FeII_Oxy_3_28                    -1                   -1
# 2OG-FeII_Oxy_3_29                    -1                   -1
# 2OG-FeII_Oxy_3_3                     -1                   -1
# 2OG-FeII_Oxy_3_30                    -1                   -1
# 2OG-FeII_Oxy_3_31                    -1                   -1
# 2OG-FeII_Oxy_3_32                    -1                   -1
# 2OG-FeII_Oxy_3_33                    -1                   -1
# 2OG-FeII_Oxy_3_34                    -1                   -1
# 2OG-FeII_Oxy_3_35                    -1                   -1
# 2OG-FeII_Oxy_3_36                    -1                   -1
# ...                                 ...                  ...
# zf-UBP_40                            -1                   -1
# zf-UBP_41                            -1                   -1
# zf-UBP_42                            -1                   -1
# zf-UBP_43                            -1                   -1
# zf-UBP_44                            -1                   -1
# zf-UBP_45                            -1                   -1
# zf-UBP_46                            -1                   -1
# zf-UBP_47                            -1                   -1
# zf-UBP_48                            -1                   -1
# zf-UBP_49                            -1                   -1
# zf-UBP_5                             -1                   -1
# zf-UBP_50                            -1                   -1
# zf-UBP_51                            -1                   -1
# zf-UBP_52                            -1                   -1
# zf-UBP_53                            -1                   -1
# zf-UBP_54                            -1                   -1
# zf-UBP_55                            -1                   -1
# zf-UBP_56                            -1                   -1
# zf-UBP_57                            -1                   -1
# zf-UBP_58                            -1                   -1
# zf-UBP_59                            -1                   -1
# zf-UBP_6                             -1                   -1
# zf-UBP_60                            -1                   -1
# zf-UBP_61                            -1                   -1
# zf-UBP_62                            -1                   -1
# zf-UBP_63                            -1                   -1
# zf-UBP_64                            -1                   -1
# zf-UBP_7                             -1                   -1
# zf-UBP_8                             -1                   -1
# zf-UBP_9                             -1                   -1
#
#                          ...         druglike_propensity  \
# 2OG-FeII_Oxy_3_1         ...                    0.000000
# 2OG-FeII_Oxy_3_10        ...                    0.037662
# 2OG-FeII_Oxy_3_11        ...                    0.000000
# 2OG-FeII_Oxy_3_12        ...                    0.849354
# 2OG-FeII_Oxy_3_13        ...                    0.000000
# 2OG-FeII_Oxy_3_14        ...                    0.075323
# 2OG-FeII_Oxy_3_15        ...                    0.887015
# 2OG-FeII_Oxy_3_16        ...                    0.000000
# 2OG-FeII_Oxy_3_17        ...                    1.000000
# 2OG-FeII_Oxy_3_18        ...                    0.000000
# 2OG-FeII_Oxy_3_19        ...                    0.075323
# 2OG-FeII_Oxy_3_2         ...                    0.461947
# 2OG-FeII_Oxy_3_20        ...                    0.000000
# 2OG-FeII_Oxy_3_21        ...                    0.000000
# 2OG-FeII_Oxy_3_22        ...                    0.000000
# 2OG-FeII_Oxy_3_23        ...                    0.037662
# 2OG-FeII_Oxy_3_24        ...                    0.000000
# 2OG-FeII_Oxy_3_25        ...                    0.000000
# 2OG-FeII_Oxy_3_26        ...                    0.075323
# 2OG-FeII_Oxy_3_27        ...                    0.000000
# 2OG-FeII_Oxy_3_28        ...                    0.000000
# 2OG-FeII_Oxy_3_29        ...                    0.000000
# 2OG-FeII_Oxy_3_3         ...                    0.000000
# 2OG-FeII_Oxy_3_30        ...                    0.000000
# 2OG-FeII_Oxy_3_31        ...                    0.000000
# 2OG-FeII_Oxy_3_32        ...                    0.000000
# 2OG-FeII_Oxy_3_33        ...                    0.037662
# 2OG-FeII_Oxy_3_34        ...                    0.000000
# 2OG-FeII_Oxy_3_35        ...                    0.887015
# 2OG-FeII_Oxy_3_36        ...                    0.000000
# ...                      ...                         ...
# zf-UBP_40                ...                   -1.000000
# zf-UBP_41                ...                   -1.000000
# zf-UBP_42                ...                   -1.000000
# zf-UBP_43                ...                   -1.000000
# zf-UBP_44                ...                   -1.000000
# zf-UBP_45                ...                   -1.000000
# zf-UBP_46                ...                   -1.000000
# zf-UBP_47                ...                   -1.000000
# zf-UBP_48                ...                   -1.000000
# zf-UBP_49                ...                   -1.000000
# zf-UBP_5                 ...                   -1.000000
# zf-UBP_50                ...                   -1.000000
# zf-UBP_51                ...                   -1.000000
# zf-UBP_52                ...                   -1.000000
# zf-UBP_53                ...                   -1.000000
# zf-UBP_54                ...                   -1.000000
# zf-UBP_55                ...                   -1.000000
# zf-UBP_56                ...                   -1.000000
# zf-UBP_57                ...                   -1.000000
# zf-UBP_58                ...                   -1.000000
# zf-UBP_59                ...                   -1.000000
# zf-UBP_6                 ...                   -1.000000
# zf-UBP_60                ...                   -1.000000
# zf-UBP_61                ...                   -1.000000
# zf-UBP_62                ...                   -1.000000
# zf-UBP_63                ...                   -1.000000
# zf-UBP_64                ...                   -1.000000
# zf-UBP_7                 ...                   -1.000000
# zf-UBP_8                 ...                   -1.000000
# zf-UBP_9                 ...                   -1.000000
#
#                    druglike_prop_th_0.1  druglike_prop_th_0.25  \
# 2OG-FeII_Oxy_3_1               0.040116               0.040116
# 2OG-FeII_Oxy_3_10              0.040116               0.040116
# 2OG-FeII_Oxy_3_11              0.040116               0.040116
# 2OG-FeII_Oxy_3_12              0.040116               0.040116
# 2OG-FeII_Oxy_3_13              0.040116               0.040116
# 2OG-FeII_Oxy_3_14              0.040116               0.040116
# 2OG-FeII_Oxy_3_15              0.040116               0.040116
# 2OG-FeII_Oxy_3_16              0.040116               0.040116
# 2OG-FeII_Oxy_3_17              0.040116               0.040116
# 2OG-FeII_Oxy_3_18              0.040116               0.040116
# 2OG-FeII_Oxy_3_19              0.040116               0.040116
# 2OG-FeII_Oxy_3_2               0.040116               0.040116
# 2OG-FeII_Oxy_3_20              0.040116               0.040116
# 2OG-FeII_Oxy_3_21              0.040116               0.040116
# 2OG-FeII_Oxy_3_22              0.040116               0.040116
# 2OG-FeII_Oxy_3_23              0.040116               0.040116
# 2OG-FeII_Oxy_3_24              0.040116               0.040116
# 2OG-FeII_Oxy_3_25              0.040116               0.040116
# 2OG-FeII_Oxy_3_26              0.040116               0.040116
# 2OG-FeII_Oxy_3_27              0.040116               0.040116
# 2OG-FeII_Oxy_3_28              0.040116               0.040116
# 2OG-FeII_Oxy_3_29              0.040116               0.040116
# 2OG-FeII_Oxy_3_3               0.040116               0.040116
# 2OG-FeII_Oxy_3_30              0.040116               0.040116
# 2OG-FeII_Oxy_3_31              0.040116               0.040116
# 2OG-FeII_Oxy_3_32              0.040116               0.040116
# 2OG-FeII_Oxy_3_33              0.040116               0.040116
# 2OG-FeII_Oxy_3_34              0.040116               0.040116
# 2OG-FeII_Oxy_3_35              0.040116               0.040116
# 2OG-FeII_Oxy_3_36              0.040116               0.040116
# ...                                 ...                    ...
# zf-UBP_40                     -1.000000              -1.000000
# zf-UBP_41                     -1.000000              -1.000000
# zf-UBP_42                     -1.000000              -1.000000
# zf-UBP_43                     -1.000000              -1.000000
# zf-UBP_44                     -1.000000              -1.000000
# zf-UBP_45                     -1.000000              -1.000000
# zf-UBP_46                     -1.000000              -1.000000
# zf-UBP_47                     -1.000000              -1.000000
# zf-UBP_48                     -1.000000              -1.000000
# zf-UBP_49                     -1.000000              -1.000000
# zf-UBP_5                      -1.000000              -1.000000
# zf-UBP_50                     -1.000000              -1.000000
# zf-UBP_51                     -1.000000              -1.000000
# zf-UBP_52                     -1.000000              -1.000000
# zf-UBP_53                     -1.000000              -1.000000
# zf-UBP_54                     -1.000000              -1.000000
# zf-UBP_55                     -1.000000              -1.000000
# zf-UBP_56                     -1.000000              -1.000000
# zf-UBP_57                     -1.000000              -1.000000
# zf-UBP_58                     -1.000000              -1.000000
# zf-UBP_59                     -1.000000              -1.000000
# zf-UBP_6                      -1.000000              -1.000000
# zf-UBP_60                     -1.000000              -1.000000
# zf-UBP_61                     -1.000000              -1.000000
# zf-UBP_62                     -1.000000              -1.000000
# zf-UBP_63                     -1.000000              -1.000000
# zf-UBP_64                     -1.000000              -1.000000
# zf-UBP_7                      -1.000000              -1.000000
# zf-UBP_8                      -1.000000              -1.000000
# zf-UBP_9                      -1.000000              -1.000000
#
#                    druglike_prop_th_0.5  druglike_prop_th_0.75  \
# 2OG-FeII_Oxy_3_1               0.085825               0.801976
# 2OG-FeII_Oxy_3_10              0.085825               0.801976
# 2OG-FeII_Oxy_3_11              0.085825               0.801976
# 2OG-FeII_Oxy_3_12              0.085825               0.801976
# 2OG-FeII_Oxy_3_13              0.085825               0.801976
# 2OG-FeII_Oxy_3_14              0.085825               0.801976
# 2OG-FeII_Oxy_3_15              0.085825               0.801976
# 2OG-FeII_Oxy_3_16              0.085825               0.801976
# 2OG-FeII_Oxy_3_17              0.085825               0.801976
# 2OG-FeII_Oxy_3_18              0.085825               0.801976
# 2OG-FeII_Oxy_3_19              0.085825               0.801976
# 2OG-FeII_Oxy_3_2               0.085825               0.801976
# 2OG-FeII_Oxy_3_20              0.085825               0.801976
# 2OG-FeII_Oxy_3_21              0.085825               0.801976
# 2OG-FeII_Oxy_3_22              0.085825               0.801976
# 2OG-FeII_Oxy_3_23              0.085825               0.801976
# 2OG-FeII_Oxy_3_24              0.085825               0.801976
# 2OG-FeII_Oxy_3_25              0.085825               0.801976
# 2OG-FeII_Oxy_3_26              0.085825               0.801976
# 2OG-FeII_Oxy_3_27              0.085825               0.801976
# 2OG-FeII_Oxy_3_28              0.085825               0.801976
# 2OG-FeII_Oxy_3_29              0.085825               0.801976
# 2OG-FeII_Oxy_3_3               0.085825               0.801976
# 2OG-FeII_Oxy_3_30              0.085825               0.801976
# 2OG-FeII_Oxy_3_31              0.085825               0.801976
# 2OG-FeII_Oxy_3_32              0.085825               0.801976
# 2OG-FeII_Oxy_3_33              0.085825               0.801976
# 2OG-FeII_Oxy_3_34              0.085825               0.801976
# 2OG-FeII_Oxy_3_35              0.085825               0.801976
# 2OG-FeII_Oxy_3_36              0.085825               0.801976
# ...                                 ...                    ...
# zf-UBP_40                     -1.000000              -1.000000
# zf-UBP_41                     -1.000000              -1.000000
# zf-UBP_42                     -1.000000              -1.000000
# zf-UBP_43                     -1.000000              -1.000000
# zf-UBP_44                     -1.000000              -1.000000
# zf-UBP_45                     -1.000000              -1.000000
# zf-UBP_46                     -1.000000              -1.000000
# zf-UBP_47                     -1.000000              -1.000000
# zf-UBP_48                     -1.000000              -1.000000
# zf-UBP_49                     -1.000000              -1.000000
# zf-UBP_5                      -1.000000              -1.000000
# zf-UBP_50                     -1.000000              -1.000000
# zf-UBP_51                     -1.000000              -1.000000
# zf-UBP_52                     -1.000000              -1.000000
# zf-UBP_53                     -1.000000              -1.000000
# zf-UBP_54                     -1.000000              -1.000000
# zf-UBP_55                     -1.000000              -1.000000
# zf-UBP_56                     -1.000000              -1.000000
# zf-UBP_57                     -1.000000              -1.000000
# zf-UBP_58                     -1.000000              -1.000000
# zf-UBP_59                     -1.000000              -1.000000
# zf-UBP_6                      -1.000000              -1.000000
# zf-UBP_60                     -1.000000              -1.000000
# zf-UBP_61                     -1.000000              -1.000000
# zf-UBP_62                     -1.000000              -1.000000
# zf-UBP_63                     -1.000000              -1.000000
# zf-UBP_64                     -1.000000              -1.000000
# zf-UBP_7                      -1.000000              -1.000000
# zf-UBP_8                      -1.000000              -1.000000
# zf-UBP_9                      -1.000000              -1.000000
#
#                    all_propensity  all_prop_th_0.1  all_prop_th_0.25  \
# 2OG-FeII_Oxy_3_1         0.006650         0.017995          0.150032
# 2OG-FeII_Oxy_3_10        0.012646         0.017995          0.150032
# 2OG-FeII_Oxy_3_11        0.006700         0.017995          0.150032
# 2OG-FeII_Oxy_3_12        0.460550         0.017995          0.150032
# 2OG-FeII_Oxy_3_13        0.026189         0.017995          0.150032
# 2OG-FeII_Oxy_3_14        0.030821         0.017995          0.150032
# 2OG-FeII_Oxy_3_15        0.373366         0.017995          0.150032
# 2OG-FeII_Oxy_3_16        0.023985         0.017995          0.150032
# 2OG-FeII_Oxy_3_17        0.366464         0.017995          0.150032
# 2OG-FeII_Oxy_3_18        0.000000         0.017995          0.150032
# 2OG-FeII_Oxy_3_19        0.061398         0.017995          0.150032
# 2OG-FeII_Oxy_3_2         0.126635         0.017995          0.150032
# 2OG-FeII_Oxy_3_20        0.041480         0.017995          0.150032
# 2OG-FeII_Oxy_3_21        0.215379         0.017995          0.150032
# 2OG-FeII_Oxy_3_22        0.030583         0.017995          0.150032
# 2OG-FeII_Oxy_3_23        0.074454         0.017995          0.150032
# 2OG-FeII_Oxy_3_24        0.071167         0.017995          0.150032
# 2OG-FeII_Oxy_3_25        0.013054         0.017995          0.150032
# 2OG-FeII_Oxy_3_26        0.099025         0.017995          0.150032
# 2OG-FeII_Oxy_3_27        0.053240         0.017995          0.150032
# 2OG-FeII_Oxy_3_28        0.122838         0.017995          0.150032
# 2OG-FeII_Oxy_3_29        0.100804         0.017995          0.150032
# 2OG-FeII_Oxy_3_3         0.000000         0.017995          0.150032
# 2OG-FeII_Oxy_3_30        0.041288         0.017995          0.150032
# 2OG-FeII_Oxy_3_31        0.094434         0.017995          0.150032
# 2OG-FeII_Oxy_3_32        0.044324         0.017995          0.150032
# 2OG-FeII_Oxy_3_33        0.128587         0.017995          0.150032
# 2OG-FeII_Oxy_3_34        0.052069         0.017995          0.150032
# 2OG-FeII_Oxy_3_35        0.293959         0.017995          0.150032
# 2OG-FeII_Oxy_3_36        0.029033         0.017995          0.150032
# ...                           ...              ...               ...
# zf-UBP_40                0.026009         0.018503          0.018503
# zf-UBP_41                0.000000         0.018503          0.018503
# zf-UBP_42                0.026009         0.018503          0.018503
# zf-UBP_43                0.000000         0.018503          0.018503
# zf-UBP_44                0.017116         0.018503          0.018503
# zf-UBP_45                0.000000         0.018503          0.018503
# zf-UBP_46                0.000000         0.018503          0.018503
# zf-UBP_47                0.051347         0.018503          0.018503
# zf-UBP_48                0.000000         0.018503          0.018503
# zf-UBP_49                0.000000         0.018503          0.018503
# zf-UBP_5                 0.000000         0.018503          0.018503
# zf-UBP_50                0.031008         0.018503          0.018503
# zf-UBP_51                0.159007         0.018503          0.018503
# zf-UBP_52                0.675836         0.018503          0.018503
# zf-UBP_53                0.169791         0.018503          0.018503
# zf-UBP_54                0.017071         0.018503          0.018503
# zf-UBP_55                0.675836         0.018503          0.018503
# zf-UBP_56                0.068463         0.018503          0.018503
# zf-UBP_57                0.000000         0.018503          0.018503
# zf-UBP_58                0.119810         0.018503          0.018503
# zf-UBP_59                0.000000         0.018503          0.018503
# zf-UBP_6                 0.000000         0.018503          0.018503
# zf-UBP_60                0.000000         0.018503          0.018503
# zf-UBP_61                0.034231         0.018503          0.018503
# zf-UBP_62                0.000000         0.018503          0.018503
# zf-UBP_63                0.000000         0.018503          0.018503
# zf-UBP_64                0.000000         0.018503          0.018503
# zf-UBP_7                 0.000000         0.018503          0.018503
# zf-UBP_8                 0.000000         0.018503          0.018503
# zf-UBP_9                 0.000000         0.018503          0.018503
#
#                    all_prop_th_0.5  all_prop_th_0.75
# 2OG-FeII_Oxy_3_1               NaN               NaN
# 2OG-FeII_Oxy_3_10              NaN               NaN
# 2OG-FeII_Oxy_3_11              NaN               NaN
# 2OG-FeII_Oxy_3_12              NaN               NaN
# 2OG-FeII_Oxy_3_13              NaN               NaN
# 2OG-FeII_Oxy_3_14              NaN               NaN
# 2OG-FeII_Oxy_3_15              NaN               NaN
# 2OG-FeII_Oxy_3_16              NaN               NaN
# 2OG-FeII_Oxy_3_17              NaN               NaN
# 2OG-FeII_Oxy_3_18              NaN               NaN
# 2OG-FeII_Oxy_3_19              NaN               NaN
# 2OG-FeII_Oxy_3_2               NaN               NaN
# 2OG-FeII_Oxy_3_20              NaN               NaN
# 2OG-FeII_Oxy_3_21              NaN               NaN
# 2OG-FeII_Oxy_3_22              NaN               NaN
# 2OG-FeII_Oxy_3_23              NaN               NaN
# 2OG-FeII_Oxy_3_24              NaN               NaN
# 2OG-FeII_Oxy_3_25              NaN               NaN
# 2OG-FeII_Oxy_3_26              NaN               NaN
# 2OG-FeII_Oxy_3_27              NaN               NaN
# 2OG-FeII_Oxy_3_28              NaN               NaN
# 2OG-FeII_Oxy_3_29              NaN               NaN
# 2OG-FeII_Oxy_3_3               NaN               NaN
# 2OG-FeII_Oxy_3_30              NaN               NaN
# 2OG-FeII_Oxy_3_31              NaN               NaN
# 2OG-FeII_Oxy_3_32              NaN               NaN
# 2OG-FeII_Oxy_3_33              NaN               NaN
# 2OG-FeII_Oxy_3_34              NaN               NaN
# 2OG-FeII_Oxy_3_35              NaN               NaN
# 2OG-FeII_Oxy_3_36              NaN               NaN
# ...                            ...               ...
# zf-UBP_40                 0.037564          0.676386
# zf-UBP_41                 0.037564          0.676386
# zf-UBP_42                 0.037564          0.676386
# zf-UBP_43                 0.037564          0.676386
# zf-UBP_44                 0.037564          0.676386
# zf-UBP_45                 0.037564          0.676386
# zf-UBP_46                 0.037564          0.676386
# zf-UBP_47                 0.037564          0.676386
# zf-UBP_48                 0.037564          0.676386
# zf-UBP_49                 0.037564          0.676386
# zf-UBP_5                  0.037564          0.676386
# zf-UBP_50                 0.037564          0.676386
# zf-UBP_51                 0.037564          0.676386
# zf-UBP_52                 0.037564          0.676386
# zf-UBP_53                 0.037564          0.676386
# zf-UBP_54                 0.037564          0.676386
# zf-UBP_55                 0.037564          0.676386
# zf-UBP_56                 0.037564          0.676386
# zf-UBP_57                 0.037564          0.676386
# zf-UBP_58                 0.037564          0.676386
# zf-UBP_59                 0.037564          0.676386
# zf-UBP_6                  0.037564          0.676386
# zf-UBP_60                 0.037564          0.676386
# zf-UBP_61                 0.037564          0.676386
# zf-UBP_62                 0.037564          0.676386
# zf-UBP_63                 0.037564          0.676386
# zf-UBP_64                 0.037564          0.676386
# zf-UBP_7                  0.037564          0.676386
# zf-UBP_8                  0.037564          0.676386
# zf-UBP_9                  0.037564          0.676386
#
# [44872 rows x 61 columns]

# %% [markdown]
# ### Aggregate positives and negatives across domains

# %%
def create_labels(position_labels):
    #Flags for creating negatives
    zero_prop = True
    no_prop = True
    all_ligands = False

    ligands_negatives_df = create_negatives_datasets_combined(zero_prop, no_prop, position_labels, [], all_ligands)
    ligands_positives_df = create_positives_datasets_combined(position_labels, [], all_ligands)

    #Initialize dataframe
    col_names=[]
    for ligand in ligands_negatives_df:
        col_names.append(ligand+"_label")
    domain_labels = pd.DataFrame(columns=col_names)

    for pos,row in position_labels.iterrows():
        #Extract domain name and check if already added
        domain_name = "_".join(pos.split("_")[:-1])
        if not domain_name in domain_labels.index:
            domain_labels.loc[domain_name] = np.zeros(len(domain_labels.columns))

        #Create binary label
        for ligand in ligands_positives_df:
            if pos in ligands_positives_df[ligand].index:
                domain_labels.loc[domain_name,ligand+"_label"] = 1

    return domain_labels

# %%
train_domain_labels = create_labels(train_position_labels)
train_domain_labels.to_csv(curr_dir+"/domain_labels/train_domain_labels_"+train_datafile_date+".csv", sep='\t')

not_train_domain_labels = create_labels(not_train_position_labels)
not_train_domain_labels.to_csv(curr_dir+"/domain_labels/not_train_domain_labels_"+not_train_datafile_date+".csv", sep='\t')
# Out:
# dna non-binding #:43886
# dnabase non-binding #:44418
# dnabackbone non-binding #:44021
# dna combined non binding #: 43884
# rna non-binding #:43727
# rnabase non-binding #:44154
# rnabackbone non-binding #:43944
# rna combined non binding #: 43720
# peptide non-binding #:41105
# ion non-binding #:39630
# metabolite non-binding #:39638
# druglike non-binding #:35018
# sm non-binding #:32697
# dna #: 369
# dnabase #: 161
# dnabackbone #: 245
# dna combined #: 397
# rna #: 206
# rnabase #: 118
# rnabackbone #: 136
# rna combined #: 247
# peptide #: 436
# ion #: 351
# metabolite #: 522
# druglike #: 763
# sm #: 825
# dna non-binding #:147900
# dnabase non-binding #:149821
# dnabackbone non-binding #:148214
# dna combined non binding #: 147893
# rna non-binding #:144984
# rnabase non-binding #:147626
# rnabackbone non-binding #:145510
# rna combined non binding #: 144977
# peptide non-binding #:148527
# ion non-binding #:142566
# metabolite non-binding #:140418
# druglike non-binding #:130078
# sm non-binding #:126372
# dna #: 569
# dnabase #: 184
# dnabackbone #: 445
# dna combined #: 628
# rna #: 2830
# rnabase #: 832
# rnabackbone #: 2509
# rna combined #: 2885
# peptide #: 513
# ion #: 603
# metabolite #: 1684
# druglike #: 3178
# sm #: 3334

# %% [markdown]
# ## Old - Uses inferred bindings scores
# ### Obtain position labels
# ##### Domains not in training set

# %%
if not os.path.exists("not_train_position_labels.csv"):
    with open(curr_dir+"/../../7.InteracDome_targetVariable/domains_ligands_propensity_dict.pik", 'rb') as handle:
         raw_labels = pickle.load(handle)

    with open(curr_dir+"/../../13.Process_domains_not_in_training/processed_domains_not_in_pipeline_final_list.pik", 'rb') as handle:
        not_train_list = pickle.load(handle)

    not_train_position_labels = pd.DataFrame(columns=["domain_length"])
    for domain in not_train_list:
        for ligand in raw_labels[domain]:
            for state in raw_labels[domain][ligand]["states_props"]:
                not_train_position_labels.loc[domain+"_"+str(state),"domain_length"] = len(raw_labels[domain][ligand]["states_props"])
                not_train_position_labels.loc[domain+"_"+str(state),ligand+"_prop_th_0.1"] = raw_labels[domain][ligand]["prop_th_0.1"]
                not_train_position_labels.loc[domain+"_"+str(state),ligand+"_prop_th_0.25"] = raw_labels[domain][ligand]["prop_th_0.25"]
                not_train_position_labels.loc[domain+"_"+str(state),ligand+"_prop_th_0.5"] = raw_labels[domain][ligand]["prop_th_0.5"]
                not_train_position_labels.loc[domain+"_"+str(state),ligand+"_prop_th_0.75"] = raw_labels[domain][ligand]["prop_th_0.75"]
                not_train_position_labels.loc[domain+"_"+str(state),ligand+"_propensity"] = raw_labels[domain][ligand]["states_props"][state]
    not_train_position_labels.to_csv("not_train_position_labels.csv", sep='\t')
else:
    not_train_position_labels = pd.read_csv("not_train_position_labels.csv", sep='\t', index_col=0)
